# %% [markdown]
# ## Custom plotting Bilby results
#
#
# This notebook plots the results from the Bilby sampler

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %%
from plotting import plot_custom_corner
root = "../data/nested_sampling/"

# %% [markdown]
# ### Example 1

# %%
path = "../data/nested_sampling/random_walk2_ozstar_result.json"
labels = [r'$\omega$', r'delta', r'alpha', r'h']
injection_parameters = [5e-7,1.0,1.0,1e-2]
axes_scales = ["log", "linear","linear", "log"]
plot_custom_corner(path,labels, injection_parameters,axes_scales,savefig=None)
# Out:
# Median values:
# 0    5.015358e-07
# 1    1.000739e+00
# 2    9.908916e-01
# 3    8.032374e-03
# dtype: float64

# %% [markdown]
# ### Example 2

# %%
path = "../data/nested_sampling/random_walk3_ozstar_result.json"
labels = [r'$\omega$', r'h']
injection_parameters = [5e-7,1e-2]
axes_scales = ["log", "log"]
plot_custom_corner(path,labels, injection_parameters,axes_scales,savefig=None)
# Out:
# Median values:
# 0    5.000000e-07
# 1    9.449992e-03
# dtype: float64

# %% [markdown]
# ### Random walk 4

# %%
path = "../data/nested_sampling/ozstar_alternative_result.json"
labels = [r'$\omega$',r'$\Phi_0$', r'$\psi$', r'\iota', r'delta', r'alpha', r'h']
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-2]
axes_scales = ["log", "linear","linear","linear","linear", "linear", "log"]
plot_custom_corner(path,labels, injection_parameters,axes_scales,savefig=None)
# Out:
#                 0         1         2         3         4         5  \
# 0    2.684943e-06  1.594583  0.242140  0.125136  1.520536  2.527472
# 1    9.172307e-06  0.012297  2.025440  0.086314  0.651139  0.264535
# 2    8.839198e-06  2.235267  2.982458  1.303486  0.783912  0.159327
# 3    4.108691e-06  1.565257  1.365416  0.052226  0.302899  2.159788
# 4    7.385736e-06  2.000298  2.384687  0.116357  1.292861  0.856135
# ..            ...       ...       ...       ...       ...       ...
# 536  1.389128e-09  1.707396  1.175617  1.041654  0.278123  1.754095
# 537  5.356086e-09  1.601046  1.288311  1.029432  0.372914  1.105874
# 538  5.763790e-09  1.590055  2.079197  0.149912  1.122059  0.091266
# 539  4.794551e-09  1.764857  2.407945  1.059307  0.937676  1.597189
# 540  4.243136e-08  1.637827  2.567373  0.327914  0.639909  1.096665
#
#                 6
# 0    8.985689e-06
# 1    3.118388e-06
# 2    6.620802e-06
# 3    9.367768e-06
# 4    3.228165e-06
# ..            ...
# 536  1.461491e-07
# 537  1.088954e-07
# 538  1.040845e-07
# 539  1.312320e-07
# 540  1.357952e-07
#
# [541 rows x 7 columns]
#          omega_gw   phi0_gw    psi_gw   iota_gw  delta_gw  alpha_gw  \
# 0    2.684943e-06  1.594583  0.242140  0.125136  1.520536  2.527472
# 1    9.172307e-06  0.012297  2.025440  0.086314  0.651139  0.264535
# 2    8.839198e-06  2.235267  2.982458  1.303486  0.783912  0.159327
# 3    4.108691e-06  1.565257  1.365416  0.052226  0.302899  2.159788
# 4    7.385736e-06  2.000298  2.384687  0.116357  1.292861  0.856135
# ..            ...       ...       ...       ...       ...       ...
# 536  1.389128e-09  1.707396  1.175617  1.041654  0.278123  1.754095
# 537  5.356086e-09  1.601046  1.288311  1.029432  0.372914  1.105874
# 538  5.763790e-09  1.590055  2.079197  0.149912  1.122059  0.091266
# 539  4.794551e-09  1.764857  2.407945  1.059307  0.937676  1.597189
# 540  4.243136e-08  1.637827  2.567373  0.327914  0.639909  1.096665
#
#                 h         f00         f01         f02  ...       gamma41  \
# 0    8.985689e-06  327.847021  205.530699  303.090979  ...  1.000000e-13
# 1    3.118388e-06  327.847021  205.530699  303.090979  ...  1.000000e-13
# 2    6.620802e-06  327.847021  205.530699  303.090979  ...  1.000000e-13
# 3    9.367768e-06  327.847021  205.530699  303.090979  ...  1.000000e-13
# 4    3.228165e-06  327.847021  205.530699  303.090979  ...  1.000000e-13
# ..            ...         ...         ...         ...  ...           ...
# 536  1.461491e-07  327.847021  205.530699  303.090979  ...  1.000000e-13
# 537  1.088954e-07  327.847021  205.530699  303.090979  ...  1.000000e-13
# 538  1.040845e-07  327.847021  205.530699  303.090979  ...  1.000000e-13
# 539  1.312320e-07  327.847021  205.530699  303.090979  ...  1.000000e-13
# 540  1.357952e-07  327.847021  205.530699  303.090979  ...  1.000000e-13
#
#           gamma42       gamma43       gamma44       gamma45       gamma46  \
# 0    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
# 1    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
# 2    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
# 3    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
# 4    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
# ..            ...           ...           ...           ...           ...
# 536  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
# 537  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
# 538  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
# 539  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
# 540  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13
#
#      sigma_p       sigma_m  log_likelihood  log_prior
# 0      0.001  1.000000e-10   -22545.338067  16.362867
# 1      0.001  1.000000e-10   -22545.282073  16.192655
# 2      0.001  1.000000e-10   -22545.281196  15.476747
# 3      0.001  1.000000e-10   -22545.267685  15.895780
# 4      0.001  1.000000e-10   -22545.262912  16.374695
# ..       ...           ...             ...        ...
# 536    0.001  1.000000e-10   -22545.238016  28.048367
# 537    0.001  1.000000e-10   -22545.238016  26.993049
# 538    0.001  1.000000e-10   -22545.238016  26.964872
# 539    0.001  1.000000e-10   -22545.238016  26.917223
# 540    0.001  1.000000e-10   -22545.238016  24.702634
#
# [541 rows x 199 columns]
# Median values:
# 0    8.327780e-08
# 1    1.696858e+00
# 2    1.620318e+00
# 3    7.450367e-01
# 4    7.988796e-01
# 5    1.598299e+00
# 6    8.625188e-07
# dtype: float64

# %%
#path = "../data/nested_sampling/diagonal9_03_result.json"
#path = "../data/nested_sampling/original_params_w_alpha_result.json"

#path = "../data/nested_sampling/original_params_w_alpha_retry_result.json"
#path = "../data/nested_sampling/run_0304a_result.json"


path = root + "canonical_example2_result.json"
path = root + "all_bar_one_result.json"
path = root + "all_gw_1_psr3_result.json"

#run_0304d
#run_0304a

# %%
from plotting import plot_custom_corner
labels = [r'$\omega$', r'$\Phi_0$', r'$\psi$', r'$\iota$', r'$\delta$', r'$h$']
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1e-2]
axes_scales = ["log", "linear","linear","linear","linear","log"]
plot_custom_corner(path,labels, injection_parameters,axes_scales,savefig=None)

# %%
import pandas as pd
import json
import corner 


def analysis(path,cols_to_plot):

    # Opening JSON file
    f = open(path)
  
    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    #Make the posterior a dataframe
    df = pd.DataFrame(data["posterior"]["content"])

    #Surface median values
    print("Number of posterior samples:")
    print(len(df))
    print("Median values:")
    print(df.median())


    y = df[cols_to_plot].to_numpy()
    fig = corner.corner(y,color='C0',
                        show_titles=True,
                        smooth=True, 
                        smooth1d=True,quantiles=[0.16, 0.84])

# %%
#columns = ["phi0_gw","psi_gw","alpha_gw","h"]
columns = ["omega_gw", "phi0_gw"]


analysis(path,columns)
# Out:
# Number of posterior samples:
# 305
# Median values:
# omega_gw          4.134123e-09
# phi0_gw           1.555278e+00
# psi_gw            1.013469e+00
# iota_gw           7.151726e-01
# delta_gw          8.673811e-01
# h                 6.251622e-01
# alpha_gw          1.000000e+00
# f00               2.668692e+02
# fdot0            -2.151992e-15
# distance0         1.666655e+11
# gamma0            1.000000e-13
# sigma_p           1.000000e-03
# sigma_m           1.000000e-10
# log_likelihood   -2.403852e+02
# log_prior         1.145932e+01
# dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb Cell 4 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> #columns = ["phi0_gw","psi_gw","alpha_gw","h"]
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> columns = ["omega_gw", "phi0_gw"]
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> analysis(path,columns)
#
# /Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb Cell 4 in analysis(path, cols_to_plot)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#W3sZmlsZQ%3D%3D?line=20'>21</a> print(df.median())
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a> y = df[cols_to_plot].to_numpy()
# ---> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a> fig = corner.corner(y,color='C0',
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a>                     show_titles=True,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#W3sZmlsZQ%3D%3D?line=26'>27</a>                     smooth=True,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#W3sZmlsZQ%3D%3D?line=27'>28</a>                     smooth1d=True,quantiles=[0.16, 0.84])
#
# NameError: name 'corner' is not defined

# %%
import json 
path = root + "rwalk_ozstar_result.json"

# Opening JSON file
f = open(path)

# returns JSON object as 
# a dictionary
data = json.load(f)

#Make the posterior a dataframe
df1 = pd.DataFrame(data["posterior"]["content"])
df2 = pd.DataFrame(data["samples"]["content"])

# %%
df1
# Out:
#          omega_gw  delta_gw  alpha_gw         h  phi0_gw  psi_gw  iota_gw  \
# 0    1.056953e-09  0.969487  0.164003  0.009780      0.2     2.5      1.0
# 1    1.385398e-09  0.997980  0.025164  0.008680      0.2     2.5      1.0
# 2    1.059498e-09  0.971508  0.167612  0.010041      0.2     2.5      1.0
# 3    1.378218e-09  0.993391  0.033459  0.010214      0.2     2.5      1.0
# 4    1.371076e-09  0.989541  0.043988  0.013400      0.2     2.5      1.0
# ..            ...       ...       ...       ...      ...     ...      ...
# 371  1.377737e-09  0.993796  0.037998  0.014084      0.2     2.5      1.0
# 372  1.376634e-09  0.993964  0.039554  0.014077      0.2     2.5      1.0
# 373  1.377818e-09  0.994005  0.037831  0.013565      0.2     2.5      1.0
# 374  1.377065e-09  0.993321  0.039684  0.013447      0.2     2.5      1.0
# 375  1.376888e-09  0.993234  0.039765  0.013678      0.2     2.5      1.0
#
#             f00         f01         f02  ...       gamma41       gamma42  \
# 0    327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
# 1    327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
# 2    327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
# 3    327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
# 4    327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
# ..          ...         ...         ...  ...           ...           ...
# 371  327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
# 372  327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
# 373  327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
# 374  327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
# 375  327.847021  205.530699  303.090979  ...  1.000000e-13  1.000000e-13
#
#           gamma43       gamma44       gamma45       gamma46  sigma_p  \
# 0    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
# 1    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
# 2    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
# 3    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
# 4    1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
# ..            ...           ...           ...           ...      ...
# 371  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
# 372  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
# 373  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
# 374  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
# 375  1.000000e-13  1.000000e-13  1.000000e-13  1.000000e-13    0.001
#
#           sigma_m  log_likelihood  log_prior
# 0    1.000000e-10   -17933.991718  18.447132
# 1    1.000000e-10   -17932.672026  18.253001
# 2    1.000000e-10   -17930.579790  18.415437
# 3    1.000000e-10   -17930.284191  18.102576
# 4    1.000000e-10   -17930.056139  17.842088
# ..            ...             ...        ...
# 371  1.000000e-10   -17923.013588  17.780977
# 372  1.000000e-10   -17923.006173  17.782038
# 373  1.000000e-10   -17922.987518  17.818111
# 374  1.000000e-10   -17922.926445  17.828494
# 375  1.000000e-10   -17922.919834  17.811690
#
# [376 rows x 199 columns]

# %%
df2.median()
# Out:
# 0    1.375669e-09
# 1    9.933454e-01
# 2    4.065379e-02
# 3    1.273043e-02
# dtype: float64

# %%
y = df2.to_numpy()
fig = corner.corner(y,color='C0',
                    show_titles=True,
                    smooth=True, 
                    smooth1d=True,quantiles=[0.16, 0.84])

# %%
# Out:
# array([[5.00000000e-07, 1.00000054e-02],
#        [5.00000000e-07, 9.99999538e-03],
#        [5.00000000e-07, 9.99999480e-03],
#        [5.00000000e-07, 1.00000001e-02],
#        [5.00000000e-07, 9.99999762e-03],
#        [5.00000000e-07, 1.00000043e-02],
#        [5.00000000e-07, 1.00000013e-02],
#        [5.00000000e-07, 9.99999873e-03],
#        [5.00000000e-07, 9.99999567e-03],
#        [5.00000000e-07, 1.00000051e-02],
#        [5.00000000e-07, 9.99999996e-03],
#        [5.00000000e-07, 1.00000032e-02],
#        [5.00000000e-07, 9.99999725e-03],
#        [5.00000000e-07, 9.99999956e-03],
#        [5.00000000e-07, 9.99999657e-03],
#        [5.00000000e-07, 1.00000032e-02],
#        [5.00000000e-07, 9.99999595e-03],
#        [5.00000000e-07, 9.99999641e-03],
#        [5.00000000e-07, 9.99999879e-03],
#        [5.00000000e-07, 9.99999607e-03],
#        [5.00000000e-07, 1.00000014e-02],
#        [5.00000000e-07, 1.00000015e-02],
#        [5.00000000e-07, 1.00000044e-02],
#        [5.00000000e-07, 1.00000036e-02],
#        [5.00000000e-07, 9.99999721e-03],
#        [5.00000000e-07, 9.99999770e-03],
#        [5.00000000e-07, 9.99999711e-03],
#        [5.00000000e-07, 9.99999652e-03],
#        [5.00000000e-07, 9.99999668e-03],
#        [5.00000000e-07, 9.99999811e-03],
#        [5.00000000e-07, 1.00000027e-02],
#        [5.00000000e-07, 1.00000036e-02],
#        [5.00000000e-07, 1.00000024e-02],
#        [5.00000000e-07, 9.99999703e-03],
#        [5.00000000e-07, 1.00000026e-02],
#        [5.00000000e-07, 1.00000019e-02],
#        [5.00000000e-07, 1.00000008e-02],
#        [5.00000000e-07, 1.00000038e-02],
#        [5.00000000e-07, 9.99999688e-03],
#        [5.00000000e-07, 9.99999976e-03],
#        [5.00000000e-07, 1.00000004e-02],
#        [5.00000000e-07, 9.99999902e-03],
#        [5.00000000e-07, 9.99999995e-03],
#        [5.00000000e-07, 1.00000004e-02],
#        [5.00000000e-07, 9.99999910e-03],
#        [5.00000000e-07, 1.00000000e-02],
#        [5.00000000e-07, 1.00000036e-02],
#        [5.00000000e-07, 9.99999946e-03],
#        [5.00000000e-07, 9.99999818e-03],
#        [5.00000000e-07, 9.99999743e-03],
#        [5.00000000e-07, 9.99999700e-03],
#        [5.00000000e-07, 9.99999910e-03],
#        [5.00000000e-07, 9.99999721e-03],
#        [5.00000000e-07, 1.00000029e-02],
#        [5.00000000e-07, 9.99999955e-03],
#        [5.00000000e-07, 9.99999932e-03],
#        [5.00000000e-07, 1.00000014e-02],
#        [5.00000000e-07, 1.00000032e-02],
#        [5.00000000e-07, 9.99999708e-03],
#        [5.00000000e-07, 1.00000023e-02],
#        [5.00000000e-07, 9.99999766e-03],
#        [5.00000000e-07, 1.00000032e-02],
#        [5.00000000e-07, 1.00000032e-02],
#        [5.00000000e-07, 1.00000020e-02],
#        [5.00000000e-07, 9.99999773e-03],
#        [5.00000000e-07, 1.00000005e-02],
#        [5.00000000e-07, 1.00000010e-02],
#        [5.00000000e-07, 1.00000033e-02],
#        [5.00000000e-07, 1.00000016e-02],
#        [5.00000000e-07, 1.00000031e-02],
#        [5.00000000e-07, 1.00000032e-02],
#        [5.00000000e-07, 1.00000016e-02],
#        [5.00000000e-07, 9.99999743e-03],
#        [5.00000000e-07, 1.00000014e-02],
#        [5.00000000e-07, 9.99999960e-03],
#        [5.00000000e-07, 1.00000021e-02],
#        [5.00000000e-07, 1.00000023e-02],
#        [5.00000000e-07, 9.99999892e-03],
#        [5.00000000e-07, 1.00000032e-02],
#        [5.00000000e-07, 1.00000032e-02],
#        [5.00000000e-07, 1.00000026e-02],
#        [5.00000000e-07, 9.99999946e-03],
#        [5.00000000e-07, 1.00000029e-02],
#        [5.00000000e-07, 1.00000012e-02],
#        [5.00000000e-07, 1.00000031e-02],
#        [5.00000000e-07, 1.00000030e-02],
#        [5.00000000e-07, 1.00000002e-02],
#        [5.00000000e-07, 9.99999812e-03],
#        [5.00000000e-07, 1.00000029e-02],
#        [5.00000000e-07, 1.00000013e-02],
#        [5.00000000e-07, 1.00000007e-02],
#        [5.00000000e-07, 1.00000023e-02],
#        [5.00000000e-07, 1.00000026e-02],
#        [5.00000000e-07, 9.99999755e-03],
#        [5.00000000e-07, 9.99999809e-03],
#        [5.00000000e-07, 9.99999759e-03],
#        [5.00000000e-07, 1.00000025e-02],
#        [5.00000000e-07, 1.00000011e-02],
#        [5.00000000e-07, 9.99999823e-03],
#        [5.00000000e-07, 1.00000008e-02],
#        [5.00000000e-07, 9.99999782e-03],
#        [5.00000000e-07, 1.00000017e-02],
#        [5.00000000e-07, 1.00000021e-02],
#        [5.00000000e-07, 1.00000004e-02],
#        [5.00000000e-07, 9.99999826e-03],
#        [5.00000000e-07, 1.00000027e-02],
#        [5.00000000e-07, 9.99999782e-03],
#        [5.00000000e-07, 1.00000013e-02],
#        [5.00000000e-07, 1.00000026e-02],
#        [5.00000000e-07, 9.99999984e-03],
#        [5.00000000e-07, 9.99999812e-03],
#        [5.00000000e-07, 1.00000013e-02],
#        [5.00000000e-07, 1.00000001e-02],
#        [5.00000000e-07, 1.00000013e-02],
#        [5.00000000e-07, 1.00000026e-02],
#        [5.00000000e-07, 1.00000026e-02],
#        [5.00000000e-07, 1.00000009e-02],
#        [5.00000000e-07, 1.00000026e-02],
#        [5.00000000e-07, 9.99999795e-03],
#        [5.00000000e-07, 9.99999910e-03],
#        [5.00000000e-07, 9.99999823e-03],
#        [5.00000000e-07, 1.00000025e-02],
#        [5.00000000e-07, 1.00000026e-02],
#        [5.00000000e-07, 1.00000007e-02],
#        [5.00000000e-07, 1.00000025e-02],
#        [5.00000000e-07, 9.99999898e-03],
#        [5.00000000e-07, 9.99999869e-03],
#        [5.00000000e-07, 1.00000021e-02],
#        [5.00000000e-07, 1.00000024e-02],
#        [5.00000000e-07, 9.99999812e-03],
#        [5.00000000e-07, 9.99999848e-03],
#        [5.00000000e-07, 9.99999825e-03],
#        [5.00000000e-07, 1.00000017e-02],
#        [5.00000000e-07, 9.99999985e-03],
#        [5.00000000e-07, 9.99999834e-03],
#        [5.00000000e-07, 1.00000023e-02],
#        [5.00000000e-07, 1.00000023e-02],
#        [5.00000000e-07, 9.99999977e-03],
#        [5.00000000e-07, 1.00000001e-02],
#        [5.00000000e-07, 9.99999820e-03],
#        [5.00000000e-07, 9.99999862e-03],
#        [5.00000000e-07, 1.00000018e-02],
#        [5.00000000e-07, 1.00000017e-02],
#        [5.00000000e-07, 9.99999846e-03],
#        [5.00000000e-07, 9.99999872e-03],
#        [5.00000000e-07, 9.99999844e-03],
#        [5.00000000e-07, 1.00000015e-02],
#        [5.00000000e-07, 1.00000020e-02],
#        [5.00000000e-07, 1.00000012e-02],
#        [5.00000000e-07, 9.99999830e-03],
#        [5.00000000e-07, 9.99999957e-03],
#        [5.00000000e-07, 1.00000016e-02],
#        [5.00000000e-07, 9.99999878e-03],
#        [5.00000000e-07, 9.99999847e-03],
#        [5.00000000e-07, 9.99999978e-03],
#        [5.00000000e-07, 1.00000018e-02],
#        [5.00000000e-07, 9.99999913e-03],
#        [5.00000000e-07, 1.00000017e-02],
#        [5.00000000e-07, 9.99999872e-03],
#        [5.00000000e-07, 9.99999847e-03],
#        [5.00000000e-07, 1.00000009e-02],
#        [5.00000000e-07, 1.00000003e-02],
#        [5.00000000e-07, 1.00000020e-02],
#        [5.00000000e-07, 9.99999987e-03],
#        [5.00000000e-07, 9.99999922e-03],
#        [5.00000000e-07, 1.00000005e-02],
#        [5.00000000e-07, 9.99999924e-03],
#        [5.00000000e-07, 1.00000012e-02],
#        [5.00000000e-07, 9.99999956e-03],
#        [5.00000000e-07, 1.00000015e-02],
#        [5.00000000e-07, 1.00000017e-02],
#        [5.00000000e-07, 9.99999874e-03],
#        [5.00000000e-07, 9.99999872e-03],
#        [5.00000000e-07, 9.99999896e-03],
#        [5.00000000e-07, 1.00000017e-02],
#        [5.00000000e-07, 9.99999966e-03],
#        [5.00000000e-07, 9.99999971e-03],
#        [5.00000000e-07, 9.99999889e-03],
#        [5.00000000e-07, 1.00000010e-02],
#        [5.00000000e-07, 9.99999890e-03],
#        [5.00000000e-07, 9.99999893e-03],
#        [5.00000000e-07, 9.99999987e-03],
#        [5.00000000e-07, 1.00000013e-02],
#        [5.00000000e-07, 1.00000003e-02],
#        [5.00000000e-07, 9.99999964e-03],
#        [5.00000000e-07, 1.00000005e-02],
#        [5.00000000e-07, 1.00000009e-02],
#        [5.00000000e-07, 1.00000017e-02],
#        [5.00000000e-07, 9.99999879e-03],
#        [5.00000000e-07, 9.99999925e-03],
#        [5.00000000e-07, 1.00000010e-02],
#        [5.00000000e-07, 1.00000003e-02],
#        [5.00000000e-07, 9.99999912e-03],
#        [5.00000000e-07, 1.00000016e-02],
#        [5.00000000e-07, 1.00000013e-02],
#        [5.00000000e-07, 1.00000010e-02],
#        [5.00000000e-07, 1.00000006e-02],
#        [5.00000000e-07, 1.00000016e-02],
#        [5.00000000e-07, 9.99999931e-03],
#        [5.00000000e-07, 9.99999912e-03],
#        [5.00000000e-07, 1.00000013e-02],
#        [5.00000000e-07, 9.99999959e-03],
#        [5.00000000e-07, 9.99999982e-03],
#        [5.00000000e-07, 1.00000014e-02],
#        [5.00000000e-07, 1.00000003e-02],
#        [5.00000000e-07, 1.00000006e-02],
#        [5.00000000e-07, 1.00000002e-02],
#        [5.00000000e-07, 1.00000009e-02],
#        [5.00000000e-07, 9.99999980e-03],
#        [5.00000000e-07, 9.99999909e-03],
#        [5.00000000e-07, 9.99999974e-03],
#        [5.00000000e-07, 9.99999906e-03],
#        [5.00000000e-07, 1.00000005e-02],
#        [5.00000000e-07, 9.99999911e-03],
#        [5.00000000e-07, 1.00000001e-02],
#        [5.00000000e-07, 9.99999950e-03],
#        [5.00000000e-07, 9.99999930e-03],
#        [5.00000000e-07, 9.99999969e-03],
#        [5.00000000e-07, 9.99999919e-03],
#        [5.00000000e-07, 1.00000013e-02],
#        [5.00000000e-07, 9.99999989e-03],
#        [5.00000000e-07, 1.00000012e-02],
#        [5.00000000e-07, 9.99999935e-03],
#        [5.00000000e-07, 9.99999998e-03],
#        [5.00000000e-07, 9.99999948e-03],
#        [5.00000000e-07, 1.00000009e-02],
#        [5.00000000e-07, 9.99999943e-03],
#        [5.00000000e-07, 9.99999998e-03],
#        [5.00000000e-07, 9.99999930e-03],
#        [5.00000000e-07, 1.00000012e-02],
#        [5.00000000e-07, 9.99999928e-03],
#        [5.00000000e-07, 1.00000012e-02],
#        [5.00000000e-07, 1.00000007e-02],
#        [5.00000000e-07, 1.00000008e-02],
#        [5.00000000e-07, 9.99999955e-03],
#        [5.00000000e-07, 9.99999935e-03],
#        [5.00000000e-07, 9.99999999e-03],
#        [5.00000000e-07, 1.00000001e-02],
#        [5.00000000e-07, 1.00000011e-02],
#        [5.00000000e-07, 1.00000003e-02],
#        [5.00000000e-07, 9.99999956e-03],
#        [5.00000000e-07, 9.99999954e-03],
#        [5.00000000e-07, 1.00000009e-02],
#        [5.00000000e-07, 9.99999976e-03],
#        [5.00000000e-07, 1.00000009e-02],
#        [5.00000000e-07, 9.99999960e-03],
#        [5.00000000e-07, 1.00000009e-02],
#        [5.00000000e-07, 1.00000004e-02],
#        [5.00000000e-07, 9.99999987e-03],
#        [5.00000000e-07, 1.00000003e-02],
#        [5.00000000e-07, 9.99999974e-03],
#        [5.00000000e-07, 1.00000008e-02],
#        [5.00000000e-07, 1.00000008e-02],
#        [5.00000000e-07, 1.00000008e-02],
#        [5.00000000e-07, 1.00000003e-02],
#        [5.00000000e-07, 1.00000005e-02],
#        [5.00000000e-07, 1.00000007e-02],
#        [5.00000000e-07, 1.00000005e-02],
#        [5.00000000e-07, 1.00000005e-02],
#        [5.00000000e-07, 9.99999986e-03],
#        [5.00000000e-07, 9.99999990e-03],
#        [5.00000000e-07, 1.00000006e-02],
#        [5.00000000e-07, 1.00000006e-02],
#        [5.00000000e-07, 1.00000004e-02],
#        [5.00000000e-07, 1.00000002e-02],
#        [5.00000000e-07, 9.99999993e-03],
#        [5.00000000e-07, 1.00000000e-02],
#        [5.00000000e-07, 1.00000000e-02],
#        [5.00000000e-07, 1.00000003e-02]])

# %%
#columns = ["phi0_gw","psi_gw","alpha_gw","h"]
columns = ["omega_gw"]
#path = root + "alpha_small_prior_result.json"

analysis(path,columns)
# Out:
# Number of posterior samples:
# 269
# Median values:
# omega_gw          5.000000e-07
# h                 1.000000e-02
# phi0_gw           2.000000e-01
# psi_gw            2.500000e+00
# iota_gw           1.000000e+00
#                       ...
# gamma46           1.000000e-13
# sigma_p           1.000000e-08
# sigma_m           1.000000e-10
# log_likelihood   -3.490949e+04
# log_prior         1.467317e+01
# Length: 199, dtype: float64

# %%
#columns = ["phi0_gw","psi_gw","alpha_gw","h"]
columns = ["omega_gw"]
#path = root + "alpha_small_prior_result.json"

analysis(path,columns)
# Out:
# Number of posterior samples:
# 269
# Median values:
# 0    5.000000e-07
# 1    1.000000e-02
# dtype: float64
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb Cell 8 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#Y235sZmlsZQ%3D%3D?line=1'>2</a> columns = ["omega_gw"]
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#Y235sZmlsZQ%3D%3D?line=2'>3</a> #path = root + "alpha_small_prior_result.json"
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#Y235sZmlsZQ%3D%3D?line=4'>5</a> analysis(path,columns)
#
# /Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb Cell 8 in analysis(path, cols_to_plot)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#Y235sZmlsZQ%3D%3D?line=20'>21</a> print(df.median())
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#Y235sZmlsZQ%3D%3D?line=23'>24</a> y = df[0].to_numpy()
# ---> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#Y235sZmlsZQ%3D%3D?line=24'>25</a> fig = corner.corner(y,color='C0',
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#Y235sZmlsZQ%3D%3D?line=25'>26</a>                     show_titles=True,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#Y235sZmlsZQ%3D%3D?line=26'>27</a>                     smooth=True,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#Y235sZmlsZQ%3D%3D?line=27'>28</a>                     smooth1d=True,quantiles=[0.16, 0.84])
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/corner.py:256, in corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     222         logging.warning(
#     223             "Please install arviz to use the advanced features of corner"
#     224         )
#     226     return corner_impl(
#     227         data,
#     228         bins=bins,
#    (...)
#     253         **hist2d_kwargs,
#     254     )
# --> 256 return arviz_corner(
#     257     data,
#     258     bins=bins,
#     259     range=range,
#     260     weights=weights,
#     261     color=color,
#     262     hist_bin_factor=hist_bin_factor,
#     263     smooth=smooth,
#     264     smooth1d=smooth1d,
#     265     labels=labels,
#     266     label_kwargs=label_kwargs,
#     267     titles=titles,
#     268     show_titles=show_titles,
#     269     title_fmt=title_fmt,
#     270     title_kwargs=title_kwargs,
#     271     truths=truths,
#     272     truth_color=truth_color,
#     273     scale_hist=scale_hist,
#     274     quantiles=quantiles,
#     275     verbose=verbose,
#     276     fig=fig,
#     277     max_n_ticks=max_n_ticks,
#     278     top_ticks=top_ticks,
#     279     use_math_text=use_math_text,
#     280     reverse=reverse,
#     281     labelpad=labelpad,
#     282     hist_kwargs=hist_kwargs,
#     283     group=group,
#     284     var_names=var_names,
#     285     filter_vars=filter_vars,
#     286     coords=coords,
#     287     divergences=divergences,
#     288     divergences_kwargs=divergences_kwargs,
#     289     labeller=labeller,
#     290     **hist2d_kwargs,
#     291 )
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/arviz_corner.py:86, in arviz_corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#      84 is_np = True
#      85 if data.ndim == 1:
# ---> 86     data = data[None, :, :]
#      87 elif data.ndim == 2:
#      88     data = data[None, :, :]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# Opening JSON file
f = open(path)

# returns JSON object as 
# a dictionary
data = json.load(f)

#Make the posterior a dataframe
df = pd.DataFrame(data["nested_samples"]["content"])

# %%
data.keys()
# Out:
# dict_keys(['label', 'outdir', 'sampler', 'log_evidence', 'log_evidence_err', 'log_noise_evidence', 'log_bayes_factor', 'priors', 'posterior', 'injection_parameters', 'meta_data', 'search_parameter_keys', 'fixed_parameter_keys', 'constraint_parameter_keys', 'sampling_time', 'sampler_kwargs', 'use_ratio', 'information_gain', 'log_likelihood_evaluations', 'log_prior_evaluations', 'num_likelihood_evaluations', 'samples', 'nested_samples', 'parameter_labels', 'parameter_labels_with_unit', 'version'])

# %%
df
# Out:
#           omega_gw    psi_gw  alpha_gw         h       weights  log_likelihood
# 0     8.666516e-07  1.156860  0.956230  0.721126  0.000000e+00   -5.041881e+12
# 1     1.690567e-07  1.571143  1.035594  0.884207  0.000000e+00   -1.738149e+12
# 2     1.594188e-08  2.391991  0.942953  0.950463  0.000000e+00   -7.283458e+10
# 3     3.383915e-06  0.314582  1.059136  0.296277  0.000000e+00   -4.921137e+07
# 4     1.758908e-06  1.702055  1.010461  0.368672  0.000000e+00   -3.086928e+07
# ...            ...       ...       ...       ...           ...             ...
# 2397  5.005001e-07  2.512051  0.999441  0.006754  6.055749e-40   -2.288252e+04
# 2398  5.012712e-07  2.445579  0.996152  0.007771  2.607990e-39   -2.288075e+04
# 2399  4.999956e-07  2.347588  1.000028  0.009216  1.619438e-24   -2.284653e+04
# 2400  4.999965e-07  2.577021  1.000019  0.011564  1.632409e-03   -2.279817e+04
# 2401  5.012726e-07  2.455134  0.996137  0.008409  9.983676e-01   -2.279175e+04
#
# [2402 rows x 6 columns]

# %%
df2.var()
# Out:
# omega_gw          1.123250e-44
# phi0_gw           2.472114e+00
# psi_gw            6.180286e-01
# alpha_gw          1.166954e-33
# h                 1.222778e-28
#                       ...
# gamma46           1.596234e-58
# sigma_p           2.494116e-60
# sigma_m           0.000000e+00
# log_likelihood    1.921576e+00
# log_prior         1.222767e-24
# Length: 199, dtype: float64

# %%
y  = df2[["phi0_gw"]].to_numpy()#,"psi_gw","alpha_gw","delta_gw"]].to_numpy()


fig = corner.corner(y,color='C0',show_titles=True,smooth=True, smooth1d=True,quantiles=[0.16, 0.84])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb Cell 16 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> y  = df2[["phi0_gw"]].to_numpy()#,"psi_gw","alpha_gw","delta_gw"]].to_numpy()
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X40sZmlsZQ%3D%3D?line=3'>4</a> fig = corner.corner(y,color='C0',show_titles=True,smooth=True, smooth1d=True,quantiles=[0.16, 0.84])
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/corner.py:256, in corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     222         logging.warning(
#     223             "Please install arviz to use the advanced features of corner"
#     224         )
#     226     return corner_impl(
#     227         data,
#     228         bins=bins,
#    (...)
#     253         **hist2d_kwargs,
#     254     )
# --> 256 return arviz_corner(
#     257     data,
#     258     bins=bins,
#     259     range=range,
#     260     weights=weights,
#     261     color=color,
#     262     hist_bin_factor=hist_bin_factor,
#     263     smooth=smooth,
#     264     smooth1d=smooth1d,
#     265     labels=labels,
#     266     label_kwargs=label_kwargs,
#     267     titles=titles,
#     268     show_titles=show_titles,
#     269     title_fmt=title_fmt,
#     270     title_kwargs=title_kwargs,
#     271     truths=truths,
#     272     truth_color=truth_color,
#     273     scale_hist=scale_hist,
#     274     quantiles=quantiles,
#     275     verbose=verbose,
#     276     fig=fig,
#     277     max_n_ticks=max_n_ticks,
#     278     top_ticks=top_ticks,
#     279     use_math_text=use_math_text,
#     280     reverse=reverse,
#     281     labelpad=labelpad,
#     282     hist_kwargs=hist_kwargs,
#     283     group=group,
#     284     var_names=var_names,
#     285     filter_vars=filter_vars,
#     286     coords=coords,
#     287     divergences=divergences,
#     288     divergences_kwargs=divergences_kwargs,
#     289     labeller=labeller,
#     290     **hist2d_kwargs,
#     291 )
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/arviz_corner.py:136, in arviz_corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     134 # Coerce the samples into the expected format
#     135 samples = np.stack([x[-1].flatten() for x in plotters], axis=-1)
# --> 136 fig = corner_impl(
#     137     samples,
#     138     bins=bins,
#     139     range=range,
#     140     weights=weights,
#     141     color=color,
#     142     hist_bin_factor=hist_bin_factor,
#     143     smooth=smooth,
#     144     smooth1d=smooth1d,
#     145     labels=labels,
#     146     label_kwargs=label_kwargs,
#     147     titles=titles,
#     148     show_titles=show_titles,
#     149     title_fmt=title_fmt,
#     150     title_kwargs=title_kwargs,
#     151     truths=truths,
#     152     truth_color=truth_color,
#     153     scale_hist=scale_hist,
#     154     quantiles=quantiles,
#     155     verbose=verbose,
#     156     fig=fig,
#     157     max_n_ticks=max_n_ticks,
#     158     top_ticks=top_ticks,
#     159     use_math_text=use_math_text,
#     160     reverse=reverse,
#     161     labelpad=labelpad,
#     162     hist_kwargs=hist_kwargs,
#     163     **hist2d_kwargs,
#     164 )
#     166 # Get diverging draws and combine chains
#     167 if divergences:
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/core.py:121, in corner_impl(xs, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, **hist2d_kwargs)
#     119         m = np.array([e[0] == e[1] for e in range], dtype=bool)
#     120         if np.any(m):
# --> 121             raise ValueError(
#     122                 (
#     123                     "It looks like the parameter(s) in "
#     124                     "column(s) {0} have no dynamic range. "
#     125                     "Please provide a `range` argument."
#     126                 ).format(
#     127                     ", ".join(map("{0}".format, np.arange(len(m))[m]))
#     128                 )
#     129             )
#     131 else:
#     132     # If any of the extents are percentiles, convert them to ranges.
#     133     # Also make sure it's a normal list.
#     134     range = list(range)
#
# ValueError: It looks like the parameter(s) in column(s) 0 have no dynamic range. Please provide a `range` argument.

# %%
import matplotlib.pyplot as plt 
import corner
labels = [r'$\omega$', r'h']



# r'$\Phi_0$', r'$\psi$', r'$\iota$', r'$\delta$', r'$\alpha$', 'h',
#        r'$\sigma_p$']

truths = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-2,1e-8]


#truths = [3.33,3.33,3.33,3.33,3.33,3.33,3.33,3.33]
truths = [5e-7,1e-2]
axes_scale = ["log", "linear"]#,"linear","linear","linear","linear","linear","linear"]

fig = corner.corner(y,color='C0',show_titles=True,smooth=True, smooth1d=True,labels=labels,truth_color='C1',quantiles=[0.16, 0.84])


#corner.overplot_lines(fig, truths, color="C1")


#plt.savefig("../data/plots/example_corner_plot.png",dpi=300, bbox_inches = "tight")




#fig = corner.corner(y,truths=truths)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb Cell 15 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a> truths = [5e-7,1e-2]
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a> axes_scale = ["log", "linear"]#,"linear","linear","linear","linear","linear","linear"]
# ---> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a> fig = corner.corner(y,color='C0',show_titles=True,smooth=True, smooth1d=True,labels=labels,truth_color='C1',quantiles=[0.16, 0.84])
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/corner.py:256, in corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     222         logging.warning(
#     223             "Please install arviz to use the advanced features of corner"
#     224         )
#     226     return corner_impl(
#     227         data,
#     228         bins=bins,
#    (...)
#     253         **hist2d_kwargs,
#     254     )
# --> 256 return arviz_corner(
#     257     data,
#     258     bins=bins,
#     259     range=range,
#     260     weights=weights,
#     261     color=color,
#     262     hist_bin_factor=hist_bin_factor,
#     263     smooth=smooth,
#     264     smooth1d=smooth1d,
#     265     labels=labels,
#     266     label_kwargs=label_kwargs,
#     267     titles=titles,
#     268     show_titles=show_titles,
#     269     title_fmt=title_fmt,
#     270     title_kwargs=title_kwargs,
#     271     truths=truths,
#     272     truth_color=truth_color,
#     273     scale_hist=scale_hist,
#     274     quantiles=quantiles,
#     275     verbose=verbose,
#     276     fig=fig,
#     277     max_n_ticks=max_n_ticks,
#     278     top_ticks=top_ticks,
#     279     use_math_text=use_math_text,
#     280     reverse=reverse,
#     281     labelpad=labelpad,
#     282     hist_kwargs=hist_kwargs,
#     283     group=group,
#     284     var_names=var_names,
#     285     filter_vars=filter_vars,
#     286     coords=coords,
#     287     divergences=divergences,
#     288     divergences_kwargs=divergences_kwargs,
#     289     labeller=labeller,
#     290     **hist2d_kwargs,
#     291 )
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/arviz_corner.py:136, in arviz_corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     134 # Coerce the samples into the expected format
#     135 samples = np.stack([x[-1].flatten() for x in plotters], axis=-1)
# --> 136 fig = corner_impl(
#     137     samples,
#     138     bins=bins,
#     139     range=range,
#     140     weights=weights,
#     141     color=color,
#     142     hist_bin_factor=hist_bin_factor,
#     143     smooth=smooth,
#     144     smooth1d=smooth1d,
#     145     labels=labels,
#     146     label_kwargs=label_kwargs,
#     147     titles=titles,
#     148     show_titles=show_titles,
#     149     title_fmt=title_fmt,
#     150     title_kwargs=title_kwargs,
#     151     truths=truths,
#     152     truth_color=truth_color,
#     153     scale_hist=scale_hist,
#     154     quantiles=quantiles,
#     155     verbose=verbose,
#     156     fig=fig,
#     157     max_n_ticks=max_n_ticks,
#     158     top_ticks=top_ticks,
#     159     use_math_text=use_math_text,
#     160     reverse=reverse,
#     161     labelpad=labelpad,
#     162     hist_kwargs=hist_kwargs,
#     163     **hist2d_kwargs,
#     164 )
#     166 # Get diverging draws and combine chains
#     167 if divergences:
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/core.py:121, in corner_impl(xs, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, **hist2d_kwargs)
#     119         m = np.array([e[0] == e[1] for e in range], dtype=bool)
#     120         if np.any(m):
# --> 121             raise ValueError(
#     122                 (
#     123                     "It looks like the parameter(s) in "
#     124                     "column(s) {0} have no dynamic range. "
#     125                     "Please provide a `range` argument."
#     126                 ).format(
#     127                     ", ".join(map("{0}".format, np.arange(len(m))[m]))
#     128                 )
#     129             )
#     131 else:
#     132     # If any of the extents are percentiles, convert them to ranges.
#     133     # Also make sure it's a normal list.
#     134     range = list(range)
#
# ValueError: It looks like the parameter(s) in column(s) 0 have no dynamic range. Please provide a `range` argument.

# %%
import matplotlib.pyplot as plt 
import corner
import scienceplots
import json
import pandas as pd







def plot_custom_corner(path,labels, injection_parameters,axes_scales):


    # Opening JSON file
    f = open(path)
    
    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    #Make it a dataframe. Nice for surfacing
    df = pd.DataFrame(data["samples"]["content"])[[0,1,3]] # posterior
    y = df.to_numpy() 

    print(df.median())

    plt.style.use('science')

    fig = corner.corner(y,
                        color='C0',
                        show_titles=True,
                        smooth=True, 
                        smooth1d=True,
                        labels=labels,
                        truth_color='C2',
                        quantiles=[0.16, 0.84],
                        truths=injection_parameters,
                        axes_scales = axes_scales)
    

    plt.show()

# %%
labels = [r'$\omega$', r'h',r'd',r'd']
injection_parameters = [5e-7,1e-2,3.23622243e+10]
axes_scales = ["log", "linear"]
#path = "../data/nested_sampling/diagonal55_result.json"
path = "../data/nested_sampling/original_params_result.json"
plot_custom_corner(path,labels, injection_parameters,axes_scales)
# Out:
# 0    5.000000e-07
# 1    3.341593e+00
# 3    1.000000e-02
# dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb Cell 18 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> #path = "../data/nested_sampling/diagonal55_result.json"
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> path = "../data/nested_sampling/original_params_result.json"
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> plot_custom_corner(path,labels, injection_parameters,axes_scales)
#
# /Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb Cell 18 in plot_custom_corner(path, labels, injection_parameters, axes_scales)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=26'>27</a> print(df.median())
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=28'>29</a> plt.style.use('science')
# ---> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=30'>31</a> fig = corner.corner(y,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=31'>32</a>                     color='C0',
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=32'>33</a>                     show_titles=True,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=33'>34</a>                     smooth=True,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=34'>35</a>                     smooth1d=True,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=35'>36</a>                     labels=labels,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=36'>37</a>                     truth_color='C2',
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=37'>38</a>                     quantiles=[0.16, 0.84],
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=38'>39</a>                     truths=injection_parameters,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=39'>40</a>                     axes_scales = axes_scales)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X14sZmlsZQ%3D%3D?line=42'>43</a> plt.show()
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/corner.py:256, in corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     222         logging.warning(
#     223             "Please install arviz to use the advanced features of corner"
#     224         )
#     226     return corner_impl(
#     227         data,
#     228         bins=bins,
#    (...)
#     253         **hist2d_kwargs,
#     254     )
# --> 256 return arviz_corner(
#     257     data,
#     258     bins=bins,
#     259     range=range,
#     260     weights=weights,
#     261     color=color,
#     262     hist_bin_factor=hist_bin_factor,
#     263     smooth=smooth,
#     264     smooth1d=smooth1d,
#     265     labels=labels,
#     266     label_kwargs=label_kwargs,
#     267     titles=titles,
#     268     show_titles=show_titles,
#     269     title_fmt=title_fmt,
#     270     title_kwargs=title_kwargs,
#     271     truths=truths,
#     272     truth_color=truth_color,
#     273     scale_hist=scale_hist,
#     274     quantiles=quantiles,
#     275     verbose=verbose,
#     276     fig=fig,
#     277     max_n_ticks=max_n_ticks,
#     278     top_ticks=top_ticks,
#     279     use_math_text=use_math_text,
#     280     reverse=reverse,
#     281     labelpad=labelpad,
#     282     hist_kwargs=hist_kwargs,
#     283     group=group,
#     284     var_names=var_names,
#     285     filter_vars=filter_vars,
#     286     coords=coords,
#     287     divergences=divergences,
#     288     divergences_kwargs=divergences_kwargs,
#     289     labeller=labeller,
#     290     **hist2d_kwargs,
#     291 )
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/arviz_corner.py:136, in arviz_corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     134 # Coerce the samples into the expected format
#     135 samples = np.stack([x[-1].flatten() for x in plotters], axis=-1)
# --> 136 fig = corner_impl(
#     137     samples,
#     138     bins=bins,
#     139     range=range,
#     140     weights=weights,
#     141     color=color,
#     142     hist_bin_factor=hist_bin_factor,
#     143     smooth=smooth,
#     144     smooth1d=smooth1d,
#     145     labels=labels,
#     146     label_kwargs=label_kwargs,
#     147     titles=titles,
#     148     show_titles=show_titles,
#     149     title_fmt=title_fmt,
#     150     title_kwargs=title_kwargs,
#     151     truths=truths,
#     152     truth_color=truth_color,
#     153     scale_hist=scale_hist,
#     154     quantiles=quantiles,
#     155     verbose=verbose,
#     156     fig=fig,
#     157     max_n_ticks=max_n_ticks,
#     158     top_ticks=top_ticks,
#     159     use_math_text=use_math_text,
#     160     reverse=reverse,
#     161     labelpad=labelpad,
#     162     hist_kwargs=hist_kwargs,
#     163     **hist2d_kwargs,
#     164 )
#     166 # Get diverging draws and combine chains
#     167 if divergences:
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/core.py:121, in corner_impl(xs, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, **hist2d_kwargs)
#     119         m = np.array([e[0] == e[1] for e in range], dtype=bool)
#     120         if np.any(m):
# --> 121             raise ValueError(
#     122                 (
#     123                     "It looks like the parameter(s) in "
#     124                     "column(s) {0} have no dynamic range. "
#     125                     "Please provide a `range` argument."
#     126                 ).format(
#     127                     ", ".join(map("{0}".format, np.arange(len(m))[m]))
#     128                 )
#     129             )
#     131 else:
#     132     # If any of the extents are percentiles, convert them to ranges.
#     133     # Also make sure it's a normal list.
#     134     range = list(range)
#
# ValueError: It looks like the parameter(s) in column(s) 0 have no dynamic range. Please provide a `range` argument.

# %%
# r'$\Phi_0$', r'$\psi$', r'$\iota$', r'$\delta$', r'$\alpha$', 'h',
#        r'$\sigma_p$']

truths = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-2,1e-8]


#truths = [3.33,3.33,3.33,3.33,3.33,3.33,3.33,3.33]
#,"linear","linear","linear","linear","linear","linear"]



axes = fig.get_axes()



for ax in axes:
    print(ax)
axes[0].set_xlim(1e-9,1e-6)
#axes[1].set_xlim(1e-9,1e-6)
axes[2].set_xlim(1e-9,1e-6)



#corner.overplot_lines(fig, truths, color="C1")


#plt.savefig("../data/plots/example_corner_plot.png",dpi=300, bbox_inches = "tight")




#fig = corner.corner(y,truths=truths)
# Out:
# AxesSubplot(0.181818,0.563636;0.363636x0.363636)
# AxesSubplot(0.563636,0.563636;0.363636x0.363636)
# AxesSubplot(0.181818,0.181818;0.363636x0.363636)
# AxesSubplot(0.563636,0.181818;0.363636x0.363636)
# (1e-09, 1e-06)

# %%
import matplotlib.pyplot as plt 
import corner
labels = [r'$\omega$', r'h']



# r'$\Phi_0$', r'$\psi$', r'$\iota$', r'$\delta$', r'$\alpha$', 'h',
#        r'$\sigma_p$']

truths = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-2,1e-8]


#truths = [3.33,3.33,3.33,3.33,3.33,3.33,3.33,3.33]
truths = [5e-7,1e-2]
axes_scale = ["log", "linear"]#,"linear","linear","linear","linear","linear","linear"]

fig = corner.corner(y,color='C0',show_titles=True,smooth=True, smooth1d=True,labels=labels,truth_color='C1',quantiles=[0.16, 0.84],truths=truths)





#corner.overplot_lines(fig, truths, color="C1")


#plt.savefig("../data/plots/example_corner_plot.png",dpi=300, bbox_inches = "tight")




#fig = corner.corner(y,truths=truths)

# %%
samples = result.posterior.to_numpy()[:, :7].copy()


samples[:, 0:7] = np.log10(samples[:, 0:7])

labels = ['$log_{10} \\gamma_{\\Omega}$ $[\\rm{s^{-1}}]$', '$log_{10} \\gamma_{Q}$ $[\\rm{s^{-1}}]$', '$log_{10} \\gamma_{S}$ $[\\rm{s^{-1}}]$', '$log_{10} \\gamma_{\\eta}$  $[\\rm{s^{-1}}]$',
                  '$log_{10} \\sigma_{Q}$  $[\\rm{s^{-1/2}}]$', '$log_{10} \\sigma_{S}$  $[\\rm{s^{-1/2}}]$', '$log_{10} \\sigma_{\\eta}$  $[\\rm{s^{-1/2}}]$']

fig = corner(samples, truths=[np.log10(gamma_omega), np.log10(gamma_Q), np.log10(gamma_S), np.log10(gamma_eta), np.log10(sigma_Q), np.log10(sigma_S), np.log10(sigma_eta)],
                     range = [(-14, -8), (-8, -5), (-8, -5), (-8, -5), (-8, -3), (-8, -3), (-8, -3)],
                     color='b', smooth=True, smooth1d=True, levels=[1-np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9/2)])

axarr = np.reshape(fig.axes, (len(labels), len(labels)))
for ii, label in enumerate(labels):
            axarr[ii,ii].set_title(label, fontsize=18)
            axarr[ii,0].yaxis.set_tick_params(labelsize=15)


            
for ax in axarr[-1, :]:
            ax.xaxis.set_tick_params(labelsize=14)
# Out:
# {'mass_1': 36.0,
#  'mass_2': 29.0,
#  'a_1': 0.4,
#  'a_2': 0.3,
#  'tilt_1': 0.5,
#  'tilt_2': 1.0,
#  'phi_12': 1.7,
#  'phi_jl': 0.3,
#  'luminosity_distance': 2000.0,
#  'theta_jn': 0.4,
#  'psi': 2.659,
#  'phase': 1.3,
#  'geocent_time': 1126259642.413,
#  'ra': 1.375,
#  'dec': -1.2108}

# %%
import numpy as np
import corner 
ndim, nsamples = 2, 10000
np.random.seed(42)
samples = np.random.randn(ndim * nsamples).reshape([nsamples, ndim])

# %%
ndim, nsamples = 2, 10000
np.random.seed(42)
samples = np.random.randn(ndim * nsamples).reshape([nsamples, ndim])
figure = corner.corner(samples)

# %%
labels = ['$log_{10} \\gamma_{\\Omega}$ $[\\rm{s^{-1}}]$', '$log_{10} \\gamma_{Q}$ $[\\rm{s^{-1}}]$', '$log_{10} \\gamma_{S}$ $[\\rm{s^{-1}}]$', '$log_{10} \\gamma_{\\eta}$  $[\\rm{s^{-1}}]$',
                  '$log_{10} \\sigma_{Q}$  $[\\rm{s^{-1/2}}]$', '$log_{10} \\sigma_{S}$  $[\\rm{s^{-1/2}}]$', '$log_{10} \\sigma_{\\eta}$  $[\\rm{s^{-1/2}}]$']


for ii, label in enumerate(labels):
            print(ii, label)
# Out:
# 0 $log_{10} \gamma_{\Omega}$ $[\rm{s^{-1}}]$
# 1 $log_{10} \gamma_{Q}$ $[\rm{s^{-1}}]$
# 2 $log_{10} \gamma_{S}$ $[\rm{s^{-1}}]$
# 3 $log_{10} \gamma_{\eta}$  $[\rm{s^{-1}}]$
# 4 $log_{10} \sigma_{Q}$  $[\rm{s^{-1/2}}]$
# 5 $log_{10} \sigma_{S}$  $[\rm{s^{-1/2}}]$
# 6 $log_{10} \sigma_{\eta}$  $[\rm{s^{-1/2}}]$

# %%
import pickle

# open a file, where you stored the pickled data
file = open('../data/nested_sampling/all_bar_one_resume2.pickle', 'rb')

# dump information to that file
data = pickle.load(file)

# %%
data

# %%
import bilby

# %%
sampler = bilby.sampler.restore(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb Cell 28 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/corner_plots.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> sampler = bilby.sampler.restore(data)
#
# AttributeError: module 'bilby.core.sampler' has no attribute 'restore'

# %%
injection_parameters = dict(
    omega_gw=5e-7,
    phi0_gw=0.20,
    psi_gw=2.50,
    iota_gw=1.0,
    delta_gw=1.0,
    alpha_gw=1.0,
    h=1e-2,
    f0=327.8470205611185,
    fdot=-1.227834e-15,
    distance=181816860005.41092,
    gamma=1e-13,
    sigma_p=1e-8,
    sigma_m=1e-08
)

# %%
import json 
import pandas as pd 

path = "../data/nested_sampling/MCMC_unthinned_result.json"
f = open(path)

# returns JSON object as 
# a dictionary
data = json.load(f)

#Make it a dataframe. Nice for surfacing
df_posterior = pd.DataFrame(data["posterior"]["content"]) # posterior
df_samples = pd.DataFrame(data["samples"]["content"]) # posterior

y_post = df_posterior.to_numpy() 
y_samp = df_samples.to_numpy()

# %%
df_posterior.median()
# Out:
# omega_gw          4.983760e-07
# phi0_gw           1.705454e-01
# psi_gw            2.567028e+00
# iota_gw           7.969900e-01
# delta_gw          9.951309e-01
#                       ...
# gamma46           1.000000e-13
# sigma_p           1.000000e-03
# sigma_m           1.000000e-10
# log_likelihood   -2.284779e+04
# log_prior         1.078486e+01
# Length: 199, dtype: float64

# %%
y_post = df_posterior[["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]].to_numpy()

# %%
y_post.shape
# Out:
# (1800, 7)

# %%
import matplotlib.pyplot as plt 
import corner
#ranges = [(4.9e-7,5.1e-7),(0.10,0.30),(2.0,3.0),(0.5,1.5),(0.5,1.5),(0.5,1.5),(1e-3,2e-2)]
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-2]
labels = [r'$\omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'h']


import scienceplots

plt.style.use('science')


fig = corner.corner(y_post,
                        color='C0',
                        show_titles=True,
                        smooth=True, 
                        smooth1d=True,
                        #range=ranges,
                        truth_color='C2',
                        quantiles=[0.16, 0.84],
                        truths = injection_parameters,
                        labels = labels,
                        label_kwargs=dict(fontsize=16)
                        )

# %% [markdown]
# samples = result.samples
# labels = result.parameter_labels
# fig = corner.corner(samples, labels=labels)
# plt.show()
# plt.close()
