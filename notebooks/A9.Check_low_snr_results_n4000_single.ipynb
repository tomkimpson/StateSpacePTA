# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
import numpy as np 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %% [markdown]
# # Low SNR, pulsar terms

# %%
import glob 
from plotting import stacked_corner


#default values of GW parameters
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(1e-15,9e-15)]


#ranges = None
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-15]
labels = [r'$10^9 \Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$10^{15} h_0$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None

list_of_files = sorted(glob.glob('/Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/*_pulsar_5e-15*')) #all the low snr pulsar results

#or select manually
#idx = 10
#list_of_files = list_of_files[idx:idx+10]
#list_of_files = ['/Users/t1/github_repos/StateSpacePTA/data/nested_sampling/compressed_files/bigrun_pulsar_5e-15_1300']

number_of_files_to_plot = len(list_of_files)
print("Plotting this many files:", number_of_files_to_plot)
#Corner plot of GW parameters
fig = stacked_corner(list_of_files,
                   number_of_files_to_plot,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e15], #the scalings for omega and h
                   savefig='corner_lowSNR',
                   smooth=True,smooth1d=True)
# Out:
# Plotting this many files: 10
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1245_result.json
# The evidence is: 585626.8693281981
# The number of samples is: 45064
# Variable/Injection/Median
# omega_gw 500.0 498.14570100661234
# phi0_gw 0.2 0.28377519150300556
# psi_gw 2.5 2.3730241904384384
# iota_gw 1.0 0.843907279075994
# delta_gw 1.0 0.7601367749008556
# alpha_gw 1.0 0.8184252133863148
# h 5.0 3.6759533174192773
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1246_result.json
# The evidence is: 585765.9461231711
# The number of samples is: 38912
# Variable/Injection/Median
# omega_gw 500.0 501.3586643289575
# phi0_gw 0.2 0.42440125103200244
# psi_gw 2.5 2.506261198194723
# iota_gw 1.0 0.8469186802309028
# delta_gw 1.0 0.9168072719904254
# alpha_gw 1.0 1.0278774724483482
# h 5.0 4.065672192773869
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1247_result.json
# The evidence is: 585866.8389987113
# The number of samples is: 50030
# Variable/Injection/Median
# omega_gw 500.0 501.435516446836
# phi0_gw 0.2 0.4264110749581579
# psi_gw 2.5 2.420527081977317
# iota_gw 1.0 0.7894100263179911
# delta_gw 1.0 0.9414963364994814
# alpha_gw 1.0 0.9914256390699934
# h 5.0 3.6235125133523334
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 2
# debug: 1 2
# debug: 2 2
# debug: 3 2
# debug: 4 2
# debug: 5 2
# debug: 6 2
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1248_result.json
# The evidence is: 585888.1990550649
# The number of samples is: 38457
# Variable/Injection/Median
# omega_gw 500.0 500.320685859724
# phi0_gw 0.2 0.26309637961702786
# psi_gw 2.5 2.5345602193006442
# iota_gw 1.0 0.68780446388028
# delta_gw 1.0 0.9727871852995247
# alpha_gw 1.0 1.080969592036336
# h 5.0 3.7087135734521124
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 3
# debug: 1 3
# debug: 2 3
# debug: 3 3
# debug: 4 3
# debug: 5 3
# debug: 6 3
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1249_result.json
# The evidence is: 585644.1287139625
# The number of samples is: 46803
# Variable/Injection/Median
# omega_gw 500.0 500.2824950753109
# phi0_gw 0.2 0.2032357050653927
# psi_gw 2.5 2.4327747268804982
# iota_gw 1.0 0.6409228596042351
# delta_gw 1.0 0.9269426914472626
# alpha_gw 1.0 0.9550195751360755
# h 5.0 3.681441637824831
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 4
# debug: 1 4
# debug: 2 4
# debug: 3 4
# debug: 4 4
# debug: 5 4
# debug: 6 4
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1250_result.json
# The evidence is: 585608.7850820199
# The number of samples is: 46447
# Variable/Injection/Median
# omega_gw 500.0 501.46003675731293
# phi0_gw 0.2 0.6595061257001771
# psi_gw 2.5 2.420264248970179
# iota_gw 1.0 0.7084289318449848
# delta_gw 1.0 0.9827985140935148
# alpha_gw 1.0 0.8612986523187093
# h 5.0 4.689317399860146
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 5
# debug: 1 5
# debug: 2 5
# debug: 3 5
# debug: 4 5
# debug: 5 5
# debug: 6 5
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1251_result.json
# The evidence is: 585758.9636884384
# The number of samples is: 38285
# Variable/Injection/Median
# omega_gw 500.0 500.7237170651522
# phi0_gw 0.2 0.26600017127435965
# psi_gw 2.5 2.471772999235141
# iota_gw 1.0 0.7950068211253601
# delta_gw 1.0 0.9580302110497956
# alpha_gw 1.0 0.9966614532628213
# h 5.0 4.186472241689222
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 6
# debug: 1 6
# debug: 2 6
# debug: 3 6
# debug: 4 6
# debug: 5 6
# debug: 6 6
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1252_result.json
# The evidence is: 585650.2341615688
# The number of samples is: 38485
# Variable/Injection/Median
# omega_gw 500.0 501.4527878405442
# phi0_gw 0.2 0.5105006619867697
# psi_gw 2.5 2.680395724510336
# iota_gw 1.0 0.993672713934619
# delta_gw 1.0 0.973894529450716
# alpha_gw 1.0 1.0927701572560855
# h 5.0 5.176247099318136
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 7
# debug: 1 7
# debug: 2 7
# debug: 3 7
# debug: 4 7
# debug: 5 7
# debug: 6 7
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1253_result.json
# The evidence is: 585763.5220743595
# The number of samples is: 38617
# Variable/Injection/Median
# omega_gw 500.0 501.02240404693663
# phi0_gw 0.2 0.13547596716495183
# psi_gw 2.5 2.4634798437701204
# iota_gw 1.0 0.9828230175940559
# delta_gw 1.0 0.9957065447991739
# alpha_gw 1.0 0.9745575982675488
# h 5.0 4.547062414211011
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 8
# debug: 1 8
# debug: 2 8
# debug: 3 8
# debug: 4 8
# debug: 5 8
# debug: 6 8
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1254_result.json
# The evidence is: 585654.9979617934
# The number of samples is: 43584
# Variable/Injection/Median
# omega_gw 500.0 499.63257911916446
# phi0_gw 0.2 0.1429910140118329
# psi_gw 2.5 2.4204436761039445
# iota_gw 1.0 0.9808677237462303
# delta_gw 1.0 0.8240884853521193
# alpha_gw 1.0 0.8235122793225369
# h 5.0 4.460770440278799
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 9
# debug: 1 9
# debug: 2 9
# debug: 3 9
# debug: 4 9
# debug: 5 9
# debug: 6 9
# Surfacing numbers for comparing two posteriors
# The RMSRE is:
