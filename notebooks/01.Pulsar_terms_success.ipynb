# %% [markdown]
# # Second attempt at pulsar terms
#
#
# This notebook is our second attempt at generating posteriors including the pulsar terms.
#
# It used the method from Eric/Tong/Jackie (ETJ)
#
# ---

# %% [markdown]
# First load everything:

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import json 
import pandas as pd 
import numpy as np 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %% [markdown]
# Now plot the result from a single run:

# %%
from plotting import plot_custom_corner


#default values of GW parameters
#ranges=[(4e-7,6e-7),(0.5,1.5),(1.2,2.6),(0.4,1.6),(0.8,1.2),(0.2,1.5),(3e-15,7e-15)]
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(2e-15,7e-15)]



injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-15]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
#ranges = None
path = '../data/nested_sampling/results/ETJ_5e15_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e15], #the scalings for omega and h
                   savefig=None,
                   smooth=True,smooth1d=True)
# Out:
# The evidence is: 585703.3301431705
# The number of samples is: 10574
# Variable/Injection/Median
# omega_gw 500.0 500.4573211749123
# phi0_gw 0.2 0.20003951912570755
# psi_gw 2.5 2.460247950595992
# iota_gw 1.0 0.6949203316193573
# delta_gw 1.0 0.9506490529642893
# alpha_gw 1.0 0.926582386307305
# h 5.0 3.460213092137367
# -------------------------------

# %% [markdown]
# # Try again! Now $n_{\rm live} = 2000$ and dlogz=0.1

# %%
from plotting import plot_custom_corner


#default values of GW parameters
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(2e-15,7e-15)]

injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-15]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
#ranges = None
path = '../data/nested_sampling/results/ETJ_n2000_5e15_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e15], #the scalings for omega and h
                   savefig=None,
                   smooth=True,smooth1d=True)
# Out:
# The evidence is: 585701.9627389061
# The number of samples is: 19738
# Variable/Injection/Median
# omega_gw 500.0 500.7009308769158
# phi0_gw 0.2 0.27312315311914603
# psi_gw 2.5 2.44815310936689
# iota_gw 1.0 0.7422519867296646
# delta_gw 1.0 0.9302784755226079
# alpha_gw 1.0 0.911410603221577
# h 5.0 3.3147050244700282
# -------------------------------
