# %% [markdown]
# # This notebook holds all the plots used in the manuscript

# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
import numpy as np 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %% [markdown]
# # 1250

# %%
import glob 
from plotting import stacked_corner


#default values of GW parameters
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5e-12,1.5e-12)]
ranges=[(4.95e-7,5.05e-7),(0.19,0.21),(2.30,2.70),(-0.2,np.pi/2),(0.5,1.5),(0.90,1.10),(0.5e-12,1.5e-12)]

#ranges = None
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-12]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
#ranges = None
#list_of_files = glob.glob('../data/clean/rsync_folder/*.json')

list_of_files = ['../data/compressed_files/piglet_earth_1e-12_1250','../data/compressed_files/piglet_pulsar_1e-12_1250']






number_of_files_to_plot = len(list_of_files)
#Corner plot of GW parameters
fig = stacked_corner(list_of_files,
                   number_of_files_to_plot,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e12], #the scalings for omega and h
                   savefig='corner_highSNR_compare',
                   smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/compressed_files/piglet_earth_1e-12_1250
# The number of samples is: 8841
# Variable/Injection/Median
# omega_gw 500.0 500.004041967123
# phi0_gw 0.2 0.19626644171507654
# psi_gw 2.5 2.5966705714863667
# iota_gw 1.0 0.8636090714990268
# delta_gw 1.0 1.002258392939293
# alpha_gw 1.0 1.0397812442595074
# h 1.0 1.1424029333913837
# -------------------------------
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.1090944602015124e-05 0.006889314547422235
# $\Phi_0$ 0.01858608860278034 0.0038544443508622657
# $\psi$ 0.03867217595210753 0.09668157249034694
# $\iota$ 0.3178512152579358 0.39960587897564226
# $\delta$ 0.0022552936875288106 0.002270464340083989
# $\alpha$ 0.039792998844519055 0.03979478180824972
# $h_{0, \times 10}$ 0.21805327984316783 0.2652845944773666
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/compressed_files/piglet_pulsar_1e-12_1250
# The number of samples is: 19805
# Variable/Injection/Median
# omega_gw 500.0 500.0077533972135
# phi0_gw 0.2 0.20178090203773766
# psi_gw 2.5 2.500654005248476
# iota_gw 1.0 0.7816141118639699
# delta_gw 1.0 1.0002262237071413
# alpha_gw 1.0 1.000579231828392
# h 1.0 0.8599926676409868
# -------------------------------
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.565937599731728e-05 0.008691168423542502
# $\Phi_0$ 0.009112774994051945 0.00206786811694013
# $\psi$ 0.00027212506103283505 0.0007834674594561638
# $\iota$ 0.2097217696184602 0.24461938850668175
# $\delta$ 0.00025545661194003124 0.0003062359736901547
# $\alpha$ 0.0005960093655029064 0.0006755741236215475
# $h_{0, \times 10}$ 0.1297695619573568 0.14876503738552838
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.11e-05 1.57e-05 4.57e-06
# 0.0186 0.00911 -0.00947
# 0.0387 0.000272 -0.0384
# 0.318 0.21 -0.108
# 0.00226 0.000255 -0.002
# 0.0398 0.000596 -0.0392
# 0.218 0.13 -0.0883

# %% [markdown]
# # 1251

# %%
import glob 
from plotting import stacked_corner


#default values of GW parameters
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5e-12,1.5e-12)]
ranges=[(4.95e-7,5.05e-7),(0.19,0.21),(2.30,2.70),(-0.2,np.pi/2),(0.5,1.5),(0.90,1.10),(0.5e-12,1.5e-12)]

#ranges = None
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-12]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
#ranges = None
#list_of_files = glob.glob('../data/clean/rsync_folder/*.json')

list_of_files = ['../data/compressed_files/piglet_earth_1e-12_1251','../data/compressed_files/piglet_pulsar_1e-12_1251']






number_of_files_to_plot = len(list_of_files)
#Corner plot of GW parameters
fig = stacked_corner(list_of_files,
                   number_of_files_to_plot,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e12], #the scalings for omega and h
                   savefig='corner_highSNR_compare',
                   smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/compressed_files/piglet_earth_1e-12_1251
# The number of samples is: 8677
# Variable/Injection/Median
# omega_gw 500.0 500.00939954618195
# phi0_gw 0.2 0.19690393217341692
# psi_gw 2.5 2.59670960355227
# iota_gw 1.0 0.7292581102599137
# delta_gw 1.0 1.0017864222596766
# alpha_gw 1.0 1.0402100334409012
# h 1.0 1.0432013305726675
# -------------------------------
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.909857682006237e-05 0.010802895258804667
# $\Phi_0$ 0.01570938213312426 0.003287163955821905
# $\psi$ 0.03869289855901024 0.0967332884957155
# $\iota$ 0.30987663987065217 0.3615676285579588
# $\delta$ 0.0017994992741050197 0.0018179409637449479
# $\alpha$ 0.04021428981436481 0.04021585541605146
# $h_{0, \times 10}$ 0.125364016169376 0.1698754090899139
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/compressed_files/piglet_pulsar_1e-12_1251
# The number of samples is: 19540
# Variable/Injection/Median
# omega_gw 500.0 500.00078419843004
# phi0_gw 0.2 0.1993521294029345
# psi_gw 2.5 2.4995224095438084
# iota_gw 1.0 0.6553809209643786
# delta_gw 1.0 0.9997972221781936
# alpha_gw 1.0 0.9996925840708059
# h 1.0 0.7933522055366796
# -------------------------------
# The error in the 1D posteriors is as follows:
# $\Omega$ 6.491182419072464e-06 0.004079807726481438
# $\Phi_0$ 0.00504881797110736 0.0012618117527296029
# $\psi$ 0.0002130414751861152 0.0006382511287549134
# $\iota$ 0.34963473436205333 0.35627925034318325
# $\delta$ 0.00023325654963746455 0.0002818291614379875
# $\alpha$ 0.00037668572921887374 0.00046126413035008356
# $h_{0, \times 10}$ 0.207106869397929 0.20952006116395575
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.91e-05 6.49e-06 -1.26e-05
# 0.0157 0.00505 -0.0107
# 0.0387 0.000213 -0.0385
# 0.31 0.35 0.0398
# 0.0018 0.000233 -0.00157
# 0.0402 0.000377 -0.0398
# 0.125 0.207 0.0817

# %% [markdown]
# # 1251 - v2 repro

# %%
import glob 
from plotting import stacked_corner


#default values of GW parameters
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5e-12,1.5e-12)]
ranges=[(4.95e-7,5.05e-7),(0.19,0.21),(2.30,2.70),(-0.2,np.pi/2),(0.5,1.5),(0.90,1.10),(0.5e-12,1.5e-12)]

#ranges = None
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-12]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
#ranges = None
#list_of_files = glob.glob('../data/clean/rsync_folder/*.json')

list_of_files = ['../data/reproduce_canonical_v2/V2reproduce_eg_canonical_earth_1e-12_1251_result.json','../data/reproduce_canonical_v2/V2reproduce_eg_canonical_pulsar_1e-12_1251_result.json']




number_of_files_to_plot = len(list_of_files)
#Corner plot of GW parameters
fig = stacked_corner(list_of_files,
                   number_of_files_to_plot,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e12], #the scalings for omega and h
                   savefig='corner_highSNR_compare',
                   smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/reproduce_canonical_v2/V2reproduce_eg_canonical_earth_1e-12_1251_result.json
# The evidence is: -555432.8404280659
# The number of samples is: 4254
# Variable/Injection/Median
# omega_gw 500.0 500.00798394548804
# phi0_gw 0.2 0.19656438391485703
# psi_gw 2.5 2.5966972356498017
# iota_gw 1.0 0.7981684472440367
# delta_gw 1.0 1.0018005235641292
# alpha_gw 1.0 1.0402104292806724
# h 1.0 1.0917064136726875
# -------------------------------
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.6865120762333847e-05 0.009754946026054782
# $\Phi_0$ 0.01687993976599312 0.0035248694903660103
# $\psi$ 0.038684280030837216 0.09671164048222994
# $\iota$ 0.24885608719794017 0.30282647130973794
# $\delta$ 0.0018078632033843123 0.0018234214720219129
# $\alpha$ 0.040211877964728894 0.04021335068192146
# $h_{0, \times 10}$ 0.14827910743777142 0.1901431462512459
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/reproduce_canonical_v2/V2reproduce_eg_canonical_pulsar_1e-12_1251_result.json
# The evidence is: 585590.8589979615
# The number of samples is: 10406
# Variable/Injection/Median
# omega_gw 500.0 500.00117433047853
# phi0_gw 0.2 0.19950447542541344
# psi_gw 2.5 2.499508320110772
# iota_gw 1.0 1.225734336545061
# delta_gw 1.0 0.9998256108511591
# alpha_gw 1.0 0.9996377060333148
# h 1.0 1.1593067165807631
# -------------------------------
# The error in the 1D posteriors is as follows:
# $\Omega$ 6.327853403973484e-06 0.003969873264247615
# $\Phi_0$ 0.004467485659254753 0.0011137532670244855
# $\psi$ 0.0002152080520347933 0.0006406301163088759
# $\iota$ 0.20915992363593378 0.23111379418016378
# $\delta$ 0.00021406770769928594 0.0002617948303499549
# $\alpha$ 0.00040772902423504557 0.0004907333668972858
# $h_{0, \times 10}$ 0.14494607924910421 0.15918505604411762
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.69e-05 6.33e-06 -1.05e-05
# 0.0169 0.00447 -0.0124
# 0.0387 0.000215 -0.0385
# 0.249 0.209 -0.0397
# 0.00181 0.000214 -0.00159
# 0.0402 0.000408 -0.0398
# 0.148 0.145 -0.00333

# %% [markdown]
# # 1252

# %%
import glob 
from plotting import stacked_corner


#default values of GW parameters
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5e-12,1.5e-12)]
ranges=[(4.95e-7,5.05e-7),(0.19,0.21),(2.30,2.70),(-0.2,np.pi/2),(0.5,1.5),(0.90,1.10),(0.5e-12,1.5e-12)]

#ranges = None
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-12]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
#ranges = None
#list_of_files = glob.glob('../data/clean/rsync_folder/*.json')

list_of_files = ['../data/compressed_files/piglet_earth_1e-12_1252','../data/compressed_files/piglet_pulsar_1e-12_1252']






number_of_files_to_plot = len(list_of_files)
#Corner plot of GW parameters
fig = stacked_corner(list_of_files,
                   number_of_files_to_plot,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e12], #the scalings for omega and h
                   savefig='corner_highSNR_compare',
                   smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/compressed_files/piglet_earth_1e-12_1252
# The number of samples is: 8651
# Variable/Injection/Median
# omega_gw 500.0 499.99838414985777
# phi0_gw 0.2 0.19549064594388468
# psi_gw 2.5 2.5979094574136594
# iota_gw 1.0 0.9110127637625435
# delta_gw 1.0 1.0026952316888984
# alpha_gw 1.0 1.04104241764117
# h 1.0 1.1814615435441922
# -------------------------------
# The error in the 1D posteriors is as follows:
# $\Omega$ 9.137797787276697e-06 0.00568849593063648
# $\Phi_0$ 0.022511454481857516 0.004615601944948096
# $\psi$ 0.03915326320736052 0.09788416827473616
# $\iota$ 0.220043147200234 0.2748188888169542
# $\delta$ 0.00268634091074865 0.002698495957153837
# $\alpha$ 0.04103104521270168 0.04103254914070027
# $h_{0, \times 10}$ 0.2179901971012715 0.2685271173827492
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/compressed_files/piglet_pulsar_1e-12_1252
# The number of samples is: 20666
# Variable/Injection/Median
# omega_gw 500.0 500.00196141909873
# phi0_gw 0.2 0.20076911929739602
# psi_gw 2.5 2.5009532935138123
# iota_gw 1.0 0.6536691668418871
# delta_gw 1.0 1.0000416226725255
# alpha_gw 1.0 1.00029153449759
# h 1.0 0.792793574006492
# -------------------------------
# The error in the 1D posteriors is as follows:
# $\Omega$ 7.07096173083126e-06 0.004470957634161086
# $\Phi_0$ 0.005388434940644113 0.001335160022518
# $\psi$ 0.00038082800857574525 0.0010361373171433503
# $\iota$ 0.34112226820624236 0.34851614394368485
# $\delta$ 0.0001541085697379573 0.00019408318930333343
# $\alpha$ 0.0003690722143860567 0.0004523843791734722
# $h_{0, \times 10}$ 0.20269908036972167 0.205571638215077
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 9.14e-06 7.07e-06 -2.07e-06
# 0.0225 0.00539 -0.0171
# 0.0392 0.000381 -0.0388
# 0.22 0.341 0.121
# 0.00269 0.000154 -0.00253
# 0.041 0.000369 -0.0407
# 0.218 0.203 -0.0153

# %% [markdown]
# # 1252
