# %% [markdown]
# # These are some plots where h was a small value = 4 x 10^-15

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %%
import matplotlib.pyplot as plt 
from priors import priors_dict
import numpy as np 
import json
import pandas as pd 
import corner
import scienceplots

def load_data(path,variables_to_plot):


    try:
        df_posterior = pd.read_parquet(path)  

    except:
        # Opening JSON file
        f = open(path)
        data = json.load(f)
        f.close()
        #Make it a dataframe. 
        df_posterior = pd.DataFrame(data["posterior"]["content"]) 


    #Make omega into nHz
    df_posterior["omega_gw"] = df_posterior["omega_gw"]*1e9
    df_posterior["h"] = df_posterior["h"]*1e12

    y_post = df_posterior[variables_to_plot].to_numpy()

    # print("Number of samples:",len(df_posterior))
    # print("Truths/Medians/Variances")
    medians = df_posterior[variables_to_plot].median()
    variances = df_posterior[variables_to_plot].var()
    q = [0.00,1.00]
    for i in range(len(medians)):
        print(variables_to_plot[i],medians[i],variances[i])
        print("quantiles:", np.quantile(df_posterior[variables_to_plot[i]],q))
    



    return_code = 0


    extra_median = df_posterior['psi_gw'].median()
    #if extra_median < 1.0: #psi is weird / not converged so don't plot it 
       # print("Ignoring this file since psi not converged",extra_median)
       # return_code = 1
        
    print('-----------------------------***********************----------------------')
    return y_post, return_code







from parse import * 


def drop_braces(string_object):

    string_object = string_object.replace('{', '')
    string_object = string_object.replace('}', '')
    return string_object


def extract_value_from_title(title_string):

    template = '$\\{param_name}$ = ${value}_{lower}^{upper}$'

    parsed_output = parse(template, title_string)

    if parsed_output is None: #Handles h which is not a greek letter
        template = '${param_name}$ = ${value}_{lower}^{upper}$'
        parsed_output = parse(template, title_string)



    

    return parsed_output['param_name'],drop_braces(parsed_output['value']),drop_braces(parsed_output['lower']),drop_braces(parsed_output['upper'])

#https://stackoverflow.com/questions/32923605/is-there-a-way-to-get-the-index-of-the-median-in-python-in-one-command
def argmedian(x):
  return np.argpartition(x, len(x) // 2)[len(x) // 2]

def stacked_corner(list_of_files,number_of_files_to_plot,variables_to_plot,ranges,injection_parameters,labels,axes_scales,savefig=None,logscale=False):




    

    y = []
    fig= None 
    i = 0

    #while i < number_of_files_to_plot:

    for j in range(len(list_of_files)):
        f = list_of_files[j]
        yi,code = load_data(f,variables_to_plot)

        if code == 0:
            y.extend([yi])
            i += 1

        if i > number_of_files_to_plot:
            break
        
        print(i, f)

    plt.style.use('science')

    

    num_params = len(variables_to_plot)
    
    title_values = np.zeros((num_params,number_of_files_to_plot)) #an array with shape number of parameters x number of noise realisations 
    title_upper = np.zeros((num_params,number_of_files_to_plot)) 
    title_lower = np.zeros((num_params,number_of_files_to_plot))

    print("Shape of title value s arary", np.shape(title_values))
    

    for i in range(number_of_files_to_plot): #for each noise realisation 

        k = i 
        if k ==2:
            k = k+1 #convoluted way of skipping C2 color




        if logscale:
            yplot = np.log10(y[i])
            injection_parameters = np.log10(injection_parameters)
            #ranges = np.log10(ranges)
        else:
            yplot = y[i]
        
        print("ranges =", ranges)
        nsamples = len(y[i])
        fs = 20

        new_injection_parameters = [injection_parameters[0]*1e9,injection_parameters[1],injection_parameters[2],injection_parameters[3],injection_parameters[4]]
        



        print("The injection parameters for the plotter are:", new_injection_parameters)
        fig = corner.corner(yplot, 
                            color=f'C{k}',
                            show_titles=True,
                            smooth=True,smooth1d=True,
                            truth_color='C2',
                            quantiles=[0.16, 0.84],
                            truths =new_injection_parameters,
                            range=ranges,
                            labels = labels,
                            label_kwargs=dict(fontsize=fs),
                            axes_scales = axes_scales,
                            weights = np.ones(nsamples)/nsamples,
                            fig=fig)


        kk = 0
        for ax in fig.axes:
            ax_title = ax.get_title()
            
            if ax_title != '':


                #print('2:', ax_title, type(ax_title))
                param_name, value,lower_limit,upper_limit = extract_value_from_title(ax_title) #Get the values that corner.corner sends to the ax title
                #print(parsed_output)

                print(kk,i,param_name,value)
                title_values[kk,i] = value
                title_lower[kk,i] = lower_limit
                title_upper[kk,i] = upper_limit


            
                kk += 1
                


        i += 1


        #Pretty-ify
    for ax in fig.axes:

        if ax.lines: #is anything plotted on this axis?
            
            ax.yaxis.set_major_locator(plt.MaxNLocator(3))
            ax.xaxis.set_major_locator(plt.MaxNLocator(3))

            ax.yaxis.set_tick_params(labelsize=fs-6)
            ax.xaxis.set_tick_params(labelsize=fs-6)


        ax.title.set_size(18)



#     #Get the indices of the median values from the list of medians 
#     idxs = [] #this is the index of the median for each parameter. 
#     for l in range(num_params):
#         idx = argmedian(title_values[l,:])
#         idxs.extend([idx])



#     #Now use it to set the titles
#     kk = 0
#     for ax in fig.axes:
#         ax_title = ax.get_title()
#         if ax_title != '':


#             selected_idx = idxs[kk]

# #foo = f'text$_{{{var}}}$'


#             new_title_string = rf'{labels[kk]} $= {title_values[kk,selected_idx]:.2f}_{{{title_lower[kk,selected_idx]:.2f}}}^{{+{title_upper[kk,selected_idx]:.2f}}}$'
#             print(new_title_string) 
#             ax.set_title(new_title_string, fontsize=18)
#             kk += 1





    if savefig != None:
        plt.savefig(f"../data/images/{savefig}.png", bbox_inches="tight",dpi=300)
        

    #return fig

# %% [markdown]
# # Define data files to use

# %%
import glob 
list_of_files = sorted(glob.glob("../data/nested_sampling/data_for_manuscript/PPPlots_h1e14/*"))
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","delta_gw","alpha_gw"]


def parse_filename(f):
    row = f.split('_')
    omega,phi0,psi,delta,alpha = row[13],row[15],row[17],row[19],row[21] #specific to these filenames
    return float(omega),float(phi0),float(psi),float(delta),float(alpha)

# %% [markdown]
# ## Plot just one file to check everything ok

# %%
f = list_of_files[2]
injection_parameters = parse_filename(f)
ranges=[(injection_parameters[0]*0.9*1e9,injection_parameters[0]*1.1*1e9),(-np.pi,np.pi),(0.0,np.pi),(-np.pi/2,np.pi/2),(0.0,2*np.pi)]

labels = [r'$\Omega_{\rm nHz}$',r'$\Phi_0$',r'$\psi$', r'$\delta$',r'$\alpha$']
axes_scales = None



print("Injection parameters = ", injection_parameters)
number_of_files_to_plot = 1
stacked_corner([f],number_of_files_to_plot,variables_to_plot,ranges,injection_parameters,labels,axes_scales,savefig=None, logscale=False)
# Out:
# Injection parameters =  (1.0381624863799256e-07, 0.4967299991033835, 3.0858471071316687, 0.6935233466696207, 1.8139070574503529)
# omega_gw 103.63846127640483 0.027671020775408582
# quantiles: [102.91883387 104.23321432]
# phi0_gw 0.411040434691754 0.0008518671516146312
# quantiles: [0.29877079 0.5368918 ]
# psi_gw 2.364742320859129 0.00010823768562950399
# quantiles: [2.28622915 2.39438336]
# delta_gw 1.3781328420830452 1.4958668510392353e-06
# quantiles: [1.3729096  1.38384824]
# alpha_gw 3.135435820366319 6.900452854654553e-05
# quantiles: [3.05679462 3.14159197]
# -----------------------------***********************----------------------
# 1 ../data/nested_sampling/data_for_manuscript/PPPlots_h1e14/NEWpp_plot_h_5e-14_model_earth_seed_1245_omega_1.0381624863799256e-07_phi0_0.4967299991033835_psi_3.0858471071316687_delta_0.6935233466696207_alpha_1.8139070574503529_result.json
# Shape of title value s arary (5, 1)
# ranges = [(93.4346237741933, 114.19787350179182), (-3.141592653589793, 3.141592653589793), (0.0, 3.141592653589793), (-1.5707963267948966, 1.5707963267948966), (0.0, 6.283185307179586)]
# The injection parameters for the plotter are: [103.81624863799256, 0.4967299991033835, 3.0858471071316687, 0.6935233466696207, 1.8139070574503529]
# 0 0 Omega_{\rm nHz} 103.64
# 1 0 Phi_0 0.41
# 2 0 psi 2.36
# 3 0 delta 1.38
# 4 0 alpha 3.14

# %% [markdown]
# ## Now lets look at getting some credible intervals / quantiles

# %%
# %%time
quantiles = np.arange(0,1.0,0.05) #[0.05,0.95] #90 per cent quantiles 
quantiles = np.append(quantiles,1.0) #quantiles.append(1.0)
import sys

#q90 = [0.05,0.95]
#q90_results = np.zeros(len(variables_to_plot))

quantile_results = np.zeros((int(len(quantiles)/2),len(variables_to_plot))) #quantile rows x variable columns

for f in list_of_files:
    print(f)
    injection_parameters = parse_filename(f)
    # Load the data into a df
    f = open(f)
    data = json.load(f)
    f.close()
    df_posterior = pd.DataFrame(data["posterior"]["content"])[variables_to_plot] 
    
    #Get the quantiles
    df_quantile = df_posterior.quantile(quantiles)


    #For each quantile pair

    #Special case for i=0
    i=0
    lower_limit = df_quantile.iloc[i] 
    upper_limit = df_quantile.iloc[-1] 
    #print("quantiles", 0,quantiles[i], quantiles[-1],quantiles[-1] -quantiles[i])


    for j in range(len(injection_parameters)):
        var = variables_to_plot[j]
        #print(0, lower_limit[var], injection_parameters[j], upper_limit[var])
        if lower_limit[var] <= injection_parameters[j] <= upper_limit[var]:
            quantile_results[i,j] = quantile_results[i,j] + 1





    for i in range(1,int(len(quantiles)/2)):
        #print("quantiles", i,quantiles[i], quantiles[-i],quantiles[-i] -quantiles[i])

        lower_limit = df_quantile.iloc[i] 
        upper_limit = df_quantile.iloc[-i-1] #-1 since we are ignoreing the last element which was handled in the special case

        for j in range(len(injection_parameters)):
            var = variables_to_plot[j]
            if lower_limit[var] <= injection_parameters[j] <= upper_limit[var]:
                quantile_results[i,j] = quantile_results[i,j] + 1
# Out:
# ../data/nested_sampling/data_for_manuscript/PPPlots_h1e14/NEWpp_plot_h_5e-14_model_earth_seed_1245_omega_1.007511062539126e-09_phi0_1.491417895936869_psi_1.5499758743692265_delta_1.112308176528821_alpha_2.157878846259271_result.json
# ../data/nested_sampling/data_for_manuscript/PPPlots_h1e14/NEWpp_plot_h_5e-14_model_earth_seed_1245_omega_1.0339204185955714e-07_phi0_0.8960820327581986_psi_0.3471476202503005_delta_1.265734698232627_alpha_0.2767665030732223_result.json
# ../data/nested_sampling/data_for_manuscript/PPPlots_h1e14/NEWpp_plot_h_5e-14_model_earth_seed_1245_omega_1
#        [ 92.,  40.,  18.,   6.,  11.],
#        [ 75.,  34.,  14.,   5.,  10.],
#        [ 62.,  24.,  14.,   4.,  10.],
#        [ 48.,  19.,   9.,   4.,   9.],
#        [ 28.,  14.,   7.,   3.,   8.],
#        [ 14.,  10.,   5.,   3.,   7.]])

# %%
quantile_results/200.0
# Out:
# array([[0.93 , 0.575, 0.3  , 0.145, 0.175],
#        [0.81 , 0.335, 0.155, 0.055, 0.07 ],
#        [0.685, 0.31 , 0.135, 0.05 , 0.065],
#        [0.535, 0.255, 0.115, 0.045, 0.06 ],
#        [0.46 , 0.2  , 0.09 , 0.03 , 0.055],
#        [0.375, 0.17 , 0.07 , 0.025, 0.05 ],
#        [0.31 , 0.12 , 0.07 , 0.02 , 0.05 ],
#        [0.24 , 0.095, 0.045, 0.02 , 0.045],
#        [0.14 , 0.07 , 0.035, 0.015, 0.04 ],
#        [0.07 , 0.05 , 0.025, 0.015, 0.035]])

# %%
import matplotlib.pyplot as plt 
import scienceplots




plt.style.use('science')
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)


xx = np.arange(1,0.0,-0.1)

for i in range(len(variables_to_plot)):
    yy = quantile_results[:,i] / 200
    ax.scatter(xx,yy,label=variables_to_plot[i])

ax.legend()


ax.plot(xx,xx,linestyle = '--', c='0.5')

# %%
# %%time
quantiles = np.arange(0,1.0,0.05) #[0.05,0.95] #90 per cent quantiles 
quantiles = np.append(quantiles,1.0) #quantiles.append(1.0)
import sys

#q90 = [0.05,0.95]
#q90_results = np.zeros(len(variables_to_plot))

quantile_results2 = np.zeros((int(len(quantiles)/2),len(variables_to_plot))) #quantile rows x variable columns

for f in list_of_files:
    print(f)
    injection_parameters = parse_filename(f)
    # Load the data into a df
    f = open(f)
    data = json.load(f)
    f.close()
    df_posterior = pd.DataFrame(data["posterior"]["content"])[variables_to_plot] 
    
    #Get the quantiles
    df_quantile = df_posterior.quantile(quantiles)


    #For each quantile pair

    #Special case for i=0
    i=0
    lower_limit = df_quantile.iloc[i] 
    upper_limit = df_quantile.iloc[-1] 
 
    print("i = 0 quantile:", lower_limit, upper_limit)
    #print("quantiles", 0,quantiles[i], quantiles[-1],quantiles[-1] -quantiles[i])


    for j in range(len(injection_parameters)):
        var = variables_to_plot[j]
        #print(0, lower_limit[var], injection_parameters[j], upper_limit[var])
        if lower_limit[var] <= injection_parameters[j] <= upper_limit[var]:
            quantile_results[i,j] = quantile_results[i,j] + 1

        else:
            if var == 'omega_gw':
                print("For this file the injected omega falls outside the 100 percent quantiles" )
                print("Offender: ", f)






    # for i in range(1,int(len(quantiles)/2)):
    #     #print("quantiles", i,quantiles[i], quantiles[-i],quantiles[-i] -quantiles[i])

    #     lower_limit = df_quantile.iloc[i] 
    #     upper_limit = df_quantile.iloc[-i-1] #-1 since we are ignoreing the last element which was handled in the special case

    #     for j in range(len(injection_parameters)):
    #         var = variables_to_plot[j]
    #         if lower_limit[var] <= injection_parameters[j] <= upper_limit[var]:
    #             quantile_results2[i,j] = quantile_results[i,j] + 1
# Out:
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.0196225038524221e-07_phi0_0.714870886742126_psi_0.9944870698629306_delta_1.2872050521677654_alpha_1.8515432419778288_result.json
# i = 0 quantile: omega_gw    9.903419e-08
# phi0_gw     1.018779e-01
# psi_gw      2.190582e+00
# delta_gw    1.249435e+00
# alpha_gw    2.321323e+00
# Name: 0.0, dtype: float64 omega_gw    1.060080e-07
# phi0_gw     1.260344e+00
# psi_gw      3.025393e+00
# delta_gw    1.396771e+00
# alpha_gw    3.141494e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.0230135211683393e-08_phi0_0.3704171536650886_psi_2.8305556812996406_delta_0.8065654642127479_alpha_1.296128240812015_result.json
# i = 0 quantile: omega_gw    1.052293e-09
# phi0_gw     1.600215e-03
# psi_gw      5.900764e-02
# delta_gw    7.303268e-01
# alpha_gw    4.451331e-04
# Name: 0.0, dtype: float64 omega_gw    1.740038e-08
# phi0_gw     1.569792e+00
# psi_gw      3.065709e+00
# delta_gw    1.443705e+00
# alpha_gw    1.297041e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.0415606385506375e-09_phi0_1.367133998480806_psi_2.2394862375387543_delta_1.4980249500799223_alpha_0.6137891270620494_result.json
# i = 0 quantile: omega_gw    1.001792e-09
# phi0_gw     1.196812e-03
# psi_gw      1.027750e-04
# delta_gw    1.589445e-04
# alpha_gw    5.794556e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.568245
# psi_gw      3.141062
# delta_gw    1.568691
# alpha_gw    3.140134
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.0959917144439979e-07_phi0_0.10298192426514075_psi_0.6208752640691612_delta_1.3622729964423819_alpha_0.8608352291238129_result.json
# i = 0 quantile: omega_gw    1.006596e-09
# phi0_gw     1.802592e-05
# psi_gw      1.964085e-03
# delta_gw    6.132367e-06
# alpha_gw    4.891102e-02
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.562700
# psi_gw      3.105618
# delta_gw    1.502458
# alpha_gw    3.136914
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.0968487938314171e-07_phi0_0.6182878130057889_psi_1.6276630208381242_delta_1.0109736402181129_alpha_2.913589423748042_result.json
# i = 0 quantile: omega_gw    1.061617e-07
# phi0_gw     7.627527e-02
# psi_gw      1.631386e+00
# delta_gw    6.882730e-06
# alpha_gw    1.100675e-05
# Name: 0.0, dtype: float64 omega_gw    1.110462e-07
# phi0_gw     9.799153e-01
# psi_gw      2.127831e+00
# delta_gw    2.846021e-01
# alpha_gw    4.113633e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.1537500122175511e-08_phi0_1.1610552441295465_psi_0.9519151541997442_delta_1.173316307314871_alpha_0.18617341605502602_result.json
# i = 0 quantile: omega_gw    1.001209e-09
# phi0_gw     4.352346e-04
# psi_gw      2.346037e-03
# delta_gw    2.164978e-04
# alpha_gw    9.299330e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569260
# psi_gw      3.138366
# delta_gw    1.570242
# alpha_gw    3.139801
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.1569531443138839e-07_phi0_0.6462038962153702_psi_0.21061992992350115_delta_0.3151267851388355_alpha_1.878315301308661_result.json
# i = 0 quantile: omega_gw    1.110155e-07
# phi0_gw     4.134190e-02
# psi_gw      1.344711e-01
# delta_gw    9.521252e-01
# alpha_gw    3.577301e-02
# Name: 0.0, dtype: float64 omega_gw    1.216074e-07
# phi0_gw     1.570405e+00
# psi_gw      3.133073e+00
# delta_gw    1.569729e+00
# alpha_gw    3.140358e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.1770870878880383e-09_phi0_0.4428391595090912_psi_2.773986495999868_delta_0.8611184073100325_alpha_0.24904018425434016_result.json
# i = 0 quantile: omega_gw    1.000522e-09
# phi0_gw     6.353118e-04
# psi_gw      9.039570e-03
# delta_gw    1.589664e-03
# alpha_gw    1.964885e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570549
# psi_gw      3.139248
# delta_gw    1.570463
# alpha_gw    3.137066
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.1901566228547066e-09_phi0_0.5671103673520994_psi_1.1575922259112237_delta_1.2375685711367643_alpha_0.03216846764544114_result.json
# i = 0 quantile: omega_gw    1.003214e-09
# phi0_gw     3.982553e-05
# psi_gw      1.633421e-04
# delta_gw    5.480633e-04
# alpha_gw    1.013306e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570228
# psi_gw      3.140022
# delta_gw    1.570710
# alpha_gw    3.141506
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.2399794468803473e-07_phi0_0.14117348714296804_psi_1.3210762311421511_delta_0.9145531734627548_alpha_0.3879742654694567_result.json
# i = 0 quantile: omega_gw    1.003583e-09
# phi0_gw     1.684626e-03
# psi_gw      8.123586e-03
# delta_gw    1.155573e-03
# alpha_gw    4.061863e-05
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569245
# psi_gw      3.138995
# delta_gw    1.569383
# alpha_gw    3.135065
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.269661422402237e-07_phi0_0.3881586994653955_psi_1.1641031896304193_delta_0.9524774856784951_alpha_3.0675007560609355_result.json
# i = 0 quantile: omega_gw    1.237985e-07
# phi0_gw     1.123374e-02
# psi_gw      4.904414e-01
# delta_gw    1.070630e-04
# alpha_gw    2.749185e-04
# Name: 0.0, dtype: float64 omega_gw    1.313244e-07
# phi0_gw     1.310889e+00
# psi_gw      2.217216e+00
# delta_gw    1.063470e+00
# alpha_gw    3.141579e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.2792536499172489e-08_phi0_0.33597587772371895_psi_0.5107936536068638_delta_1.210391599536352_alpha_0.720845611375956_result.json
# i = 0 quantile: omega_gw    1.004010e-09
# phi0_gw     8.317142e-03
# psi_gw      1.143532e-01
# delta_gw    9.232950e-04
# alpha_gw    6.985483e-01
# Name: 0.0, dtype: float64 omega_gw    1.455790e-08
# phi0_gw     1.570673e+00
# psi_gw      2.446508e+00
# delta_gw    8.104833e-01
# alpha_gw    2.296110e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.2865713266416145e-08_phi0_0.7720790067317768_psi_1.416712517260658_delta_0.8512298558611202_alpha_1.45104007110531_result.json
# i = 0 quantile: omega_gw    1.002076e-09
# phi0_gw     8.517173e-04
# psi_gw      1.392319e-03
# delta_gw    7.996264e-01
# alpha_gw    8.943329e-03
# Name: 0.0, dtype: float64 omega_gw    1.852029e-08
# phi0_gw     1.570717e+00
# psi_gw      3.121228e+00
# delta_gw    1.570039e+00
# alpha_gw    2.931415e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.291870433475937e-08_phi0_1.244776238410025_psi_1.80439977258406_delta_1.0742004645243592_alpha_0.47189848627652453_result.json
# i = 0 quantile: omega_gw    1.008207e-09
# phi0_gw     1.594644e-03
# psi_gw      3.854117e-03
# delta_gw    2.374444e-03
# alpha_gw    1.305359e-01
# Name: 0.0, dtype: float64 omega_gw    2.054389e-08
# phi0_gw     1.569924e+00
# psi_gw      3.140079e+00
# delta_gw    1.566239e+00
# alpha_gw    2.908519e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.3246475018876175e-07_phi0_1.5241828585576047_psi_1.7726671307068185_delta_0.3771675620862008_alpha_2.778080652222133_result.json
# i = 0 quantile: omega_gw    1.005322e-09
# phi0_gw     2.634014e-03
# psi_gw      2.080186e-03
# delta_gw    2.220860e-03
# alpha_gw    6.597273e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569239
# psi_gw      3.140104
# delta_gw    1.570500
# alpha_gw    3.141592
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.327394319273927e-09_phi0_1.333070165450216_psi_1.0842459574311707_delta_0.046385354904384016_alpha_2.6170172382250603_result.json
# i = 0 quantile: omega_gw    1.005506e-09
# phi0_gw     2.064027e-04
# psi_gw      4.002161e-04
# delta_gw    2.425899e-04
# alpha_gw    7.991961e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.568402
# psi_gw      3.140888
# delta_gw    1.569601
# alpha_gw    3.137468
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.3445926268164308e-08_phi0_1.312404088651848_psi_1.4445596974237231_delta_0.014426775590604264_alpha_2.116937213875887_result.json
# i = 0 quantile: omega_gw    2.645928e-09
# phi0_gw     3.382476e-05
# psi_gw      5.777552e-02
# delta_gw    7.722171e-01
# alpha_gw    1.679387e-03
# Name: 0.0, dtype: float64 omega_gw    1.722399e-08
# phi0_gw     1.566389e+00
# psi_gw      2.894282e+00
# delta_gw    1.566572e+00
# alpha_gw    3.141566e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.353219042935457e-07_phi0_0.6675460505230797_psi_2.9572594132121237_delta_1.5623111661581157_alpha_3.053226488922797_result.json
# i = 0 quantile: omega_gw    1.304389e-07
# phi0_gw     3.200692e-05
# psi_gw      1.432504e-03
# delta_gw    1.196654e-01
# alpha_gw    3.474197e-03
# Name: 0.0, dtype: float64 omega_gw    1.405530e-07
# phi0_gw     1.442816e+00
# psi_gw      3.141524e+00
# delta_gw    9.399369e-01
# alpha_gw    1.820960e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.357941432704459e-07_phi0_0.5547696397109657_psi_3.0366627727126043_delta_1.0668945242792527_alpha_0.42019942059026133_result.json
# i = 0 quantile: omega_gw    1.332478e-07
# phi0_gw     1.510474e-04
# psi_gw      1.766414e-03
# delta_gw    1.885685e-01
# alpha_gw    7.404077e-01
# Name: 0.0, dtype: float64 omega_gw    1.400739e-07
# phi0_gw     8.457882e-01
# psi_gw      3.141581e+00
# delta_gw    7.303392e-01
# alpha_gw    1.303080e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.3870924541557672e-09_phi0_0.4931395888834545_psi_2.7773672186390757_delta_1.497948802023855_alpha_0.2653961203605292_result.json
# i = 0 quantile: omega_gw    1.000981e-09
# phi0_gw     8.466731e-05
# psi_gw      9.158721e-04
# delta_gw    1.035243e-03
# alpha_gw    3.945572e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570518
# psi_gw      3.140746
# delta_gw    1.567824
# alpha_gw    3.140812
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.3938931989184324e-08_phi0_1.3444372033906848_psi_0.3324023232612842_delta_0.858013681671505_alpha_0.04262127975929244_result.json
# i = 0 quantile: omega_gw    3.416440e-09
# phi0_gw     2.948566e-01
# psi_gw      1.407327e-05
# delta_gw    1.806297e-05
# alpha_gw    8.632344e-01
# Name: 0.0, dtype: float64 omega_gw    1.455039e-08
# phi0_gw     1.556563e+00
# psi_gw      3.141523e+00
# delta_gw    3.418902e-01
# alpha_gw    1.503430e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.3960873397949353e-09_phi0_1.127541930002849_psi_0.45145016719473335_delta_0.02137421102070216_alpha_2.2122243147505514_result.json
# i = 0 quantile: omega_gw    1.001735e-09
# phi0_gw     8.102236e-05
# psi_gw      1.220867e-03
# delta_gw    2.026778e-04
# alpha_gw    3.398148e-05
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569920
# psi_gw      3.138652
# delta_gw    1.570370
# alpha_gw    3.140477
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.4025640535881544e-08_phi0_1.5284905457514306_psi_1.4887655432270948_delta_1.1385404716348675_alpha_0.9348949984202283_result.json
# i = 0 quantile: omega_gw    1.002839e-09
# phi0_gw     5.603030e-04
# psi_gw      5.248355e-03
# delta_gw    1.463207e-03
# alpha_gw    1.049618e-02
# Name: 0.0, dtype: float64 omega_gw    5.783550e-07
# phi0_gw     1.570678e+00
# psi_gw      3.140562e+00
# delta_gw    1.503044e+00
# alpha_gw    3.115643e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.4210588548929141e-08_phi0_0.26558463364333096_psi_0.7237060346373818_delta_1.2903447503447678_alpha_2.503716092405733_result.json
# i = 0 quantile: omega_gw    1.000130e-09
# phi0_gw     3.087307e-06
# psi_gw      5.283976e-03
# delta_gw    1.116486e-05
# alpha_gw    1.600052e-03
# Name: 0.0, dtype: float64 omega_gw    0.000009
# phi0_gw     1.569622
# psi_gw      3.138756
# delta_gw    1.570718
# alpha_gw    3.141437
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.4355161236005995e-07_phi0_1.4721278864282354_psi_2.2152980601907255_delta_0.27095272690282185_alpha_2.1043300959136824_result.json
# i = 0 quantile: omega_gw    1.362677e-07
# phi0_gw     6.188565e-02
# psi_gw      1.830599e-01
# delta_gw    6.751272e-01
# alpha_gw    1.344948e-01
# Name: 0.0, dtype: float64 omega_gw    1.461767e-07
# phi0_gw     1.554716e+00
# psi_gw      2.185900e+00
# delta_gw    1.569692e+00
# alpha_gw    3.141503e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.4549706557922182e-07_phi0_0.7541969144062175_psi_0.14650656986112526_delta_0.2008982966276224_alpha_0.13569869284376548_result.json
# i = 0 quantile: omega_gw    1.409276e-07
# phi0_gw     1.827389e-02
# psi_gw      2.119057e-06
# delta_gw    7.338436e-04
# alpha_gw    8.855676e-05
# Name: 0.0, dtype: float64 omega_gw    1.490225e-07
# phi0_gw     1.511632e+00
# psi_gw      3.462044e-01
# delta_gw    5.521733e-01
# alpha_gw    7.051873e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.4933502495099678e-07_phi0_0.8773083884373405_psi_0.09322816930008215_delta_0.10227083502444514_alpha_2.614248963809674_result.json
# i = 0 quantile: omega_gw    1.000745e-09
# phi0_gw     6.068564e-05
# psi_gw      2.317332e-04
# delta_gw    2.446151e-03
# alpha_gw    3.001776e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.568627
# psi_gw      3.141364
# delta_gw    1.568067
# alpha_gw    3.141507
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.5026114097109381e-09_phi0_0.2520732657596406_psi_2.2564033245344093_delta_0.8548857763180104_alpha_1.6152858932908178_result.json
# i = 0 quantile: omega_gw    1.001122e-09
# phi0_gw     1.839947e-04
# psi_gw      1.732469e-03
# delta_gw    2.392688e-04
# alpha_gw    8.390543e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569660
# psi_gw      3.141188
# delta_gw    1.570541
# alpha_gw    3.141245
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.517668127836692e-08_phi0_1.564756531833681_psi_2.20250366637542_delta_1.4106290825756396_alpha_2.092586642830348_result.json
# i = 0 quantile: omega_gw    5.949222e-09
# phi0_gw     4.069186e-01
# psi_gw      6.445268e-02
# delta_gw    1.258188e+00
# alpha_gw    2.256213e+00
# Name: 0.0, dtype: float64 omega_gw    1.757936e-08
# phi0_gw     1.570305e+00
# psi_gw      1.062984e+00
# delta_gw    1.566911e+00
# alpha_gw    3.141586e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.5855649842810227e-09_phi0_0.21937789767097204_psi_3.1295729759110342_delta_1.3474323836000586_alpha_1.9500651195266983_result.json
# i = 0 quantile: omega_gw    1.002090e-09
# phi0_gw     5.692373e-04
# psi_gw      2.591136e-03
# delta_gw    2.286157e-03
# alpha_gw    1.722724e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570725
# psi_gw      3.141315
# delta_gw    1.570204
# alpha_gw    3.141163
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.5863062295117154e-07_phi0_1.0546352253177098_psi_1.0255361294537404_delta_0.9865041137196827_alpha_2.7446414427271746_result.json
# i = 0 quantile: omega_gw    1.556185e-07
# phi0_gw     6.447122e-01
# psi_gw      1.996343e+00
# delta_gw    7.383475e-04
# alpha_gw    2.447004e-07
# Name: 0.0, dtype: float64 omega_gw    1.618428e-07
# phi0_gw     1.569167e+00
# psi_gw      2.389329e+00
# delta_gw    3.934171e-01
# alpha_gw    1.603893e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.6211390104430554e-07_phi0_0.6798207723977633_psi_1.6304350575044593_delta_0.8849294071508665_alpha_1.1789789435272862_result.json
# i = 0 quantile: omega_gw    1.599083e-07
# phi0_gw     7.206542e-01
# psi_gw      9.191425e-01
# delta_gw    8.686102e-01
# alpha_gw    3.258889e-04
# Name: 0.0, dtype: float64 omega_gw    1.660257e-07
# phi0_gw     1.570780e+00
# psi_gw      2.677563e+00
# delta_gw    1.485985e+00
# alpha_gw    1.741226e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.6271995374147487e-09_phi0_0.09066615036733333_psi_2.540567353108348_delta_1.5273285423901446_alpha_0.5453000903146751_result.json
# i = 0 quantile: omega_gw    1.001611e-09
# phi0_gw     9.517147e-05
# psi_gw      8.260073e-04
# delta_gw    2.463813e-03
# alpha_gw    1.272387e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570230
# psi_gw      3.139178
# delta_gw    1.570726
# alpha_gw    3.141017
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.6585187309947905e-09_phi0_0.8465628205212299_psi_2.5266387199619174_delta_0.7285902429441686_alpha_2.1350356652216305_result.json
# i = 0 quantile: omega_gw    1.000550e-09
# phi0_gw     2.288967e-03
# psi_gw      3.012398e-03
# delta_gw    5.941515e-04
# alpha_gw    2.293335e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570727
# psi_gw      3.140547
# delta_gw    1.570697
# alpha_gw    3.141010
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.660339240846408e-07_phi0_0.5425208314405265_psi_1.3116079352597452_delta_0.2455439648969306_alpha_0.2488837580569854_result.json
# i = 0 quantile: omega_gw    1.636849e-07
# phi0_gw     8.689137e-02
# psi_gw      1.183766e+00
# delta_gw    1.922862e-03
# alpha_gw    7.411733e-05
# Name: 0.0, dtype: float64 omega_gw    1.720473e-07
# phi0_gw     1.559323e+00
# psi_gw      1.663523e+00
# delta_gw    5.146098e-01
# alpha_gw    6.384460e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.7184725661408265e-07_phi0_0.7384019116695212_psi_2.0308080760008296_delta_0.3674152350373387_alpha_2.5477371932307182_result.json
# i = 0 quantile: omega_gw    1.222431e-09
# phi0_gw     2.608064e-03
# psi_gw      4.774944e-03
# delta_gw    5.272692e-04
# alpha_gw    5.083245e-02
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.557540
# psi_gw      3.077308
# delta_gw    1.545532
# alpha_gw    3.141591
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.7206794218609675e-08_phi0_1.2790000509069435_psi_0.6589776172611899_delta_0.5317365828522229_alpha_1.978949424194579_result.json
# i = 0 quantile: omega_gw    7.327454e-09
# phi0_gw     2.335557e-01
# psi_gw      1.245047e-02
# delta_gw    9.081772e-01
# alpha_gw    1.638081e+00
# Name: 0.0, dtype: float64 omega_gw    1.970581e-08
# phi0_gw     1.570792e+00
# psi_gw      3.089582e+00
# delta_gw    1.419395e+00
# alpha_gw    2.907685e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.7345968336874868e-07_phi0_0.25213582560798536_psi_0.16277275189844942_delta_0.3058658444808147_alpha_2.918806067538762_result.json
# i = 0 quantile: omega_gw    1.620226e-07
# phi0_gw     1.455729e-05
# psi_gw      5.711528e-06
# delta_gw    5.114619e-06
# alpha_gw    7.757246e-04
# Name: 0.0, dtype: float64 omega_gw    1.774014e-07
# phi0_gw     1.570000e+00
# psi_gw      2.406659e+00
# delta_gw    1.560780e+00
# alpha_gw    3.141556e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.743144629505699e-09_phi0_0.5715238067128676_psi_2.6850615611142468_delta_1.3959774429905285_alpha_1.459932567359338_result.json
# i = 0 quantile: omega_gw    1.001694e-09
# phi0_gw     1.084246e-03
# psi_gw      2.448512e-03
# delta_gw    6.169287e-05
# alpha_gw    1.009669e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570361
# psi_gw      3.139865
# delta_gw    1.569772
# alpha_gw    3.141357
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.7501738984396713e-07_phi0_0.2969588108938496_psi_1.9288740806202298_delta_0.38697368572140817_alpha_2.633942500715377_result.json
# i = 0 quantile: omega_gw    1.742757e-07
# phi0_gw     1.331054e-01
# psi_gw      1.323722e+00
# delta_gw    2.054111e-01
# alpha_gw    2.731680e+00
# Name: 0.0, dtype: float64 omega_gw    1.839396e-07
# phi0_gw     1.564054e+00
# psi_gw      2.002932e+00
# delta_gw    1.087504e+00
# alpha_gw    3.141590e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.7820198785578558e-09_phi0_1.0187393499840702_psi_1.2749676606540064_delta_0.30903405288609015_alpha_1.0716276705481793_result.json
# i = 0 quantile: omega_gw    1.008390e-09
# phi0_gw     1.665813e-04
# psi_gw      1.275983e-03
# delta_gw    1.924958e-04
# alpha_gw    1.326277e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570366
# psi_gw      3.140462
# delta_gw    1.568079
# alpha_gw    3.140689
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.8064137206971818e-07_phi0_0.41728348231659645_psi_0.7507082235186238_delta_0.4624098121749638_alpha_2.6935712393333775_result.json
# i = 0 quantile: omega_gw    1.000009e-09
# phi0_gw     2.033124e-03
# psi_gw      1.393915e-03
# delta_gw    8.131300e-04
# alpha_gw    1.425117e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570185
# psi_gw      3.138553
# delta_gw    1.569403
# alpha_gw    3.141526
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.8115944954722236e-07_phi0_0.019193676050020637_psi_1.160102621275388_delta_0.8783275479861651_alpha_2.8295099545227154_result.json
# i = 0 quantile: omega_gw    1.000046e-09
# phi0_gw     1.377212e-04
# psi_gw      5.737318e-03
# delta_gw    3.396822e-04
# alpha_gw    3.253089e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570355
# psi_gw      3.140524
# delta_gw    1.570666
# alpha_gw    3.141530
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.8207418096725594e-08_phi0_1.2878477599521576_psi_1.1329613928297577_delta_1.3192675305522386_alpha_2.4045872593021356_result.json
# i = 0 quantile: omega_gw    1.360580e-08
# phi0_gw     1.810981e-02
# psi_gw      6.700111e-02
# delta_gw    3.130853e-05
# alpha_gw    5.262104e-02
# Name: 0.0, dtype: float64 omega_gw    2.212046e-08
# phi0_gw     1.567755e+00
# psi_gw      3.141562e+00
# delta_gw    1.405389e+00
# alpha_gw    3.141541e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.8419206386851329e-09_phi0_1.0593224699153758_psi_1.5026041721817862_delta_1.1007686096890206_alpha_1.7710675867528574_result.json
# i = 0 quantile: omega_gw    1.000236e-09
# phi0_gw     5.922638e-04
# psi_gw      4.736459e-03
# delta_gw    3.905597e-04
# alpha_gw    4.452221e-05
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570770
# psi_gw      3.140716
# delta_gw    1.567843
# alpha_gw    3.141242
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.8502440975180728e-07_phi0_1.366579084201073_psi_1.9019205880682026_delta_0.7741747208569969_alpha_2.397489001746755_result.json
# i = 0 quantile: omega_gw    1.825522e-07
# phi0_gw     9.295144e-01
# psi_gw      1.016693e+00
# delta_gw    8.896230e-01
# alpha_gw    2.851305e+00
# Name: 0.0, dtype: float64 omega_gw    1.876016e-07
# phi0_gw     1.570659e+00
# psi_gw      1.516233e+00
# delta_gw    1.269109e+00
# alpha_gw    3.141543e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.8567609141929826e-07_phi0_0.9828765915591058_psi_1.868805057442283_delta_0.3154278611818026_alpha_2.0414896253631536_result.json
# i = 0 quantile: omega_gw    1.814566e-07
# phi0_gw     4.449931e-01
# psi_gw      7.913753e-01
# delta_gw    6.291497e-01
# alpha_gw    1.320787e+00
# Name: 0.0, dtype: float64 omega_gw    1.889523e-07
# phi0_gw     1.568016e+00
# psi_gw      2.803993e+00
# delta_gw    1.544728e+00
# alpha_gw    3.141586e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.867041937561535e-07_phi0_0.050307779383550306_psi_0.23715169984938717_delta_0.04174032064352877_alpha_1.5965850736468779_result.json
# i = 0 quantile: omega_gw    1.864248e-07
# phi0_gw     5.236437e-05
# psi_gw      6.316632e-02
# delta_gw    1.075745e+00
# alpha_gw    1.872470e-02
# Name: 0.0, dtype: float64 omega_gw    1.936193e-07
# phi0_gw     1.006183e+00
# psi_gw      3.141425e+00
# delta_gw    1.570749e+00
# alpha_gw    3.128627e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.8675940509292946e-09_phi0_0.775213003580127_psi_1.1578756290833137_delta_0.00137135645427101_alpha_1.019027038602321_result.json
# i = 0 quantile: omega_gw    1.003670e-09
# phi0_gw     1.998587e-04
# psi_gw      2.337860e-03
# delta_gw    7.744859e-04
# alpha_gw    2.967171e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.565198
# psi_gw      3.140354
# delta_gw    1.570633
# alpha_gw    3.136035
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.8759879162328202e-09_phi0_1.001422138463456_psi_0.20502850035158432_delta_1.4127457689329703_alpha_0.31771680389460283_result.json
# i = 0 quantile: omega_gw    1.002499e-09
# phi0_gw     1.449097e-03
# psi_gw      2.275762e-03
# delta_gw    7.880937e-04
# alpha_gw    1.961827e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570563
# psi_gw      3.140829
# delta_gw    1.569938
# alpha_gw    3.138980
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.8869492283648126e-07_phi0_0.9195458519222997_psi_2.3272261850258444_delta_0.3423155936402068_alpha_3.032539047516845_result.json
# i = 0 quantile: omega_gw    1.825942e-07
# phi0_gw     2.353981e-03
# psi_gw      2.114582e+00
# delta_gw    5.285475e-04
# alpha_gw    2.795523e+00
# Name: 0.0, dtype: float64 omega_gw    1.912925e-07
# phi0_gw     1.194100e+00
# psi_gw      2.629634e+00
# delta_gw    9.133318e-01
# alpha_gw    3.141581e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.89734801724148e-09_phi0_0.9513435414845139_psi_2.44180726762388_delta_0.6796568716680742_alpha_0.37168253743630547_result.json
# i = 0 quantile: omega_gw    1.002425e-09
# phi0_gw     6.986693e-04
# psi_gw      8.007565e-03
# delta_gw    6.035777e-04
# alpha_gw    1.437933e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570405
# psi_gw      3.140910
# delta_gw    1.570491
# alpha_gw    3.127348
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.9050095052613358e-08_phi0_0.689689512270684_psi_2.125999194944743_delta_0.010949507381970695_alpha_1.9479446283592978_result.json
# i = 0 quantile: omega_gw    2.506587e-09
# phi0_gw     4.882107e-03
# psi_gw      3.090983e-02
# delta_gw    8.770743e-01
# alpha_gw    2.155434e+00
# Name: 0.0, dtype: float64 omega_gw    2.364702e-08
# phi0_gw     1.562433e+00
# psi_gw      3.092040e+00
# delta_gw    1.478704e+00
# alpha_gw    3.141535e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.9170580600528736e-08_phi0_0.29319168277055413_psi_0.16097997651175605_delta_1.425534080832212_alpha_0.5730579114684453_result.json
# i = 0 quantile: omega_gw    1.262734e-09
# phi0_gw     4.898418e-04
# psi_gw      4.859060e-02
# delta_gw    3.682113e-04
# alpha_gw    1.317238e-02
# Name: 0.0, dtype: float64 omega_gw    0.000007
# phi0_gw     1.570785
# psi_gw      3.076520
# delta_gw    1.565637
# alpha_gw    3.000475
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.9302738484507604e-09_phi0_0.34621659446655234_psi_0.9554121083903208_delta_0.3201273933257741_alpha_1.9309530467679326_result.json
# i = 0 quantile: omega_gw    1.001119e-09
# phi0_gw     4.214443e-05
# psi_gw      3.115470e-03
# delta_gw    3.278419e-04
# alpha_gw    1.126476e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570190
# psi_gw      3.140422
# delta_gw    1.568876
# alpha_gw    3.141505
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.9316083006895842e-07_phi0_1.0033791703987074_psi_2.0564264108340153_delta_0.2572099055477023_alpha_1.4615076293975189_result.json
# i = 0 quantile: omega_gw    1.871687e-07
# phi0_gw     3.947739e-02
# psi_gw      1.730203e+00
# delta_gw    2.542363e-01
# alpha_gw    2.971444e-04
# Name: 0.0, dtype: float64 omega_gw    1.969550e-07
# phi0_gw     1.566437e+00
# psi_gw      3.137805e+00
# delta_gw    1.534339e+00
# alpha_gw    1.323309e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.937405980340014e-08_phi0_0.5027295598373378_psi_2.843672759611347_delta_1.4170507353621673_alpha_2.616537989441507_result.json
# i = 0 quantile: omega_gw    1.001406e-09
# phi0_gw     6.867710e-04
# psi_gw      6.185821e-04
# delta_gw    1.352576e-03
# alpha_gw    9.815648e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.568893
# psi_gw      3.141306
# delta_gw    1.570520
# alpha_gw    3.141366
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.9427547457284744e-08_phi0_0.8137059524604969_psi_0.9708225600567727_delta_1.4695816388221632_alpha_1.814242674958042_result.json
# i = 0 quantile: omega_gw    1.651549e-08
# phi0_gw     6.592753e-04
# psi_gw      1.974407e+00
# delta_gw    1.209011e+00
# alpha_gw    2.284147e+00
# Name: 0.0, dtype: float64 omega_gw    2.556201e-08
# phi0_gw     1.404054e+00
# psi_gw      2.864076e+00
# delta_gw    1.403100e+00
# alpha_gw    3.141562e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_1.9619990623180433e-08_phi0_0.14809795620472302_psi_0.41456676782367574_delta_1.0284571583739743_alpha_2.3737577206067506_result.json
# i = 0 quantile: omega_gw    1.780181e-08
# phi0_gw     1.532384e-02
# psi_gw      4.440281e-03
# delta_gw    9.753642e-01
# alpha_gw    3.629687e-06
# Name: 0.0, dtype: float64 omega_gw    2.727014e-08
# phi0_gw     1.418258e+00
# psi_gw      3.141290e+00
# delta_gw    1.570752e+00
# alpha_gw    3.141514e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.027866364151691e-09_phi0_1.13459606984539_psi_0.8777695089027914_delta_0.10951592043891815_alpha_0.9708555614052036_result.json
# i = 0 quantile: omega_gw    1.001302e-09
# phi0_gw     9.559240e-04
# psi_gw      8.309315e-04
# delta_gw    3.444434e-04
# alpha_gw    5.441227e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570781
# psi_gw      3.141205
# delta_gw    1.569708
# alpha_gw    3.141225
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.0859261944407376e-09_phi0_0.13870942921031612_psi_1.470232672959981_delta_0.4990464509174225_alpha_0.562988985298196_result.json
# i = 0 quantile: omega_gw    1.000615e-09
# phi0_gw     2.288452e-04
# psi_gw      2.023649e-04
# delta_gw    4.849624e-04
# alpha_gw    9.214924e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.568342
# psi_gw      3.141160
# delta_gw    1.570448
# alpha_gw    3.139947
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.0971860148256713e-09_phi0_0.4770655945544507_psi_0.315370282698194_delta_1.0381172016113052_alpha_2.1128251105448204_result.json
# i = 0 quantile: omega_gw    1.000131e-09
# phi0_gw     8.487392e-04
# psi_gw      3.161702e-03
# delta_gw    5.052207e-04
# alpha_gw    7.916399e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.565634
# psi_gw      3.139483
# delta_gw    1.570718
# alpha_gw    3.133938
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.137779864477248e-08_phi0_0.3912594976440772_psi_0.362898641660569_delta_0.5920688869306024_alpha_0.2262667531777062_result.json
# i = 0 quantile: omega_gw    5.843228e-09
# phi0_gw     1.630576e-04
# psi_gw      1.806184e-02
# delta_gw    3.521003e-05
# alpha_gw    1.131881e-06
# Name: 0.0, dtype: float64 omega_gw    2.822021e-08
# phi0_gw     1.417861e+00
# psi_gw      1.974094e+00
# delta_gw    3.889224e-01
# alpha_gw    7.211862e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.1855233874703755e-07_phi0_1.1772830009418003_psi_0.7158891216719683_delta_1.5645526654203885_alpha_2.8770066519084376_result.json
# i = 0 quantile: omega_gw    1.001453e-09
# phi0_gw     4.094433e-05
# psi_gw      3.867581e-03
# delta_gw    7.994352e-05
# alpha_gw    1.445189e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.568998
# psi_gw      3.138467
# delta_gw    1.570554
# alpha_gw    3.140137
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.2041942622654293e-09_phi0_0.6364874199792683_psi_1.1784777770472288_delta_0.09162408490307951_alpha_2.2927852624210456_result.json
# i = 0 quantile: omega_gw    1.003060e-09
# phi0_gw     8.655623e-05
# psi_gw      6.656900e-04
# delta_gw    1.115320e-03
# alpha_gw    1.087530e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569573
# psi_gw      3.136739
# delta_gw    1.570019
# alpha_gw    3.139448
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.2281091740579955e-07_phi0_0.9621589226732309_psi_1.1902752310419578_delta_0.23748067699872163_alpha_1.6674412312245317_result.json
# i = 0 quantile: omega_gw    2.187514e-07
# phi0_gw     1.581568e-01
# psi_gw      5.620096e-04
# delta_gw    6.374637e-01
# alpha_gw    7.692712e-02
# Name: 0.0, dtype: float64 omega_gw    2.262856e-07
# phi0_gw     1.511186e+00
# psi_gw      3.135909e+00
# delta_gw    1.570741e+00
# alpha_gw    3.139997e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.228788164678751e-07_phi0_0.7939170296103236_psi_0.41878393502355327_delta_1.0432283742818238_alpha_1.205934314685807_result.json
# i = 0 quantile: omega_gw    2.201434e-07
# phi0_gw     3.208556e-01
# psi_gw      1.559583e-04
# delta_gw    9.199716e-01
# alpha_gw    5.739416e-01
# Name: 0.0, dtype: float64 omega_gw    2.278086e-07
# phi0_gw     1.522243e+00
# psi_gw      3.132844e+00
# delta_gw    1.275325e+00
# alpha_gw    1.690281e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.2309885492356114e-08_phi0_1.1708635002243597_psi_2.210141429950611_delta_0.21798179695616945_alpha_1.5780344378978584_result.json
# i = 0 quantile: omega_gw    1.001351e-09
# phi0_gw     2.913028e-04
# psi_gw      2.434450e-04
# delta_gw    3.190913e-04
# alpha_gw    1.037418e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570743
# psi_gw      3.139635
# delta_gw    1.570680
# alpha_gw    3.141337
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.254985858416412e-08_phi0_0.6101008852581091_psi_0.8745052921286999_delta_1.512618773802484_alpha_0.7583880866349891_result.json
# i = 0 quantile: omega_gw    2.150068e-08
# phi0_gw     9.427471e-05
# psi_gw      5.393097e-01
# delta_gw    4.419538e-01
# alpha_gw    7.242152e-01
# Name: 0.0, dtype: float64 omega_gw    2.789520e-08
# phi0_gw     7.358225e-01
# psi_gw      1.090397e+00
# delta_gw    8.712376e-01
# alpha_gw    1.659559e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.279258526142203e-08_phi0_0.12332649206373711_psi_2.8782995463229035_delta_0.0980411676452637_alpha_3.0812766632686825_result.json
# i = 0 quantile: omega_gw    2.161662e-09
# phi0_gw     3.278114e-05
# psi_gw      2.702421e-02
# delta_gw    9.432859e-05
# alpha_gw    5.890115e-05
# Name: 0.0, dtype: float64 omega_gw    3.092388e-08
# phi0_gw     1.570382e+00
# psi_gw      3.141253e+00
# delta_gw    1.412660e+00
# alpha_gw    3.141536e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.3199961442409046e-07_phi0_0.38408166182402304_psi_3.066826446717543_delta_1.0767191773133784_alpha_2.4681128877202947_result.json
# i = 0 quantile: omega_gw    2.290940e-07
# phi0_gw     1.643484e-01
# psi_gw      9.573768e-01
# delta_gw    7.935255e-01
# alpha_gw    1.728973e+00
# Name: 0.0, dtype: float64 omega_gw    2.363772e-07
# phi0_gw     1.441572e+00
# psi_gw      2.446719e+00
# delta_gw    1.387257e+00
# alpha_gw    3.141582e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.3831587036008398e-07_phi0_0.7253195523322928_psi_0.5290302243755014_delta_1.247549878250383_alpha_1.4246062117921061_result.json
# i = 0 quantile: omega_gw    1.000575e-09
# phi0_gw     3.770547e-04
# psi_gw      5.296567e-04
# delta_gw    1.089644e-03
# alpha_gw    2.313845e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570501
# psi_gw      3.140688
# delta_gw    1.570703
# alpha_gw    3.141268
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.400949849110232e-08_phi0_0.2677624120259294_psi_1.5660597229527673_delta_0.6325131462265084_alpha_2.2010383451039925_result.json
# i = 0 quantile: omega_gw    1.496511e-09
# phi0_gw     8.882172e-04
# psi_gw      1.237650e-03
# delta_gw    1.639731e-04
# alpha_gw    3.357642e-02
# Name: 0.0, dtype: float64 omega_gw    0.000001
# phi0_gw     1.568582
# psi_gw      3.141362
# delta_gw    1.567705
# alpha_gw    3.141472
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.4101216078917493e-09_phi0_0.27027600451529404_psi_0.45969055656388624_delta_0.9506022227382438_alpha_2.24232926838417_result.json
# i = 0 quantile: omega_gw    1.005868e-09
# phi0_gw     2.637367e-04
# psi_gw      2.375684e-03
# delta_gw    5.902837e-04
# alpha_gw    1.202177e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569139
# psi_gw      3.141538
# delta_gw    1.570599
# alpha_gw    3.140543
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.4474094930462174e-08_phi0_0.7974631535808631_psi_0.9613438760670472_delta_0.7554196975898898_alpha_0.7679631261597297_result.json
# i = 0 quantile: omega_gw    7.238131e-09
# phi0_gw     8.854208e-05
# psi_gw      1.481150e-01
# delta_gw    6.777893e-01
# alpha_gw    5.537554e-05
# Name: 0.0, dtype: float64 omega_gw    2.733850e-08
# phi0_gw     1.514986e+00
# psi_gw      2.176469e+00
# delta_gw    1.247756e+00
# alpha_gw    7.531680e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.4804572102244965e-09_phi0_0.06802872481346706_psi_0.26895889017619284_delta_0.5523155162430335_alpha_0.652035582648518_result.json
# i = 0 quantile: omega_gw    1.009900e-09
# phi0_gw     3.284181e-04
# psi_gw      2.817297e-03
# delta_gw    5.340287e-05
# alpha_gw    7.306936e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570285
# psi_gw      3.140070
# delta_gw    1.570572
# alpha_gw    3.140110
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.495794786912017e-09_phi0_1.046781880635637_psi_2.625328445666862_delta_0.37825141147853275_alpha_0.5126907493874725_result.json
# i = 0 quantile: omega_gw    1.007878e-09
# phi0_gw     5.344973e-04
# psi_gw      9.505545e-04
# delta_gw    1.910146e-03
# alpha_gw    6.770061e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569946
# psi_gw      3.141051
# delta_gw    1.569310
# alpha_gw    3.139660
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.5197242668514378e-09_phi0_0.7710831942903833_psi_2.6472261412453872_delta_0.854488918196856_alpha_2.2672733547932027_result.json
# i = 0 quantile: omega_gw    1.000074e-09
# phi0_gw     2.274534e-03
# psi_gw      1.217121e-03
# delta_gw    4.157114e-04
# alpha_gw    1.157727e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570571
# psi_gw      3.139499
# delta_gw    1.568352
# alpha_gw    3.140732
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.539652905670663e-07_phi0_0.8520526328134468_psi_2.41252333033036_delta_1.0643766276411082_alpha_1.7239848154327355_result.json
# i = 0 quantile: omega_gw    2.477665e-07
# phi0_gw     1.417463e-01
# psi_gw      4.407433e-05
# delta_gw    8.972273e-01
# alpha_gw    4.043299e-01
# Name: 0.0, dtype: float64 omega_gw    2.567049e-07
# phi0_gw     1.569949e+00
# psi_gw      1.759686e+00
# delta_gw    1.521123e+00
# alpha_gw    3.092624e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.6055752982438143e-09_phi0_0.5129437580358077_psi_2.367074627171374_delta_0.17177224338257724_alpha_2.642294000457305_result.json
# i = 0 quantile: omega_gw    1.004473e-09
# phi0_gw     1.834369e-04
# psi_gw      3.564073e-03
# delta_gw    2.455381e-04
# alpha_gw    5.399111e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570208
# psi_gw      3.139092
# delta_gw    1.569164
# alpha_gw    3.141323
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.6836558228090423e-09_phi0_1.3425236225390853_psi_2.4822828839438826_delta_0.8040281139384939_alpha_2.1536074599570796_result.json
# i = 0 quantile: omega_gw    1.000004e-09
# phi0_gw     1.645531e-04
# psi_gw      2.553240e-03
# delta_gw    2.809533e-04
# alpha_gw    5.364016e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569437
# psi_gw      3.141070
# delta_gw    1.570644
# alpha_gw    3.140337
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.712884435167613e-07_phi0_0.15458418450260863_psi_0.9154561600650148_delta_1.3703564464839515_alpha_2.5072108694568183_result.json
# i = 0 quantile: omega_gw    2.704745e-07
# phi0_gw     1.667949e-04
# psi_gw      2.711149e+00
# delta_gw    1.128322e-06
# alpha_gw    1.079801e-03
# Name: 0.0, dtype: float64 omega_gw    2.767563e-07
# phi0_gw     1.120284e+00
# psi_gw      3.023060e+00
# delta_gw    1.080981e-01
# alpha_gw    4.590125e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.7300310501401486e-08_phi0_0.956000807334708_psi_0.020056866052066514_delta_1.1179045790479032_alpha_0.8638169979397242_result.json
# i = 0 quantile: omega_gw    6.923180e-09
# phi0_gw     4.992605e-03
# psi_gw      2.333807e-04
# delta_gw    7.525737e-02
# alpha_gw    1.576093e-01
# Name: 0.0, dtype: float64 omega_gw    3.163762e-08
# phi0_gw     1.570416e+00
# psi_gw      3.141578e+00
# delta_gw    1.475988e+00
# alpha_gw    2.125700e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.731101438660417e-07_phi0_1.1435829891543074_psi_0.5339951604798456_delta_0.9255552662376016_alpha_2.199175872286162_result.json
# i = 0 quantile: omega_gw    2.663702e-07
# phi0_gw     1.714323e-01
# psi_gw      9.338168e-01
# delta_gw    9.482194e-01
# alpha_gw    1.580585e+00
# Name: 0.0, dtype: float64 omega_gw    2.763672e-07
# phi0_gw     1.569793e+00
# psi_gw      3.103092e+00
# delta_gw    1.567498e+00
# alpha_gw    3.141368e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.7668422464687286e-08_phi0_0.6754733720982906_psi_2.3763661845928374_delta_0.9338155649236377_alpha_2.690110289593908_result.json
# i = 0 quantile: omega_gw    1.014731e-09
# phi0_gw     4.528319e-05
# psi_gw      3.214410e-04
# delta_gw    2.951322e-06
# alpha_gw    2.446360e-03
# Name: 0.0, dtype: float64 omega_gw    0.000009
# phi0_gw     1.570648
# psi_gw      3.133827
# delta_gw    1.570192
# alpha_gw    3.141214
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.8136975739568826e-08_phi0_0.4522638484470486_psi_1.5113282861458357_delta_0.6860093676366572_alpha_2.161259415112308_result.json
# i = 0 quantile: omega_gw    2.331226e-08
# phi0_gw     3.238877e-04
# psi_gw      2.318398e-04
# delta_gw    2.220550e-01
# alpha_gw    4.356803e-01
# Name: 0.0, dtype: float64 omega_gw    3.253426e-08
# phi0_gw     1.457099e+00
# psi_gw      3.140665e+00
# delta_gw    1.553643e+00
# alpha_gw    3.141587e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.8374274996035685e-09_phi0_1.4324569515474825_psi_1.7355691946078058_delta_0.36468491083622784_alpha_0.08977469440023926_result.json
# i = 0 quantile: omega_gw    1.004233e-09
# phi0_gw     1.033863e-03
# psi_gw      2.988791e-04
# delta_gw    8.400991e-05
# alpha_gw    7.695985e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570013
# psi_gw      3.140665
# delta_gw    1.570786
# alpha_gw    3.137138
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_2.8654562047051794e-08_phi0_0.06656660380266309_psi_0.8456603362650738_delta_0.3505687139896359_alpha_0.19113162189638613_result.json
# i = 0 quantile: omega_gw    1.025925e-09
# phi0_gw     7.750314e-06
# psi_gw      3.874152e-02
# delta_gw    6.177631e-03
# alpha_gw    3.362640e-02
# Name: 0.0, dtype: float64 omega_gw    0.000007
# phi0_gw     1.570765
# psi_gw      3.125575
# delta_gw    1.543438
# alpha_gw    3.116777
# Name: 1.0, dtype: float64
# ...
# psi_gw      3.141548
# delta_gw    1.568355
# alpha_gw    3.141466
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_7.347438117269556e-07_phi0_0.31188151158942934_psi_0.9005478585643093_delta_1.4103236710295792_alpha_0.7769858852018838_result.json
# i = 0 quantile: omega_gw    7.315731e-07
# phi0_gw     2.829935e-03
# psi_gw      4.385352e-01
# delta_gw    7.058799e-01
# alpha_gw    1.407070e+00
# Name: 0.0, dtype: float64 omega_gw    7.425933e-07
# phi0_gw     1.511985e+00
# psi_gw      2.295886e+00
# delta_gw    1.397433e+00
# alpha_gw    3.094619e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_7.350198364258075e-09_phi0_1.4799956762762352_psi_2.05981215450648_delta_0.12928276419306048_alpha_0.1432771751965867_result.json
# i = 0 quantile: omega_gw    1.007474e-09
# phi0_gw     7.510994e-04
# psi_gw      6.742382e-04
# delta_gw    8.545731e-04
# alpha_gw    5.329503e-05
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570474
# psi_gw      3.140244
# delta_gw    1.570113
# alpha_gw    3.140534
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_7.487360516252364e-09_phi0_0.9370299722889202_psi_2.0353686345176216_delta_0.7459061822685881_alpha_0.9974813716119564_result.json
# i = 0 quantile: omega_gw    1.000480e-09
# phi0_gw     1.663974e-03
# psi_gw      1.713361e-02
# delta_gw    1.242827e-02
# alpha_gw    3.074919e-05
# Name: 0.0, dtype: float64 omega_gw    0.000009
# phi0_gw     1.570479
# psi_gw      3.139178
# delta_gw    1.569587
# alpha_gw    3.136018
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_7.582202856840321e-09_phi0_1.185010950710902_psi_0.17176703491010606_delta_0.2617375203029598_alpha_3.054567771085707_result.json
# i = 0 quantile: omega_gw    1.000175e-09
# phi0_gw     1.422862e-04
# psi_gw      5.920765e-04
# delta_gw    7.926041e-05
# alpha_gw    2.011782e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.568704
# psi_gw      3.141066
# delta_gw    1.570219
# alpha_gw    3.141449
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_7.701156118541654e-08_phi0_1.4098281583300942_psi_2.4818779016214303_delta_0.6244391628588539_alpha_1.2443264191572767_result.json
# i = 0 quantile: omega_gw    7.370005e-08
# phi0_gw     3.866151e-01
# psi_gw      1.856933e+00
# delta_gw    8.605740e-01
# alpha_gw    1.097446e-06
# Name: 0.0, dtype: float64 omega_gw    8.056335e-08
# phi0_gw     1.569752e+00
# psi_gw      3.025947e+00
# delta_gw    1.456289e+00
# alpha_gw    1.220561e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_7.784099042063748e-09_phi0_0.40654692991942804_psi_1.2118347530248799_delta_0.9485665200549284_alpha_0.27226244907613406_result.json
# i = 0 quantile: omega_gw    1.000075e-09
# phi0_gw     1.767893e-04
# psi_gw      2.027783e-03
# delta_gw    1.493307e-03
# alpha_gw    3.715890e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570274
# psi_gw      3.141019
# delta_gw    1.570294
# alpha_gw    3.140507
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_7.902921322350652e-07_phi0_0.28263760012869027_psi_0.6683624368906577_delta_0.15977002418081904_alpha_1.0508398514282518_result.json
# i = 0 quantile: omega_gw    7.902908e-07
# phi0_gw     1.730473e-02
# psi_gw      4.699720e-01
# delta_gw    8.453380e-01
# alpha_gw    5.224627e-05
# Name: 0.0, dtype: float64 omega_gw    7.957831e-07
# phi0_gw     1.021131e+00
# psi_gw      1.189954e+00
# delta_gw    1.369572e+00
# alpha_gw    7.061617e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_7.918753915897424e-09_phi0_0.9028798696593778_psi_0.8301768550580249_delta_1.0590422235123909_alpha_2.9731239494274_result.json
# i = 0 quantile: omega_gw    1.001084e-09
# phi0_gw     6.498298e-04
# psi_gw      2.582152e-03
# delta_gw    3.474619e-04
# alpha_gw    2.790166e-05
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570711
# psi_gw      3.137089
# delta_gw    1.569623
# alpha_gw    3.140806
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.08265034368483e-08_phi0_0.23847366588636823_psi_0.8873167840034366_delta_1.5506652149335756_alpha_2.0331767629630204_result.json
# i = 0 quantile: omega_gw    7.849599e-08
# phi0_gw     5.653460e-04
# psi_gw      4.207564e-03
# delta_gw    1.217762e+00
# alpha_gw    6.140494e-01
# Name: 0.0, dtype: float64 omega_gw    8.565493e-08
# phi0_gw     1.124363e+00
# psi_gw      2.635679e+00
# delta_gw    1.570690e+00
# alpha_gw    3.141584e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.248836779232551e-09_phi0_1.2417560296763162_psi_2.9221745345001624_delta_1.5314612266557484_alpha_0.817743619808429_result.json
# i = 0 quantile: omega_gw    1.000678e-09
# phi0_gw     3.582874e-05
# psi_gw      2.012620e-03
# delta_gw    2.713229e-05
# alpha_gw    3.781760e-03
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570719
# psi_gw      3.140394
# delta_gw    1.570748
# alpha_gw    3.139070
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.411530053514068e-09_phi0_1.0862563212822232_psi_0.16410131153103916_delta_1.1956571100971851_alpha_1.0699061962991367_result.json
# i = 0 quantile: omega_gw    1.000589e-09
# phi0_gw     2.891512e-04
# psi_gw      8.116839e-04
# delta_gw    2.817201e-04
# alpha_gw    5.770751e-06
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570617
# psi_gw      3.141289
# delta_gw    1.567263
# alpha_gw    3.141077
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.430628718103953e-07_phi0_0.2081982574823419_psi_2.3332394318071152_delta_0.6506564558711404_alpha_0.41761104154590367_result.json
# i = 0 quantile: omega_gw    5.350748e-08
# phi0_gw     1.931075e-04
# psi_gw      6.783329e-02
# delta_gw    1.577297e-01
# alpha_gw    8.653279e-01
# Name: 0.0, dtype: float64 omega_gw    8.506726e-07
# phi0_gw     1.225087e+00
# psi_gw      2.741829e+00
# delta_gw    1.160925e+00
# alpha_gw    2.889591e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.472662749113746e-07_phi0_0.027202754598777776_psi_0.5023643553385262_delta_0.04275823611883162_alpha_0.9191992862707973_result.json
# i = 0 quantile: omega_gw    8.455888e-07
# phi0_gw     6.106180e-04
# psi_gw      1.690356e-01
# delta_gw    7.753949e-01
# alpha_gw    1.868790e-04
# Name: 0.0, dtype: float64 omega_gw    8.538193e-07
# phi0_gw     1.131856e+00
# psi_gw      2.932129e+00
# delta_gw    1.570565e+00
# alpha_gw    2.599808e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.495589983933578e-07_phi0_0.4286047820589582_psi_0.30303654612853187_delta_0.9747263928915351_alpha_2.9894434619696164_result.json
# i = 0 quantile: omega_gw    1.000814e-09
# phi0_gw     1.241000e-03
# psi_gw      7.803491e-04
# delta_gw    1.262286e-03
# alpha_gw    1.185113e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.569278
# psi_gw      3.141055
# delta_gw    1.569759
# alpha_gw    3.141172
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.550348088140648e-07_phi0_0.4105470745739856_psi_2.665110894203398_delta_1.051362254449979_alpha_2.473525524669777_result.json
# i = 0 quantile: omega_gw    8.471735e-07
# phi0_gw     3.788607e-03
# psi_gw      1.972782e-01
# delta_gw    6.871593e-01
# alpha_gw    1.148903e+00
# Name: 0.0, dtype: float64 omega_gw    8.577136e-07
# phi0_gw     1.443802e+00
# psi_gw      1.066604e+00
# delta_gw    1.146737e+00
# alpha_gw    1.860073e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.682179230529094e-08_phi0_0.2965345301035458_psi_1.9316105643717592_delta_0.4725192017117574_alpha_0.7095901051887533_result.json
# i = 0 quantile: omega_gw    8.138885e-08
# phi0_gw     6.356611e-04
# psi_gw      1.559732e+00
# delta_gw    3.152970e-01
# alpha_gw    1.042044e-02
# Name: 0.0, dtype: float64 omega_gw    9.048749e-08
# phi0_gw     1.324123e+00
# psi_gw      2.462405e+00
# delta_gw    1.105677e+00
# alpha_gw    1.123244e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.743725997942375e-08_phi0_1.3541923953248967_psi_0.1572643338737073_delta_1.1316070389850352_alpha_1.3036223134820046_result.json
# i = 0 quantile: omega_gw    8.093192e-08
# phi0_gw     1.831114e-01
# psi_gw      8.396506e-01
# delta_gw    5.091494e-01
# alpha_gw    1.993290e-04
# Name: 0.0, dtype: float64 omega_gw    9.134028e-08
# phi0_gw     1.558131e+00
# psi_gw      2.914587e+00
# delta_gw    1.192484e+00
# alpha_gw    2.559954e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.778988640933124e-07_phi0_0.1767413567723127_psi_1.9280979334211843_delta_1.551042420077039_alpha_1.693723739950981_result.json
# i = 0 quantile: omega_gw    8.751158e-07
# phi0_gw     1.342559e-07
# psi_gw      8.547540e-01
# delta_gw    2.931894e-05
# alpha_gw    1.835490e-01
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.001837
# psi_gw      2.563792
# delta_gw    0.488054
# alpha_gw    2.807640
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.958190612847977e-08_phi0_1.2987723478023017_psi_0.5097476548933974_delta_1.4387430044402916_alpha_0.8473473516703847_result.json
# i = 0 quantile: omega_gw    8.319838e-08
# phi0_gw     3.961592e-01
# psi_gw      1.177698e-01
# delta_gw    2.988254e-01
# alpha_gw    1.128422e+00
# Name: 0.0, dtype: float64 omega_gw    9.131433e-08
# phi0_gw     1.568628e+00
# psi_gw      8.634187e-01
# delta_gw    1.011447e+00
# alpha_gw    1.880576e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_8.964274334254249e-08_phi0_1.470976685009514_psi_1.3869679501421404_delta_1.1910452449192659_alpha_1.9548276849371171_result.json
# i = 0 quantile: omega_gw    8.444525e-08
# phi0_gw     5.008065e-01
# psi_gw      3.538525e-04
# delta_gw    5.067160e-01
# alpha_gw    1.103328e+00
# Name: 0.0, dtype: float64 omega_gw    9.232974e-08
# phi0_gw     1.570501e+00
# psi_gw      3.141188e+00
# delta_gw    1.568657e+00
# alpha_gw    3.141577e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_9.075512824845505e-08_phi0_1.5108533092909757_psi_2.8154733586516354_delta_0.20944743306039254_alpha_3.1259204551218844_result.json
# i = 0 quantile: omega_gw    8.655079e-08
# phi0_gw     4.654362e-01
# psi_gw      9.560717e-02
# delta_gw    4.916124e-05
# alpha_gw    2.818470e-02
# Name: 0.0, dtype: float64 omega_gw    9.398165e-08
# phi0_gw     1.570616e+00
# psi_gw      3.006550e+00
# delta_gw    8.298522e-01
# alpha_gw    3.141583e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_9.156156512981495e-08_phi0_0.4035542230220416_psi_2.509174431455965_delta_1.2789729697232641_alpha_2.7053857628278313_result.json
# i = 0 quantile: omega_gw    8.762921e-08
# phi0_gw     2.364188e-02
# psi_gw      5.894172e-01
# delta_gw    2.161613e-05
# alpha_gw    6.972385e-05
# Name: 0.0, dtype: float64 omega_gw    9.868389e-08
# phi0_gw     1.570075e+00
# psi_gw      1.900965e+00
# delta_gw    8.907061e-01
# alpha_gw    2.873587e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_9.27206283438795e-07_phi0_0.5964782033439929_psi_0.42649993965670274_delta_0.25459357945193045_alpha_1.9075541007952324_result.json
# i = 0 quantile: omega_gw    9.209882e-07
# phi0_gw     1.263359e-04
# psi_gw      8.501601e-05
# delta_gw    7.176197e-01
# alpha_gw    7.558761e-01
# Name: 0.0, dtype: float64 omega_gw    9.320452e-07
# phi0_gw     1.139006e+00
# psi_gw      3.053992e+00
# delta_gw    1.570285e+00
# alpha_gw    3.141354e+00
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_9.462622684717936e-09_phi0_1.0614043618355617_psi_0.11999354936463888_delta_1.2135605664621985_alpha_1.0537800114082654_result.json
# i = 0 quantile: omega_gw    1.176703e-09
# phi0_gw     3.759697e-03
# psi_gw      1.061509e-02
# delta_gw    1.816956e-01
# alpha_gw    1.458987e-03
# Name: 0.0, dtype: float64 omega_gw    0.000002
# phi0_gw     1.570109
# psi_gw      3.141514
# delta_gw    1.555156
# alpha_gw    2.723330
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_9.499712960606028e-08_phi0_0.825328168627241_psi_2.4541556080529627_delta_1.2691229968237923_alpha_2.7494640012193385_result.json
# i = 0 quantile: omega_gw    9.061511e-08
# phi0_gw     2.957858e-01
# psi_gw      8.679692e-01
# delta_gw    1.863897e-07
# alpha_gw    1.478604e-03
# Name: 0.0, dtype: float64 omega_gw    1.003390e-07
# phi0_gw     1.569026e+00
# psi_gw      1.233952e+00
# delta_gw    1.239130e-01
# alpha_gw    9.336643e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_9.550497431775752e-09_phi0_1.4299956469728887_psi_0.055836994329762135_delta_1.1848300573164832_alpha_2.193628263484705_result.json
# i = 0 quantile: omega_gw    1.003840e-09
# phi0_gw     6.833242e-04
# psi_gw      4.089642e-04
# delta_gw    6.466016e-06
# alpha_gw    1.099115e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570536
# psi_gw      3.140923
# delta_gw    1.570578
# alpha_gw    3.141588
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_9.555753900942095e-09_phi0_1.279040355293265_psi_0.9666243047976358_delta_0.25432532904140753_alpha_0.08765623858518368_result.json
# i = 0 quantile: omega_gw    1.000662e-09
# phi0_gw     6.495391e-04
# psi_gw      2.694925e-04
# delta_gw    7.909844e-05
# alpha_gw    1.163055e-04
# Name: 0.0, dtype: float64 omega_gw    0.000010
# phi0_gw     1.570564
# psi_gw      3.141358
# delta_gw    1.570340
# alpha_gw    3.139535
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_9.631144082240518e-09_phi0_0.1307216872480581_psi_3.097124939087503_delta_0.56523405613663_alpha_0.42953387274077726_result.json
# i = 0 quantile: omega_gw    1.000999e-09
# phi0_gw     1.469515e-04
# psi_gw      3.264067e-04
# delta_gw    2.097996e-01
# alpha_gw    1.973436e-01
# Name: 0.0, dtype: float64 omega_gw    1.638895e-08
# phi0_gw     1.570779e+00
# psi_gw      3.140428e+00
# delta_gw    6.438679e-01
# alpha_gw    8.270773e-01
# Name: 1.0, dtype: float64
# ../data/nested_sampling/data_for_manuscript/pp_plots_small_h/pp_plot_h_5e-15_model_earth_seed_1237_omega_9.80037828434754e-08_phi0_0.9417476945947276_psi_2.1080358816286155_delta_1.1408523015246115_alpha_0.35065422612579733_result.json
# i = 0 quantile: omega_gw    9.473751e-08
# phi0_gw     6.953901e-04
# psi_gw      1.383396e+00
# delta_gw    1.288372e-04
# alpha_gw    7.929178e-01
# Name: 0.0, dtype: float64 omega_gw    1.021868e-07
# phi0_gw     1.174012e+00
# psi_gw      2.244308e+00
# delta_gw    5.454813e-01
# alpha_gw    1.897699e+00
# Name: 1.0, dtype: float64
# CPU times: user 6min 56s, sys: 22.9 s, total: 7min 19s
# Wall time: 7min 22s

# %%
df_quantile
# Out:
#           omega_gw   phi0_gw    psi_gw  delta_gw  alpha_gw
# 0.00  9.903419e-08  0.101878  2.190582  1.249435  2.321323
# 0.05  1.011847e-07  0.467998  2.452548  1.308175  2.651319
# 0.10  1.015339e-07  0.524012  2.499733  1.321957  2.701743
# 0.15  1.017347e-07  0.560480  2.532750  1.330377  2.737758
# 0.20  1.018902e-07  0.588531  2.564103  1.337566  2.769016
# 0.25  1.020192e-07  0.612061  2.594278  1.343195  2.796363
# 0.30  1.021412e-07  0.635266  2.621069  1.348378  2.821611
# 0.35  1.022510e-07  0.655280  2.646126  1.351929  2.846029
# 0.40  1.023643e-07  0.675098  2.670299  1.355673  2.869908
# 0.45  1.024601e-07  0.693751  2.695377  1.358879  2.892243
# 0.50  1.025641e-07  0.711606  2.725701  1.362037  2.923382
# 0.55  1.026616e-07  0.727601  2.767679  1.365130  2.964254
# 0.60  1.027623e-07  0.745638  2.809755  1.367602  3.034217
# 0.65  1.028642e-07  0.764306  2.834000  1.369223  3.056307
# 0.70  1.029741e-07  0.783977  2.850868  1.370428  3.071706
# 0.75  1.030883e-07  0.804327  2.866916  1.371762  3.084782
# 0.80  1.032238e-07  0.830445  2.882657  1.373154  3.096157
# 0.85  1.033735e-07  0.857378  2.898222  1.374634  3.107343
# 0.90  1.035507e-07  0.895121  2.914392  1.376487  3.118850
# 0.95  1.038300e-07  0.947595  2.933117  1.379921  3.130114
# 1.00  1.060080e-07  1.260344  3.025393  1.396771  3.141494

# %%
quantiles = np.arange(0,1.0,0.05) #[0.05,0.95] #90 per cent quantiles 
quantiles = np.append(quantiles,1.0) #quantiles.append(1.0)
for i in range(1,int(len(quantiles)/2)):
    print("quantiles", i,quantiles[i], quantiles[-i-1],quantiles[-i-1] -quantiles[i])

    # lower_limit = df_quantile.iloc[i] 
    # upper_limit = df_quantile.iloc[-i-1] 

    # print(i,lower_limit["omega_gw"],upper_limit["omega_gw"])
# Out:
# quantiles 1 0.05 0.9500000000000001 0.9
# quantiles 2 0.1 0.9 0.8
# quantiles 3 0.15000000000000002 0.8500000000000001 0.7000000000000001
# quantiles 4 0.2 0.8 0.6000000000000001
# quantiles 5 0.25 0.75 0.5
# quantiles 6 0.30000000000000004 0.7000000000000001 0.4
# quantiles 7 0.35000000000000003 0.65 0.3
# quantiles 8 0.4 0.6000000000000001 0.20000000000000007
# quantiles 9 0.45 0.55 0.10000000000000003

# %%
df_quantile
# Out:
#           omega_gw   phi0_gw    psi_gw  delta_gw  alpha_gw
# 0.00  9.473751e-08  0.000695  1.383396  0.000129  0.792918
# 0.05  9.606490e-08  0.157644  1.733701  0.036713  1.036512
# 0.10  9.644945e-08  0.219911  1.775966  0.059823  1.072184
# 0.15  9.671623e-08  0.266403  1.804091  0.077665  1.097268
# 0.20  9.692526e-08  0.301811  1.824927  0.093616  1.117820
# 0.25  9.709342e-08  0.331164  1.846043  0.109597  1.135612
# 0.30  9.724903e-08  0.359110  1.862359  0.124151  1.149473
# 0.35  9.739003e-08  0.384281  1.877656  0.137782  1.163410
# 0.40  9.754183e-08  0.410425  1.892284  0.152138  1.176327
# 0.45  9.770319e-08  0.435395  1.905421  0.164837  1.188129
# 0.50  9.784170e-08  0.459910  1.918432  0.178228  1.200680
# 0.55  9.798410e-08  0.481830  1.930649  0.192999  1.212832
# 0.60  9.813051e-08  0.509360  1.943403  0.206117  1.226622
# 0.65  9.829354e-08  0.534752  1.958391  0.220370  1.239303
# 0.70  9.844848e-08  0.561297  1.970760  0.234862  1.250646
# 0.75  9.862081e-08  0.592789  1.986187  0.250918  1.264203
# 0.80  9.881813e-08  0.628181  2.004706  0.268384  1.278235
# 0.85  9.902480e-08  0.668292  2.024642  0.288945  1.297451
# 0.90  9.931252e-08  0.720560  2.048881  0.313303  1.319064
# 0.95  9.968057e-08  0.798356  2.085025  0.350741  1.354585
# 1.00  1.021868e-07  1.174012  2.244308  0.545481  1.897699

# %%
for i in range(1,int(len(qnew)/2)):
    print("quantiles", i,qnew[i], qnew[-i],qnew[-i] -qnew[i])
# Out:
# quantiles 1 0.05 1.0 0.95
# quantiles 2 0.1 0.9500000000000001 0.8500000000000001
# quantiles 3 0.15000000000000002 0.9 0.75
# quantiles 4 0.2 0.8500000000000001 0.6500000000000001
# quantiles 5 0.25 0.8 0.55
# quantiles 6 0.30000000000000004 0.75 0.44999999999999996
# quantiles 7 0.35000000000000003 0.7000000000000001 0.35000000000000003
# quantiles 8 0.4 0.65 0.25
# quantiles 9 0.45 0.6000000000000001 0.15000000000000008

# %%
quantiles_new = np.delete(quantiles, 10, axis=0)

# %%
for i in range(int(len(quantiles_new)/2)):
    print("quantiles", i,quantiles_new[i], quantiles_new[-i],quantiles_new[-i] -quantiles_new[i])
# Out:
# quantiles 0 0.0 0.0 0.0
# quantiles 1 0.05 1.0 0.95
# quantiles 2 0.1 0.9500000000000001 0.8500000000000001
# quantiles 3 0.15000000000000002 0.9 0.75
# quantiles 4 0.2 0.8500000000000001 0.6500000000000001
# quantiles 5 0.25 0.8 0.55
# quantiles 6 0.30000000000000004 0.75 0.44999999999999996
# quantiles 7 0.35000000000000003 0.7000000000000001 0.35000000000000003
# quantiles 8 0.4 0.65 0.25
# quantiles 9 0.45 0.6000000000000001 0.15000000000000008

# %%
for i in range(int(len(quantiles)/2)):
    print(quantiles[i], quantiles[-i],quantiles[-i] -quantiles[i])
# Out:
# 0.0 0.0 0.0
# 0.05 0.9500000000000001 0.9
# 0.1 0.9 0.8
# 0.15000000000000002 0.8500000000000001 0.7000000000000001
# 0.2 0.8 0.6000000000000001
# 0.25 0.75 0.5
# 0.30000000000000004 0.7000000000000001 0.4
# 0.35000000000000003 0.65 0.3
# 0.4 0.6000000000000001 0.20000000000000007
# 0.45 0.55 0.10000000000000003

# %%
# %%time
q90_results/10
# Out:
# CPU times: user 29 µs, sys: 0 ns, total: 29 µs
# Wall time: 32.9 µs
# array([0.6, 0.9, 0.6, 0.4, 0.4])

# %%
q90_results/200
# Out:
# array([0.865, 0.75 , 0.65 , 0.44 , 0.565])

# %%
dtmp.loc[0.05]
# Out:
# omega_gw    5.666316e-09
# phi0_gw     2.301482e-01
# psi_gw      2.079523e+00
# delta_gw    8.373452e-01
# alpha_gw    6.737613e-02
# Name: 0.05, dtype: float64

# %%
dtmp
# Out:
#           omega_gw   phi0_gw    psi_gw  delta_gw  alpha_gw
# 0.05  5.666316e-09  0.230148  2.079523  0.837345  0.067376
# 0.95  1.428526e-08  1.172421  2.665543  1.106143  0.681643

# %%
    

#injection_parameters
# Out:
# omega_gw 1.0230135211683393e-08 5.666316125013677e-09 1.4285261253409139e-08
# phi0_gw 0.3704171536650886 0.2301482451910942 1.1724207206342971
# psi_gw 2.8305556812996406 2.079523434354083 2.6655429408612705
# delta_gw 0.8065654642127479 0.8373452248734071 1.1061434585674124
# alpha_gw 1.296128240812015 0.06737613287043862 0.6816429849159905

# %%
lower_limit
# Out:
# omega_gw    5.666316e-09
# phi0_gw     2.301482e-01
# psi_gw      2.079523e+00
# delta_gw    8.373452e-01
# alpha_gw    6.737613e-02
# Name: 0.05, dtype: float64

# %% [markdown]
# # Plot a specific result
