# %% [markdown]
# # What do our likelihood surfaces look like?
#
# Bayes:
#
# $$ p(\theta | d) \propto p(d|\theta) \pi(\theta)$$
#
# For a uniform prior, the posterior will look like the likelihood, modulo a normalization factor.
#
# Lets see what some of our univariate likelihood curves look like (i.e. holding all other parameters constant)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
try:
    sys.path.remove("../../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../../py_src") # Means that I dont have to make src/ a proper python package

# %%
from system_parameters import SystemParameters
from pulsars import Pulsars

from synthetic_data import SyntheticData
from plotting import plot_statespace,plot_all
from model import LinearModel
from kalman_filter import KalmanFilter
from bilby_wrapper import BilbySampler
from priors import priors_dict,bilby_priors_dict

# %% [markdown]
# ### 1. Example system

# %%
import numpy as np 
import logging 

logger = logging.getLogger().setLevel(logging.ERROR)

def iterate_over_parameter(parameter_name,parameter_value,measurement_model,seed):

    P    = SystemParameters(h=5e-15,σp=None,σm=1e-11,measurement_model=measurement_model,seed=seed)       #define the system parameters as a class
    PTA  = Pulsars(P)               # setup the PTA
    data = SyntheticData(PTA,P) # generate some synthetic data

    #Define the model 
    model = LinearModel(P)

    #Initialise the Kalman filter
    KF = KalmanFilter(model,data.f_measured,PTA)

    # Run the KFwith the correct parameters
    true_parameters = priors_dict(PTA,P)
    true_parameters[parameter_name] = parameter_value
    print(parameter_name,parameter_value)

    model_likelihood, model_state_predictions_x,model_state_predictions_y = KF.likelihood(true_parameters)
    print(model_likelihood)

    return model_likelihood

# %% [markdown]
# # Omega

# %%
parameter_name = "omega"

N = 100
parameter_range = np.logspace(-9,-6,N)
measurement_model = 'earth'
seed = 1230
likelihoods = np.zeros(N)
for i in range(N):
    likelihoods[i] = iterate_over_parameter(parameter_name,parameter_range[i],measurement_model,seed)
# Out:
# omega 1e-09
# 585686.6848098991
# omega 1.0722672220103253e-09
# 585686.6848098991
# omega 1.1497569953977357e-09
# 585686.6848098991
# omega 1.2328467394420684e-09
# 585686.6848098991
# omega 1.3219411484660288e-09
# 585686.6848098991
# omega 1.4174741629268078e-09
# 585686.6848098991
# omega 1.519911082952933e-09
# 585686.6848098991
# omega 1.6297508346206469e-09
# 585686.6848098991
# omega 1.747528400007683e-09
# 585686.6848098991
# omega 1.873817422860387e-09
# 585686.6848098991
# omega 2.009233002565046e-09
# 585686.6848098991
# omega 2.1544346900318866e-09
# 585686.6848098991
# omega 2.310129700083158e-09
# 585686.6848098991
# omega 2.4770763559917138e-09
# 585686.6848098991
# omega 2.656087782946684e-09
# 585686.6848098991
# omega 2.848035868435805e-09
# 585686.6848098991
# omega 3.0538555088334124e-09
# 585686.6848098991
# omega 3.2745491628777316e-09
# 585686.6848098991
# omega 3.5111917342151273e-09
# 585686.6848098991
# omega 3.764935806792472e-09
# 585686.6848098991
# omega 4.0370172585965495e-09
# 585686.6848098991
# omega 4.328761281083061e-09
# 585686.6848098991
# omega 4.641588833612773e-09
# 585686.6848098991
# omega 4.977023564332114e-09
# 585686.6848098991
# omega 5.336699231206302e-09
# 585686.6848098991
# omega 5.72236765935022e-09
# 585686.6848098991
# omega 6.135907273413163e-09
# 585686.6848098991
# omega 6.579332246575682e-09
# 585686.6848098991
# omega 7.054802310718631e-09
# 585686.6848098991
# omega 7.56463327554629e-09
# 585686.6848098991
# omega 8.11130830789689e-09
# 585686.6848098991
# omega 8.697490026177834e-09
# 585686.6848098991
# omega 9.32603346883218e-09
# 585686.6848098991
# omega 1e-08
# 585686.6848098991
# omega 1.0722672220103231e-08
# 585686.6848098991
# omega 1.1497569953977357e-08
# 585686.6848098991
# omega 1.232846739442066e-08
# 585686.6848098991
# omega 1.3219411484660288e-08
# 585686.6848098991
# omega 1.4174741629268047e-08
# 585686.6848098991
# omega 1.519911082952933e-08
# 585686.6848098991
# omega 1.6297508346206433e-08
# 585686.6848098991
# omega 1.747528400007683e-08
# 585686.6848098991
# omega 1.873817422860383e-08
# 585686.6848098991
# omega 2.009233002565046e-08
# 585686.6848098991
# omega 2.1544346900318866e-08
# 585686.6848098991
# omega 2.310129700083158e-08
# 585686.6848098991
# omega 2.4770763559917138e-08
# 585686.6848098991
# omega 2.656087782946684e-08
# 585686.6848098991
# omega 2.848035868435805e-08
# 585686.6848098991
# omega 3.053855508833412e-08
# 585686.6848098991
# omega 3.274549162877732e-08
# 585686.6848098991
# omega 3.5111917342151277e-08
# 585686.6848098991
# omega 3.7649358067924714e-08
# 585686.6848098991
# omega 4.037017258596558e-08
# 585686.6848098991
# omega 4.328761281083061e-08
# 585686.6848098991
# omega 4.641588833612782e-08
# 585686.6848098991
# omega 4.977023564332114e-08
# 585686.6848098991
# omega 5.3366992312063125e-08
# 585686.6848098991
# omega 5.72236765935022e-08
# 585686.6848098991
# omega 6.135907273413176e-08
# 585686.6848098991
# omega 6.579332246575682e-08
# 585686.6848098991
# omega 7.054802310718646e-08
# 585686.6848098991
# omega 7.56463327554629e-08
# 585686.6848098991
# omega 8.111308307896873e-08
# 585686.6848098991
# omega 8.697490026177834e-08
# 585686.6848098991
# omega 9.3260334688322e-08
# 585686.6848098991
# omega 1e-07
# 585686.6848098991
# omega 1.0722672220103232e-07
# 585686.6848098991
# omega 1.1497569953977356e-07
# 585686.6848098991
# omega 1.232846739442066e-07
# 585686.6848098991
# omega 1.3219411484660288e-07
# 585686.6848098991
# omega 1.417474162926805e-07
# 585686.6848098991
# omega 1.519911082952933e-07
# 585686.6848098991
# omega 1.6297508346206468e-07
# 585686.6848098991
# omega 1.747528400007683e-07
# 585686.6848098991
# omega 1.8738174228603868e-07
# 585686.6848098991
# omega 2.009233002565046e-07
# 585686.6848098991
# omega 2.1544346900318867e-07
# 585686.6848098991
# omega 2.310129700083158e-07
# 585686.6848098991
# omega 2.477076355991714e-07
# 585686.6848098991
# omega 2.656087782946684e-07
# 585686.6848098991
# omega 2.848035868435805e-07
# 585686.6848098991
# omega 3.0538555088334124e-07
# 585686.6848098991
# omega 3.2745491628777317e-07
# 585686.6848098991
# omega 3.5111917342151277e-07
# 585686.6848098991
# omega 3.764935806792471e-07
# 585686.6848098991
# omega 4.0370172585965496e-07
# 585686.6848098991
# omega 4.3287612810830616e-07
# 585686.6848098991
# omega 4.641588833612782e-07
# 585686.6848098991
# omega 4.977023564332114e-07
# 585686.6848098991
# omega 5.336699231206313e-07
# 585686.6848098991
# omega 5.722367659350221e-07
# 585686.6848098991
# omega 6.135907273413176e-07
# 585686.6848098991
# omega 6.579332246575682e-07
# 585686.6848098991
# omega 7.054802310718645e-07
# 585686.6848098991
# omega 7.564633275546291e-07
# 585686.6848098991
# omega 8.111308307896872e-07
# 585686.6848098991
# omega 8.697490026177835e-07
# 585686.6848098991
# omega 9.326033468832199e-07
# 585686.6848098991
# omega 1e-06
# 585686.6848098991

# %%
import matplotlib.pyplot as plt 
import scienceplots

plt.style.use('science')
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

ax.plot(parameter_range,likelihoods,linestyle = 'solid')

# %% [markdown]
# # Delta

# %%
import matplotlib.pyplot as plt 
import scienceplots



plt.style.use('science')
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)


for i in range(len(seeds)):
    print(i)
    ypulsar = yc_pulsar[:,i]
    yearth = yc_earth[:,i]

    #Normalise
    ypulsar = ypulsar / np.abs(np.max(ypulsar))
    yearth = yearth / np.abs(np.max(yearth))
    #yearth = yearth + 2.0 



    psr_color = 'C0'
    earth_color = 'C2'
    ax.plot(x,ypulsar,linestyle = 'solid',c=psr_color)
    ax.plot(x,yearth,linestyle = 'solid',c=earth_color)





    idx_psr = np.argmax(ypulsar)
    xc_psr = x[idx_psr]
    ax.axvline(xc_psr,c=psr_color,linestyle='--')


    idx_earth = np.argmax(yearth)
    xc_earth = x[idx_earth]

    #ax.plot([xc_earth,xc_earth],[np.min(yc_earth),np.max(yc_earth)])

    ax.axvline(xc_earth,c=earth_color,linestyle='--')



#plt.axvline(1.0,c='C2',linestyle='--')






fs = 20
ax.set_xlabel(r'$\Phi_0$', fontsize=fs)
ax.set_ylabel(r'$\log \mathcal{L}$', fontsize=fs)

ax.xaxis.set_tick_params(labelsize=fs-4)
ax.yaxis.set_tick_params(labelsize=fs-4)

#ax.yaxis.set_major_locator(plt.MaxNLocator(5))
#plt.setp(ax.get_yticklabels()[0], visible=False)   #no 0th label to prevent overlap  


savefig = 'phi0_likelihood_surface'
plt.savefig(f"../data/images/{savefig}.png", bbox_inches="tight",dpi=300)
# Out:
# 0

# %%
plot_data_dict(parameters_dict,loaded_data,true_parameters)

# %%
variable = 'iota_gw'
variable_range = np.arange(0,np.pi/2.0,0.1)
iota_likelihoods = get_likelihood_instance(P,PTA,data,variable,variable_range)

# %%
plt.plot(variable_range,iota_likelihoods)

# %%
selected_parameters = ["omega_gw",
                    "phi0_gw",
                       "psi_gw",
                        "iota_gw",
                        "delta_gw",
                        "alpha_gw",
                        "h"]
parameters_dict = {k: guessed_parameters[k] for k in selected_parameters}


nsamples = int(1e3)

priors = [np.logspace(-9,-5,nsamples),                   # omega
          np.linspace(0,2*np.pi,nsamples),               # psi
          np.linspace(0,2*np.pi,nsamples),               # phi0
          np.linspace(0,2*np.pi,nsamples),               # iota
          np.linspace(-np.pi/2.0,np.pi/2.0,nsamples),    # delta
          np.linspace(0,2*np.pi,nsamples),               # alpha
          np.logspace(-4,-1,nsamples),                   # h
]

from plotting import likelihoods_over_priors
#likelihoods_over_priors(parameters_dict,priors,PTA,P,KF)
likelihoods_over_priors(parameters_dict,priors,PTA,P,KF,"Likelihood curves, Earth terms, heterodyned", savefig=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb Cell 13 line <cell line: 8>()
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> selected_parameters = ["omega_gw",
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>                     "phi0_gw",
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>                        "psi_gw",
#    (...)
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>                         "alpha_gw",
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>                         "h"]
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> parameters_dict = {k: guessed_parameters[k] for k in selected_parameters}
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a> nsamples = int(1e3)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> priors = [np.logspace(-9,-5,nsamples),                   # omega
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a>           np.linspace(0,2*np.pi,nsamples),               # psi
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=14'>15</a>           np.linspace(0,2*np.pi,nsamples),               # phi0
#    (...)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=18'>19</a>           np.logspace(-4,-1,nsamples),                   # h
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=19'>20</a> ]
#
# /Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb Cell 13 line <dictcomp>(.0)
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> selected_parameters = ["omega_gw",
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>                     "phi0_gw",
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>                        "psi_gw",
#    (...)
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>                         "alpha_gw",
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>                         "h"]
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> parameters_dict = {k: guessed_parameters[k] for k in selected_parameters}
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a> nsamples = int(1e3)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> priors = [np.logspace(-9,-5,nsamples),                   # omega
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a>           np.linspace(0,2*np.pi,nsamples),               # psi
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=14'>15</a>           np.linspace(0,2*np.pi,nsamples),               # phi0
#    (...)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=18'>19</a>           np.logspace(-4,-1,nsamples),                   # h
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/complete_legacy_notebooks/A7.likelihood_terms_just_phi0.ipynb#X15sZmlsZQ%3D%3D?line=19'>20</a> ]
#
# NameError: name 'guessed_parameters' is not defined
