# %% [markdown]
# This notebook compares explores the use of a broader prior on the frequency

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %%
from plotting import plot_custom_corner

# %%
def plot_all_corners(path,seed,save_id,tol=0.01,npsr = 5):


    #default values of GW parameters
    ranges=[(4e-7*1e9,6e-7*1e9),(-np.pi,np.pi),(0.0+1.0,np.pi+1.0),(0.0,np.pi/2.0),(-np.pi/2 + 0.8,np.pi/2 + 0.8),(0.0,np.pi),(0.5e-12*1e12,1.5e-12*1e12)]
    injection_parameters = [5e-7*1e9,0.20,2.50,1.0,1.0,1.0,1e-12*1e12]
    labels = [r'$\Omega_{\rm nHz}$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10^{12}}$']
    variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
    axes_scales = None

    #Corner plot of GW parameters
    plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=f'{save_id}_GW')




    #Plot f0 
    pulsars = pd.read_csv("../data/NANOGrav_pulsars.csv")
    true_f = pulsars["F0"].to_numpy()
    labels = [rf'$f_{i}$' for i in range(npsr)]
    idx = len(labels)
    injection_parameters = true_f[0:idx]
    variables_to_plot = [rf'f{i:02d}' for i in range(npsr)]
    ranges = [(i-np.abs(i*tol),i+np.abs(i*tol)) for i in injection_parameters]
    axes_scales = None
    plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=f'{save_id}_f' )


    #Plot f1
    true_f = pulsars["F1"].to_numpy()

    labels = [r'$\dot{f}$' + rf'$_{i}$' for i in range(npsr)]
    idx = len(labels)
    injection_parameters = true_f[0:idx]
    variables_to_plot = [rf'fdot{i}' for i in range(npsr)] #["fdot0", "fdot1", "fdot2", "fdot3", "fdot4"]

    #tol = 0.01
    ranges = [(i-np.abs(i*tol),i+np.abs(i*tol)) for i in injection_parameters]
    axes_scales = None
    plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=f'{save_id}_fdot')


    #Plot sigma_p, log scaled
    generator = np.random.default_rng(seed)
    σp = generator.uniform(low = 1e-21,high=1e-19,size=len(true_f))

        
    labels = [r'$\sigma_p^0$',r'$\sigma_p^1$',r'$\sigma_p^2$',r'$\sigma_p^3$', r'$\sigma_p^4$']
    idx = len(labels)
    injection_parameters = σp[0:idx]
    variables_to_plot    = ["sigma_p0", "sigma_p1", "sigma_p2", "sigma_p3", "sigma_p4"]
    ranges = [(1e-22,1e-18) for i in injection_parameters]




    plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=f'{save_id}_sigma_p',logscale=True)

# %%
import numpy as np 


f ="../data/nested_sampling/data_for_manuscript/canonical_example_fprior_result.json"
plot_all_corners(f,1237,save_id=None)
# Out:
# json
# The evidence is: -664794.3212174099
#      omega_gw   phi0_gw    psi_gw   iota_gw  delta_gw  alpha_gw         h  \
# 0  500.001028  0.173187  2.403733  1.090623  0.763571  0.726050  1.254870
# 1  499.998786  0.172736  2.403393  0.817561  0.763681  0.725229  1.037308
# 2  500.000295  0.173530  2.403675  1.060556  0.763288  0.726552  1.227752
# 3  500.002575  0.174326  2.404909  1.099448  0.763148  0.727450  1.262169
# 4  500.004250  0.173234  2.403931  0.772344  0.763504  0.726177  1.005104
# 5  500.002364  0.172504  2.404444  1.081196  0.763210  0.727336  1.247050
#
#           f00         f01         f02  ...    distance40    distance41  \
# 0  329.727389  205.655283  300.124975  ...  6.000000e+10  1.800000e+11
# 1  330.531217  206.412553  301.721354  ...  6.000000e+10  1.800000e+11
# 2  330.941910  206.842127  303.461126  ...  6.000000e+10  1.800000e+11
# 3  329.722998  206.435644  304.213044  ...  6.000000e+10  1.800000e+11
# 4  330.452008  206.429425  301.761353  ...  6.000000e+10  1.800000e+11
# 5  330.820118  205.949674  302.132113  ...  6.000000e+10  1.800000e+11
#
#      distance42    distance43    distance44    distance45    distance46  \
# 0  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 1  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 2  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 3  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 5  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
#
#         sigma_m  log_likelihood    log_prior
# 0  1.000000e-11  -664664.046261  3866.759729
# 1  1.000000e-11  -664663.078478  3874.911692
# 2  1.000000e-11  -664662.852591  3891.824811
# 3  1.000000e-11  -664662.540683  3881.490957
# 4  1.000000e-11  -664662.144299  3874.720267
# 5  1.000000e-11  -664661.820893  3877.328158
#
# [6 rows x 245 columns]
# Number of samples:
# 6
# Truths/Medians/Variances
# $\Omega_{\rm nHz}$ 500.0 500.00169554083465 3.697804253017678e-06
# $\Phi_0$ 0.2 0.17321085199233738 4.1226646855622316e-07
# $\psi$ 2.5 2.4038320177512507 3.143092100047437e-07
# $\iota$ 1.0 1.070875690583071 0.02249042588394725
# $\delta$ 1.0 0.7633962822182199 4.617905271714928e-08
# $\alpha$ 1.0 0.726364471971472 7.040725553732078e-07
# $h_{0, \times 10^{12}}$ 1.0 1.2374008696254357 0.013946772593502538
# running with increased label size
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb Cell 6 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> f ="../data/nested_sampling/data_for_manuscript/canonical_example_fprior_result.json"
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> plot_all_corners(f,1237,save_id=None)
#
# /Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb Cell 6 in plot_all_corners(path, seed, save_id, tol, npsr)
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X35sZmlsZQ%3D%3D?line=8'>9</a> axes_scales = None
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X35sZmlsZQ%3D%3D?line=10'>11</a> #Corner plot of GW parameters
# ---> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X35sZmlsZQ%3D%3D?line=11'>12</a> plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=f'{save_id}_GW')
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X35sZmlsZQ%3D%3D?line=16'>17</a> #Plot f0
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X35sZmlsZQ%3D%3D?line=17'>18</a> pulsars = pd.read_csv("../data/NANOGrav_pulsars.csv")
#
# File ~/github_repos/StateSpacePTA/notebooks/../py_src/plotting.py:170, in plot_custom_corner(path, variables_to_plot, labels, injection_parameters, ranges, axes_scales, savefig, logscale, title)
#     168 print("running with increased label size")
#     169 fs = 20
# --> 170 fig = corner.corner(y_post,
#     171                     color='C0',
#     172                     show_titles=True,
#     173                     smooth=True,smooth1d=True,
#     174                     truth_color='C2',
#     175                     quantiles=[0.16, 0.84],
#     176                     truths = injection_parameters,
#     177                     range=ranges,
#     178                     labels = labels,
#     179                     label_kwargs=dict(fontsize=fs),
#     180                     axes_scales = axes_scales)
#     183 #Pretty-ify
#     184 for ax in fig.axes:
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/corner.py:256, in corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     222         logging.warning(
#     223             "Please install arviz to use the advanced features of corner"
#     224         )
#     226     return corner_impl(
#     227         data,
#     228         bins=bins,
#    (...)
#     253         **hist2d_kwargs,
#     254     )
# --> 256 return arviz_corner(
#     257     data,
#     258     bins=bins,
#     259     range=range,
#     260     weights=weights,
#     261     color=color,
#     262     hist_bin_factor=hist_bin_factor,
#     263     smooth=smooth,
#     264     smooth1d=smooth1d,
#     265     labels=labels,
#     266     label_kwargs=label_kwargs,
#     267     titles=titles,
#     268     show_titles=show_titles,
#     269     title_fmt=title_fmt,
#     270     title_kwargs=title_kwargs,
#     271     truths=truths,
#     272     truth_color=truth_color,
#     273     scale_hist=scale_hist,
#     274     quantiles=quantiles,
#     275     verbose=verbose,
#     276     fig=fig,
#     277     max_n_ticks=max_n_ticks,
#     278     top_ticks=top_ticks,
#     279     use_math_text=use_math_text,
#     280     reverse=reverse,
#     281     labelpad=labelpad,
#     282     hist_kwargs=hist_kwargs,
#     283     group=group,
#     284     var_names=var_names,
#     285     filter_vars=filter_vars,
#     286     coords=coords,
#     287     divergences=divergences,
#     288     divergences_kwargs=divergences_kwargs,
#     289     labeller=labeller,
#     290     **hist2d_kwargs,
#     291 )
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/arviz_corner.py:136, in arviz_corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     134 # Coerce the samples into the expected format
#     135 samples = np.stack([x[-1].flatten() for x in plotters], axis=-1)
# --> 136 fig = corner_impl(
#     137     samples,
#     138     bins=bins,
#     139     range=range,
#     140     weights=weights,
#     141     color=color,
#     142     hist_bin_factor=hist_bin_factor,
#     143     smooth=smooth,
#     144     smooth1d=smooth1d,
#     145     labels=labels,
#     146     label_kwargs=label_kwargs,
#     147     titles=titles,
#     148     show_titles=show_titles,
#     149     title_fmt=title_fmt,
#     150     title_kwargs=title_kwargs,
#     151     truths=truths,
#     152     truth_color=truth_color,
#     153     scale_hist=scale_hist,
#     154     quantiles=quantiles,
#     155     verbose=verbose,
#     156     fig=fig,
#     157     max_n_ticks=max_n_ticks,
#     158     top_ticks=top_ticks,
#     159     use_math_text=use_math_text,
#     160     reverse=reverse,
#     161     labelpad=labelpad,
#     162     hist_kwargs=hist_kwargs,
#     163     **hist2d_kwargs,
#     164 )
#     166 # Get diverging draws and combine chains
#     167 if divergences:
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/core.py:67, in corner_impl(xs, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, **hist2d_kwargs)
#      65 # Deal with 1D sample lists.
#      66 xs = _parse_input(xs)
# ---> 67 assert xs.shape[0] <= xs.shape[1], (
#      68     "I don't believe that you want more " "dimensions than samples!"
#      69 )
#      71 # Parse the weight array.
#      72 if weights is not None:
#
# AssertionError: I don't believe that you want more dimensions than samples!

# %%
# Out:
# json
# The evidence is: -664794.3212174099
#      omega_gw   phi0_gw    psi_gw   iota_gw  delta_gw  alpha_gw         h  \
# 0  500.001028  0.173187  2.403733  1.090623  0.763571  0.726050  1.254870
# 1  499.998786  0.172736  2.403393  0.817561  0.763681  0.725229  1.037308
# 2  500.000295  0.173530  2.403675  1.060556  0.763288  0.726552  1.227752
# 3  500.002575  0.174326  2.404909  1.099448  0.763148  0.727450  1.262169
# 4  500.004250  0.173234  2.403931  0.772344  0.763504  0.726177  1.005104
# 5  500.002364  0.172504  2.404444  1.081196  0.763210  0.727336  1.247050
#
#           f00         f01         f02  ...    distance40    distance41  \
# 0  329.727389  205.655283  300.124975  ...  6.000000e+10  1.800000e+11
# 1  330.531217  206.412553  301.721354  ...  6.000000e+10  1.800000e+11
# 2  330.941910  206.842127  303.461126  ...  6.000000e+10  1.800000e+11
# 3  329.722998  206.435644  304.213044  ...  6.000000e+10  1.800000e+11
# 4  330.452008  206.429425  301.761353  ...  6.000000e+10  1.800000e+11
# 5  330.820118  205.949674  302.132113  ...  6.000000e+10  1.800000e+11
#
#      distance42    distance43    distance44    distance45    distance46  \
# 0  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 1  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 2  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 3  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 5  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
#
#         sigma_m  log_likelihood    log_prior
# 0  1.000000e-11  -664664.046261  3866.759729
# 1  1.000000e-11  -664663.078478  3874.911692
# 2  1.000000e-11  -664662.852591  3891.824811
# 3  1.000000e-11  -664662.540683  3881.490957
# 4  1.000000e-11  -664662.144299  3874.720267
# 5  1.000000e-11  -664661.820893  3877.328158
#
# [6 rows x 245 columns]
# Number of samples:
# 6
# Truths/Medians/Variances
# $\Omega_{\rm nHz}$ 500.0 500.00169554083465 3.697804253017678e-06
# $\Phi_0$ 0.2 0.17321085199233738 4.1226646855622316e-07
# $\psi$ 2.5 2.4038320177512507 3.143092100047437e-07
# $\iota$ 1.0 1.070875690583071 0.02249042588394725
# $\delta$ 1.0 0.7633962822182199 4.617905271714928e-08
# $\alpha$ 1.0 0.726364471971472 7.040725553732078e-07
# $h_{0, \times 10^{12}}$ 1.0 1.2374008696254357 0.013946772593502538
# running with increased label size
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb Cell 6 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> f ="../data/nested_sampling/data_for_manuscript/canonical_example_fprior_result.json"
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> plot_all_corners(f,1237,save_id=None)
#
# /Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb Cell 6 in plot_all_corners(path, seed, save_id, tol, npsr)
#       <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a> axes_scales = None
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X31sZmlsZQ%3D%3D?line=10'>11</a> #Corner plot of GW parameters
# ---> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X31sZmlsZQ%3D%3D?line=11'>12</a> plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=f'{save_id}_GW')
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X31sZmlsZQ%3D%3D?line=16'>17</a> #Plot f0
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A6.Explore_broader_f_prior.ipynb#X31sZmlsZQ%3D%3D?line=17'>18</a> pulsars = pd.read_csv("../data/NANOGrav_pulsars.csv")
#
# File ~/github_repos/StateSpacePTA/notebooks/../py_src/plotting.py:170, in plot_custom_corner(path, variables_to_plot, labels, injection_parameters, ranges, axes_scales, savefig, logscale, title)
#     168 print("running with increased label size")
#     169 fs = 20
# --> 170 fig = corner.corner(y_post,
#     171                     color='C0',
#     172                     show_titles=True,
#     173                     smooth=True,smooth1d=True,
#     174                     truth_color='C2',
#     175                     quantiles=[0.16, 0.84],
#     176                     truths = injection_parameters,
#     177                     range=ranges,
#     178                     labels = labels,
#     179                     label_kwargs=dict(fontsize=fs),
#     180                     axes_scales = axes_scales)
#     183 #Pretty-ify
#     184 for ax in fig.axes:
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/corner.py:256, in corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     222         logging.warning(
#     223             "Please install arviz to use the advanced features of corner"
#     224         )
#     226     return corner_impl(
#     227         data,
#     228         bins=bins,
#    (...)
#     253         **hist2d_kwargs,
#     254     )
# --> 256 return arviz_corner(
#     257     data,
#     258     bins=bins,
#     259     range=range,
#     260     weights=weights,
#     261     color=color,
#     262     hist_bin_factor=hist_bin_factor,
#     263     smooth=smooth,
#     264     smooth1d=smooth1d,
#     265     labels=labels,
#     266     label_kwargs=label_kwargs,
#     267     titles=titles,
#     268     show_titles=show_titles,
#     269     title_fmt=title_fmt,
#     270     title_kwargs=title_kwargs,
#     271     truths=truths,
#     272     truth_color=truth_color,
#     273     scale_hist=scale_hist,
#     274     quantiles=quantiles,
#     275     verbose=verbose,
#     276     fig=fig,
#     277     max_n_ticks=max_n_ticks,
#     278     top_ticks=top_ticks,
#     279     use_math_text=use_math_text,
#     280     reverse=reverse,
#     281     labelpad=labelpad,
#     282     hist_kwargs=hist_kwargs,
#     283     group=group,
#     284     var_names=var_names,
#     285     filter_vars=filter_vars,
#     286     coords=coords,
#     287     divergences=divergences,
#     288     divergences_kwargs=divergences_kwargs,
#     289     labeller=labeller,
#     290     **hist2d_kwargs,
#     291 )
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/arviz_corner.py:136, in arviz_corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     134 # Coerce the samples into the expected format
#     135 samples = np.stack([x[-1].flatten() for x in plotters], axis=-1)
# --> 136 fig = corner_impl(
#     137     samples,
#     138     bins=bins,
#     139     range=range,
#     140     weights=weights,
#     141     color=color,
#     142     hist_bin_factor=hist_bin_factor,
#     143     smooth=smooth,
#     144     smooth1d=smooth1d,
#     145     labels=labels,
#     146     label_kwargs=label_kwargs,
#     147     titles=titles,
#     148     show_titles=show_titles,
#     149     title_fmt=title_fmt,
#     150     title_kwargs=title_kwargs,
#     151     truths=truths,
#     152     truth_color=truth_color,
#     153     scale_hist=scale_hist,
#     154     quantiles=quantiles,
#     155     verbose=verbose,
#     156     fig=fig,
#     157     max_n_ticks=max_n_ticks,
#     158     top_ticks=top_ticks,
#     159     use_math_text=use_math_text,
#     160     reverse=reverse,
#     161     labelpad=labelpad,
#     162     hist_kwargs=hist_kwargs,
#     163     **hist2d_kwargs,
#     164 )
#     166 # Get diverging draws and combine chains
#     167 if divergences:
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/site-packages/corner/core.py:67, in corner_impl(xs, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, **hist2d_kwargs)
#      65 # Deal with 1D sample lists.
#      66 xs = _parse_input(xs)
# ---> 67 assert xs.shape[0] <= xs.shape[1], (
#      68     "I don't believe that you want more " "dimensions than samples!"
#      69 )
#      71 # Parse the weight array.
#      72 if weights is not None:
#
# AssertionError: I don't believe that you want more dimensions than samples!

# %% [markdown]
# ### Noise realisation 1248
