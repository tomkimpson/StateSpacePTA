# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
import numpy as np 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %%
import glob 
from plotting import stacked_corner





for i in [1245,1246,1247,1248,1249,1250,1251,1252,1253,1254,1255]:


    #default values of GW parameters
    ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5e-12,1.5e-12)]
    ranges=[(4.95e-7,5.05e-7),(0.19,0.21),(2.30,2.70),(-0.2,np.pi/2),(0.5,1.5),(0.90,1.10),(0.5e-12,1.5e-12)]

    #ranges = None
    injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-12]
    labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
    variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
    axes_scales = None
    #ranges = None
    #list_of_files = glob.glob('../data/clean/rsync_folder/*.json')

    list_of_files = [f'../data/clean/eg_canonical_earth_1e-12_{i}_result.json',f'../data/clean/eg_canonical_pulsar_1e-12_{i}_result.json']

    number_of_files_to_plot = len(list_of_files)
    #Corner plot of GW parameters
    fig = stacked_corner(list_of_files,
                    number_of_files_to_plot,
                    variables_to_plot,
                    labels,
                    injection_parameters,
                    ranges,
                    axes_scales,
                    scalings = [1e9,1e12], #the scalings for omega and h
                    savefig=f'example_corner_compare_{i}',
                    smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1245_result.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb Cell 3 line <cell line: 8>()
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=24'>25</a> number_of_files_to_plot = len(list_of_files)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=25'>26</a> #Corner plot of GW parameters
# ---> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=26'>27</a> fig = stacked_corner(list_of_files,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=27'>28</a>                 number_of_files_to_plot,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=28'>29</a>                 variables_to_plot,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=29'>30</a>                 labels,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=30'>31</a>                 injection_parameters,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=31'>32</a>                 ranges,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=32'>33</a>                 axes_scales,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=33'>34</a>                 scalings = [1e9,1e12], #the scalings for omega and h
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=34'>35</a>                 savefig=f'example_corner_compare_{i}',
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W2sZmlsZQ%3D%3D?line=35'>36</a>                 smooth=True,smooth1d=True)
#
# File ~/github_repos/StateSpacePTA/notebooks/../py_src/plotting.py:267, in stacked_corner(list_of_files, number_of_files_to_plot, variables_to_plot, labels, injection_parameters, ranges, axes_scales, scalings, savefig, logscale, title, smooth, smooth1d, seed, no_titles, plot_datapoints)
#     264 injection_parameters_idx = injection_parameters.copy()
#     265 ranges_idx = ranges.copy()
# --> 267 y_post,injection_parameters_idx,ranges_idx,return_code= _extract_posterior_results(f,variables_to_plot,injection_parameters_idx,ranges_idx,scalings=scalings)
#     269 if return_code == 1:
#     270     print("Breaking due to weird psi")
#
# File ~/github_repos/StateSpacePTA/notebooks/../py_src/plotting.py:113, in _extract_posterior_results(path, variables_to_plot, injection_parameters, ranges, scalings)
#     109 f = open(path)
#     111 # returns JSON object as
#     112 # a dictionary
# --> 113 data = json.load(f)
#     114 print("The evidence is:", data["log_evidence"])
#     115 f.close()
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/miniconda3/envs/KalmanGW/lib/python3.10/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %% [markdown]
# # Low SNR, vs n4000

# %%
import glob 
from plotting import stacked_corner





for i in [1245,1248,1249,1250,1251,1252,1253,1254,1255]: #np.arange(1245,1255):

    #default values of GW parameters
    ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5*5e-15,1.5*5e-15)]
    #ranges=[(4.95e-7,5.05e-7),(0.19,0.21),(2.30,2.70),(-0.2,np.pi/2),(0.5,1.5),(0.90,1.10),(1e-15,9e-15)]

    #ranges = None
    injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-15]
    labels = [r'$10^9 \Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$10^{15} h_{0}$']
    variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
    axes_scales = None
    #ranges = None
    #list_of_files = glob.glob('../data/clean/rsync_folder/*.json')

    #list_of_files = ['../data/clean/eg_canonical_earth_5e-15_1251_result.json','../data/clean/eg_canonical_pulsar_5e-15_1251_result.json']

    list_of_files = [f'../data/clean/eg_canonical_earth_5e-15_{i}_result.json',f'../data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_{i}_result.json']

    #list_of_files = sorted(glob.glob('/Users/t1/github_repos/StateSpacePTA/')) #all the low snr pulsar results





    number_of_files_to_plot = len(list_of_files)
    #Corner plot of GW parameters
    fig = stacked_corner(list_of_files,
                    number_of_files_to_plot,
                    variables_to_plot,
                    labels,
                    injection_parameters,
                    ranges,
                    axes_scales,
                    scalings = [1e9,1e15], #the scalings for omega and h
                    savefig=None,
                    smooth=True,smooth1d=True,no_titles=True,plot_datapoints=False)
# Out:
# Extracting data from file:  ../data/clean/eg_canonical_earth_5e-15_1245_result.json
# The evidence is: 585619.8001630775
# The number of samples is: 4980
# Variable/Injection/Median
# omega_gw 500.0 498.47356664611976
# phi0_gw 0.2 0.18097557745319487
# psi_gw 2.5 2.416069515452495
# iota_gw 1.0 0.8610449343939721
# delta_gw 1.0 0.8323156329879116
# alpha_gw 1.0 0.9618617200134365
# h 5.0 4.96332300257081
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1245_result.json
# The evidence is: 585626.8693281981
# The number of samples is: 45064
# Variable/Injection/Median
# omega_gw 500.0 498.14570100661234
# phi0_gw 0.2 0.28377519150300556
# psi_gw 2.5 2.3730241904384384
# iota_gw 1.0 0.843907279075994
# delta_gw 1.0 0.7601367749008556
# alpha_gw 1.0 0.8184252133863148
# h 5.0 3.6759533174192773
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing numbers for comparing two posteriors
# The RMSRE is:
# omega_gw 1.72 2.04 -0.314 -0.182
# phi0_gw 0.141 0.204 -0.063 -0.448
# psi_gw 0.163 0.176 -0.0132 -0.0808
# iota_gw 0.374 0.383 -0.00843 -0.0225
# delta_gw 0.219 0.238 -0.0192 -0.088
# alpha_gw 0.246 0.265 -0.0187 -0.0762
# h 1.19 1.48 -0.29 -0.243
# Extracting data from file:  ../data/clean/eg_canonical_earth_5e-15_1248_result.json
# The evidence is: 585872.687650915
# The number of samples is: 5473
# Variable/Injection/Median
# omega_gw 500.0 500.0226343675669
# phi0_gw 0.2 0.25455041980431503
# psi_gw 2.5 2.652971170708161
# iota_gw 1.0 0.6959798277071194
# delta_gw 1.0 0.9144848223712858
# alpha_gw 1.0 1.0925419220389136
# h 5.0 4.16689522694517
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1248_result.json
# The evidence is: 585888.1990550649
# The number of samples is: 38457
# Variable/Injection/Median
# omega_gw 500.0 500.320685859724
# phi0_gw 0.2 0.26309637961702786
# psi_gw 2.5 2.5345602193006442
# iota_gw 1.0 0.68780446388028
# delta_gw 1.0 0.9727871852995247
# alpha_gw 1.0 1.080969592036336
# h 5.0 3.7087135734521124
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing numbers for comparing two posteriors
# The RMSRE is:
# omega_gw 180 0.839 179 0.995
# phi0_gw 0.17 0.159 0.0104 0.0614
# psi_gw 0.18 0.588 -0.408 -2.27
# iota_gw 0.415 0.41 0.0054 0.013
# delta_gw 0.15 0.0616 0.0883 0.589
# alpha_gw 0.153 0.555 -0.402 -2.63
# h 1.2 1.4 -0.196 -0.163
# Extracting data from file:  ../data/clean/eg_canonical_earth_5e-15_1249_result.json
# The evidence is: 585629.8557420946
# The number of samples is: 5440
# Variable/Injection/Median
# omega_gw 500.0 501.4736262988383
# phi0_gw 0.2 0.3502890672918849
# psi_gw 2.5 2.4488359867713543
# iota_gw 1.0 0.7825029863850592
# delta_gw 1.0 0.9374899657010336
# alpha_gw 1.0 0.9674487593879275
# h 5.0 5.200636055608537
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/dir_eg_canonical_bias_exploration_n4000/eg_canonical_bias_exploration_n4000_pulsar_5e-15_1249_result.json
# The evidence is: 585644.1287139625
# The number of samples is: 46803
# Variable/Injection/Median
# omega_gw 500.0 500.2824950753109
# phi0_gw 0.2 0.2032357050653927
# psi_gw 2.5 2.4327747268804982
# iota_gw 1.0 0.6409228596042351
# delta_gw 1.0 0.9269426914472626
# alpha_gw 1.0 0.9550195751360755
# h 5.0 3.681441637824831
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
