# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
import numpy as np 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %%
import glob 
from plotting import stacked_corner





for i in [1245,1246,1247,1248,1249,1250,1251,1252,1253,1254,1255]:


    #default values of GW parameters
    ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5e-12,1.5e-12)]
    ranges=[(4.95e-7,5.05e-7),(0.19,0.21),(2.30,2.70),(-0.2,np.pi/2),(0.5,1.5),(0.90,1.10),(0.5e-12,1.5e-12)]

    #ranges = None
    injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-12]
    labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
    variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
    axes_scales = None
    #ranges = None
    #list_of_files = glob.glob('../data/clean/rsync_folder/*.json')

    list_of_files = [f'../data/clean/eg_canonical_earth_1e-12_{i}_result.json',f'../data/clean/eg_canonical_pulsar_1e-12_{i}_result.json']

    number_of_files_to_plot = len(list_of_files)
    #Corner plot of GW parameters
    fig = stacked_corner(list_of_files,
                    number_of_files_to_plot,
                    variables_to_plot,
                    labels,
                    injection_parameters,
                    ranges,
                    axes_scales,
                    scalings = [1e9,1e12], #the scalings for omega and h
                    savefig=f'example_corner_compare_{i}',
                    smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1245_result.json
# The evidence is: -553439.2854993172
# The number of samples is: 4046
# Variable/Injection/Median
# omega_gw 500.0 499.9933319084631
# phi0_gw 0.2 0.19599214315707597
# psi_gw 2.5 2.5961558864775958
# iota_gw 1.0 0.6115055615051976
# delta_gw 1.0 1.0017437388513866
# alpha_gw 1.0 1.0399137481168728
# h 1.0 0.9715072651062968
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.4609610489966522e-05 0.008738838167177168
# $\Phi_0$ 0.019988234860095083 0.004130904420317567
# $\psi$ 0.03846077948532813 0.09615297139512019
# $\iota$ 0.3817296761328604 0.4354080616486104
# $\delta$ 0.001748131920702426 0.0017670396068965337
# $\alpha$ 0.039926532136664444 0.03992811275643487
# $h_{0, \times 10}$ 0.11530534385013291 0.14149889602814508
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1245_result.json
# The evidence is: 582553.8634627829
# The number of samples is: 9739
# Variable/Injection/Median
# omega_gw 500.0 499.991436085219
# phi0_gw 0.2 0.20043728973604802
# psi_gw 2.5 2.4997761391254056
# iota_gw 1.0 0.7686068128210748
# delta_gw 1.0 0.9996229766038478
# alpha_gw 1.0 0.9998012296571201
# h 1.0 0.8512712336040188
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.7116659174220338e-05 0.009345184148713026
# $\Phi_0$ 0.00425067005791137 0.001069793588804779
# $\psi$ 0.00014681828660229097 0.0004590090462558167
# $\iota$ 0.21364701273906886 0.23927397957613797
# $\delta$ 0.00038421670582407654 0.00042837741950504384
# $\alpha$ 0.0003036933740080274 0.000379669848718697
# $h_{0, \times 10}$ 0.1344210142814355 0.14845514840585844
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.46e-05 1.71e-05 2.51e-06
# 0.02 0.00425 -0.0157
# 0.0385 0.000147 -0.0383
# 0.382 0.214 -0.168
# 0.00175 0.000384 -0.00136
# 0.0399 0.000304 -0.0396
# 0.115 0.134 0.0191
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1246_result.json
# The evidence is: -552190.4665803388
# The number of samples is: 4714
# Variable/Injection/Median
# omega_gw 500.0 500.0086268184556
# phi0_gw 0.2 0.19731561976245915
# psi_gw 2.5 2.597105421118961
# iota_gw 1.0 0.8860234578393786
# delta_gw 1.0 1.0020662733380892
# alpha_gw 1.0 1.0404528807927458
# h 1.0 1.1607202972221577
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.7505737161526715e-05 0.010054998631280366
# $\Phi_0$ 0.01345134292675556 0.0028705956460158824
# $\psi$ 0.038831856135609036 0.09708073515701206
# $\iota$ 0.2940779265690956 0.38690452192526587
# $\delta$ 0.0020586406819312563 0.0020758899933166213
# $\alpha$ 0.040450283879446894 0.040451998896885
# $h_{0, \times 10}$ 0.21609618683487858 0.2609614495163311
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1246_result.json
# The evidence is: 584208.9705810809
# The number of samples is: 11411
# Variable/Injection/Median
# omega_gw 500.0 500.00195065698284
# phi0_gw 0.2 0.2005776893909777
# psi_gw 2.5 2.5008641443611066
# iota_gw 1.0 0.5208137444205058
# delta_gw 1.0 1.000008934393478
# alpha_gw 1.0 1.0007133961785732
# h 1.0 0.737138074708977
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 6.814154541954108e-06 0.0042480716904513645
# $\Phi_0$ 0.004624984138837818 0.0011533102949861274
# $\psi$ 0.0003458910808019768 0.000959485921212357
# $\iota$ 0.47894185461807187 0.48205855528478314
# $\delta$ 0.0001518442721706829 0.0001903557800790736
# $\alpha$ 0.000714940365696761 0.0007868480349708817
# $h_{0, \times 10}$ 0.2616082987018418 0.26236552469253005
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.75e-05 6.81e-06 -1.07e-05
# 0.0135 0.00462 -0.00883
# 0.0388 0.000346 -0.0385
# 0.294 0.479 0.185
# 0.00206 0.000152 -0.00191
# 0.0405 0.000715 -0.0397
# 0.216 0.262 0.0455
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1247_result.json
# The evidence is: -554806.0268053901
# The number of samples is: 4167
# Variable/Injection/Median
# omega_gw 500.0 499.99966767521414
# phi0_gw 0.2 0.19527993160344684
# psi_gw 2.5 2.596678078669099
# iota_gw 1.0 0.7871293731730415
# delta_gw 1.0 1.0019029988885872
# alpha_gw 1.0 1.0402407893556458
# h 1.0 1.083434973332581
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 8.813005686146619e-06 0.005535453050150752
# $\Phi_0$ 0.023856017257905177 0.004871844659947624
# $\psi$ 0.038681541359797046 0.09670480272183575
# $\iota$ 0.2923433289441242 0.33922884478579557
# $\delta$ 0.0019033623295912714 0.0019219380041924459
# $\alpha$ 0.04026758380632298 0.040269088561018615
# $h_{0, \times 10}$ 0.16997660119132785 0.24263536330930682
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1247_result.json
# The evidence is: 584521.3892455451
# The number of samples is: 10847
# Variable/Injection/Median
# omega_gw 500.0 500.0053838649704
# phi0_gw 0.2 0.20035163007979404
# psi_gw 2.5 2.4994560293224297
# iota_gw 1.0 0.6004747993232257
# delta_gw 1.0 0.9999549864380333
# alpha_gw 1.0 0.9999874604378939
# h 1.0 0.7686523716779697
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.1360056785346986e-05 0.006599966349234828
# $\Phi_0$ 0.00432261238879105 0.0010780198116118462
# $\psi$ 0.00023676703092050284 0.0007022971537221276
# $\iota$ 0.4007529611083691 0.4043406252301569
# $\delta$ 0.00016214955260751627 0.00020230574970476505
# $\alpha$ 0.0002935279129504392 0.0003687445729869945
# $h_{0, \times 10}$ 0.23075101367566847 0.23188247189840663
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 8.81e-06 1.14e-05 2.55e-06
# 0.0239 0.00432 -0.0195
# 0.0387 0.000237 -0.0384
# 0.292 0.401 0.108
# 0.0019 0.000162 -0.00174
# 0.0403 0.000294 -0.04
# 0.17 0.231 0.0608
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1248_result.json
# The evidence is: -555062.5486732459
# The number of samples is: 4282
# Variable/Injection/Median
# omega_gw 500.0 499.9931377270415
# phi0_gw 0.2 0.19457840472144516
# psi_gw 2.5 2.59771824780913
# iota_gw 1.0 0.7432959422059456
# delta_gw 1.0 1.002214012941087
# alpha_gw 1.0 1.0408046788722944
# h 1.0 1.0527339207859234
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.4640147482934252e-05 0.008667226418887695
# $\Phi_0$ 0.026891077547913426 0.005466581801928176
# $\psi$ 0.03908374694187519 0.09771032216151342
# $\iota$ 0.26619335729604154 0.310335472130485
# $\delta$ 0.0022092454316893807 0.0022235548271012863
# $\alpha$ 0.040806554727570256 0.0408079739030301
# $h_{0, \times 10}$ 0.10267978074650337 0.129078312685124
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1248_result.json
# The evidence is: 585641.62939588
# The number of samples is: 10628
# Variable/Injection/Median
# omega_gw 500.0 499.99931465899874
# phi0_gw 0.2 0.19895795679258105
# psi_gw 2.5 2.499951581410373
# iota_gw 1.0 0.9313871789744864
# delta_gw 1.0 1.0001133123650376
# alpha_gw 1.0 0.9999503493310862
# h 1.0 0.9525657514079482
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 6.1979536042982145e-06 0.003895858445688025
# $\Phi_0$ 0.006264230746100916 0.0015234929650741603
# $\psi$ 0.00014479714480005956 0.0004533624685041925
# $\iota$ 0.11226341193959855 0.13885437792761887
# $\delta$ 0.00018620126390182397 0.00023212844540613362
# $\alpha$ 0.00031032641769321913 0.00038721195315794075
# $h_{0, \times 10}$ 0.07456095167961085 0.09062196864996716
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.46e-05 6.2e-06 -8.44e-06
# 0.0269 0.00626 -0.0206
# 0.0391 0.000145 -0.0389
# 0.266 0.112 -0.154
# 0.00221 0.000186 -0.00202
# 0.0408 0.00031 -0.0405
# 0.103 0.0746 -0.0281
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1249_result.json
# The evidence is: -553400.936197005
# The number of samples is: 4119
# Variable/Injection/Median
# omega_gw 500.0 500.00565847139063
# phi0_gw 0.2 0.19645167900285912
# psi_gw 2.5 2.596246705162904
# iota_gw 1.0 0.5524634008540403
# delta_gw 1.0 1.0020003855229034
# alpha_gw 1.0 1.0397994926543002
# h 1.0 0.9417763896959129
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.281762090008916e-05 0.007696815446699241
# $\Phi_0$ 0.01807042984279919 0.0037476907844558103
# $\psi$ 0.03849498211366911 0.09623849453771387
# $\iota$ 0.46320268240221923 0.5046953724560862
# $\delta$ 0.0020014892638151624 0.0020197677486370994
# $\alpha$ 0.03981305325152466 0.039814630740111046
# $h_{0, \times 10}$ 0.09036508123049036 0.10452848702886533
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1249_result.json
# The evidence is: 564638.1081238207
# The number of samples is: 11138
# Variable/Injection/Median
# omega_gw 500.0 499.99227216132897
# phi0_gw 0.2 0.19622055946154537
# psi_gw 2.5 2.4992371442950887
# iota_gw 1.0 0.431952365694897
# delta_gw 1.0 0.9993930444860392
# alpha_gw 1.0 0.9998704416413575
# h 1.0 0.707799702860503
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.5527239876763153e-05 0.008575055516640069
# $\Phi_0$ 0.01881936522161947 0.003908525557449809
# $\psi$ 0.0003096988811742194 0.0008787142249614099
# $\iota$ 0.5700160557730531 0.5709899385627388
# $\delta$ 0.0006113486446167709 0.0006427332337492861
# $\alpha$ 0.00029359735682051903 0.0003658683941159594
# $h_{0, \times 10}$ 0.2923859285739185 0.29254812995818896
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.28e-05 1.55e-05 2.71e-06
# 0.0181 0.0188 0.000749
# 0.0385 0.00031 -0.0382
# 0.463 0.57 0.107
# 0.002 0.000611 -0.00139
# 0.0398 0.000294 -0.0395
# 0.0904 0.292 0.202
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1250_result.json
# The evidence is: -556073.4850638453
# The number of samples is: 4198
# Variable/Injection/Median
# omega_gw 500.0 500.00508203030626
# phi0_gw 0.2 0.19646443051558343
# psi_gw 2.5 2.596607146558471
# iota_gw 1.0 0.6457088703016223
# delta_gw 1.0 1.0022344226062054
# alpha_gw 1.0 1.0397245146041207
# h 1.0 0.9921304539038478
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.2323981068191904e-05 0.0075424409417003
# $\Phi_0$ 0.01785575460465004 0.0037224062345110804
# $\psi$ 0.03863849214001647 0.096597245048502
# $\iota$ 0.37414606497733527 0.4459541150112742
# $\delta$ 0.0022261686754132997 0.002241308325070979
# $\alpha$ 0.03971399794401841 0.039715420196363684
# $h_{0, \times 10}$ 0.16844797413144424 0.20972889497831168
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1250_result.json
# The evidence is: 584052.1127790113
# The number of samples is: 11048
# Variable/Injection/Median
# omega_gw 500.0 500.0073348934619
# phi0_gw 0.2 0.20166576056186356
# psi_gw 2.5 2.500595829395034
# iota_gw 1.0 0.945401270854238
# delta_gw 1.0 1.0002151069324872
# alpha_gw 1.0 1.000559381307669
# h 1.0 0.9631268560690665
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.4861580194631094e-05 0.008309877387745059
# $\Phi_0$ 0.008503601267380869 0.0019196235382372452
# $\psi$ 0.00025364706174567294 0.0007484107793140559
# $\iota$ 0.12632785068285296 0.14912597039541503
# $\delta$ 0.0002420379988895918 0.0002890841032885789
# $\alpha$ 0.0005822765699658116 0.0006717899603083067
# $h_{0, \times 10}$ 0.0845675359646438 0.09840766547753704
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.23e-05 1.49e-05 2.54e-06
# 0.0179 0.0085 -0.00935
# 0.0386 0.000254 -0.0384
# 0.374 0.126 -0.248
# 0.00223 0.000242 -0.00198
# 0.0397 0.000582 -0.0391
# 0.168 0.0846 -0.0839
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1251_result.json
# The evidence is: -555434.9453226039
# The number of samples is: 4378
# Variable/Injection/Median
# omega_gw 500.0 500.0094030149673
# phi0_gw 0.2 0.19682349720116313
# psi_gw 2.5 2.5968337072323253
# iota_gw 1.0 0.7992401103748881
# delta_gw 1.0 1.0018471849844288
# alpha_gw 1.0 1.0403282294724017
# h 1.0 1.0924889743845245
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.9370050409981296e-05 0.01101313613328608
# $\Phi_0$ 0.01579499630228236 0.003320698655042103
# $\psi$ 0.03872975260095234 0.09682542914039238
# $\iota$ 0.2768014794396836 0.3432271413072102
# $\delta$ 0.0018502992485547817 0.0018686765241351607
# $\alpha$ 0.04032015448119168 0.040321809772794565
# $h_{0, \times 10}$ 0.17262136390452373 0.2269999031375111
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1251_result.json
# The evidence is: 581553.9413898641
# The number of samples is: 11257
# Variable/Injection/Median
# omega_gw 500.0 500.00179301011224
# phi0_gw 0.2 0.19955525571517158
# psi_gw 2.5 2.499496849408651
# iota_gw 1.0 1.0608531167854356
# delta_gw 1.0 0.9997988251962828
# alpha_gw 1.0 0.9997225797321867
# h 1.0 1.0432313499720207
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 6.897888162466452e-06 0.004301256960541691
# $\Phi_0$ 0.004605307318989369 0.001149040388840815
# $\psi$ 0.00021958123946523654 0.000653052764483865
# $\iota$ 0.09081516818283385 0.10649004414043893
# $\delta$ 0.00023403829915230343 0.0002853552685386591
# $\alpha$ 0.0003551458541800821 0.0004348976374820146
# $h_{0, \times 10}$ 0.06401399545620357 0.07500311332308424
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.94e-05 6.9e-06 -1.25e-05
# 0.0158 0.00461 -0.0112
# 0.0387 0.00022 -0.0385
# 0.277 0.0908 -0.186
# 0.00185 0.000234 -0.00162
# 0.0403 0.000355 -0.04
# 0.173 0.064 -0.109
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1252_result.json
# The evidence is: -553750.766338591
# The number of samples is: 4479
# Variable/Injection/Median
# omega_gw 500.0 499.9979361547686
# phi0_gw 0.2 0.19541292637248334
# psi_gw 2.5 2.5978740971216983
# iota_gw 1.0 0.6019672945373599
# delta_gw 1.0 1.002668394122943
# alpha_gw 1.0 1.0410173747586335
# h 1.0 0.9679959052997958
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 9.626090809505088e-06 0.006030794100366761
# $\Phi_0$ 0.022771474714697662 0.004675062403270376
# $\psi$ 0.0391446204164136 0.0978624560307294
# $\iota$ 0.3822222551488105 0.4212331897781936
# $\delta$ 0.0026642679476310276 0.0026766012926808078
# $\alpha$ 0.04101319361243646 0.04101455426242807
# $h_{0, \times 10}$ 0.0887143229853284 0.1025285026593159
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1252_result.json
# The evidence is: 584154.6177264033
# The number of samples is: 10208
# Variable/Injection/Median
# omega_gw 500.0 500.0021662397039
# phi0_gw 0.2 0.20071934330064697
# psi_gw 2.5 2.5009227729533032
# iota_gw 1.0 0.956480314729282
# delta_gw 1.0 1.000087477073094
# alpha_gw 1.0 1.00024409418103
# h 1.0 0.9700234853029677
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 7.15623332491607e-06 0.0044450140231271805
# $\Phi_0$ 0.005111431185866538 0.0012649862553580072
# $\psi$ 0.000370890322984504 0.0010217029202748448
# $\iota$ 0.10344246640328805 0.12138508521729326
# $\delta$ 0.0001718551955092443 0.0002141361622222648
# $\alpha$ 0.00035450735873128984 0.00043777041930053047
# $h_{0, \times 10}$ 0.07044421774723394 0.08182914965242731
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 9.63e-06 7.16e-06 -2.47e-06
# 0.0228 0.00511 -0.0177
# 0.0391 0.000371 -0.0388
# 0.382 0.103 -0.279
# 0.00266 0.000172 -0.00249
# 0.041 0.000355 -0.0407
# 0.0887 0.0704 -0.0183
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1253_result.json
# The evidence is: -554923.173045496
# The number of samples is: 4193
# Variable/Injection/Median
# omega_gw 500.0 499.9956570417711
# phi0_gw 0.2 0.19429963407707537
# psi_gw 2.5 2.59644208651855
# iota_gw 1.0 0.7988112280778311
# delta_gw 1.0 1.00204118964103
# alpha_gw 1.0 1.0398883747251826
# h 1.0 1.0920604690659579
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.1368589906596978e-05 0.006936667757508435
# $\Phi_0$ 0.028382821088056242 0.005767721639352856
# $\psi$ 0.038568850849721156 0.09642313001297739
# $\iota$ 0.284100328558399 0.34175175944197506
# $\delta$ 0.0020302320832443193 0.002044566748429228
# $\alpha$ 0.039873934708052276 0.03987532554331822
# $h_{0, \times 10}$ 0.17809902495131097 0.23289514882076132
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1253_result.json
# The evidence is: 585513.0280348719
# The number of samples is: 11385
# Variable/Injection/Median
# omega_gw 500.0 500.00346368487425
# phi0_gw 0.2 0.19809922223145257
# psi_gw 2.5 2.4989012099885395
# iota_gw 1.0 0.9181197351196093
# delta_gw 1.0 1.0000840993503843
# alpha_gw 1.0 0.9991744911505844
# h 1.0 0.9438614544484206
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 8.643976337428476e-06 0.005315274723856987
# $\Phi_0$ 0.009635870005210968 0.0021754943800870877
# $\psi$ 0.00044112126545076455 0.001179475527286312
# $\iota$ 0.11394136771843763 0.13829948428007305
# $\delta$ 0.000177686571044383 0.00022385068637350555
# $\alpha$ 0.0008305332978478146 0.000898391274723878
# $h_{0, \times 10}$ 0.07569892221084222 0.09047147595083184
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.14e-05 8.64e-06 -2.72e-06
# 0.0284 0.00964 -0.0187
# 0.0386 0.000441 -0.0381
# 0.284 0.114 -0.17
# 0.00203 0.000178 -0.00185
# 0.0399 0.000831 -0.039
# 0.178 0.0757 -0.102
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1254_result.json
# The evidence is: -555156.4559904316
# The number of samples is: 4121
# Variable/Injection/Median
# omega_gw 500.0 499.99491779927
# phi0_gw 0.2 0.19468087897986028
# psi_gw 2.5 2.5966434101553726
# iota_gw 1.0 0.6659666106595686
# delta_gw 1.0 1.0022900784768989
# alpha_gw 1.0 1.039676299280335
# h 1.0 1.0029562821282036
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.2259662057244355e-05 0.007476862016644367
# $\Phi_0$ 0.026611537392725586 0.005409463039410275
# $\psi$ 0.03865894144561788 0.09664840115022648
# $\iota$ 0.3591537500062372 0.40173960397521435
# $\delta$ 0.0022824485519177067 0.0022969438477477636
# $\alpha$ 0.039682772033075735 0.03968432317953471
# $h_{0, \times 10}$ 0.08690038755184752 0.09947220267011016
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  ../data/clean/eg_canonical_pulsar_1e-12_1254_result.json
# The evidence is: 584223.1942739114
# The number of samples is: 10748
# Variable/Injection/Median
# omega_gw 500.0 499.99203877713796
# phi0_gw 0.2 0.1981528513617336
# psi_gw 2.5 2.5002541430256517
# iota_gw 1.0 0.5953857175560704
# delta_gw 1.0 0.9998054580170266
# alpha_gw 1.0 1.0002463151376126
# h 1.0 0.7666859680479612
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $\Omega$ 1.5938665276665695e-05 0.0088105894255984
# $\Phi_0$ 0.00924839342735781 0.0020746612243525663
# $\psi$ 0.00016212435666013608 0.000504481943898558
# $\iota$ 0.40081158561154917 0.4040127869785311
# $\delta$ 0.00023135953951158026 0.0002808164888513056
# $\alpha$ 0.0003413081390140873 0.00041936070651896814
# $h_{0, \times 10}$ 0.2306688868915917 0.23169507394930533
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Surfacing some numbers for comparing two posteriors
# 1.23e-05 1.59e-05 3.68e-06
# 0.0266 0.00925 -0.0174
# 0.0387 0.000162 -0.0385
# 0.359 0.401 0.0417
# 0.00228 0.000231 -0.00205
# 0.0397 0.000341 -0.0393
# 0.0869 0.231 0.144
# Extracting data from file:  ../data/clean/eg_canonical_earth_1e-12_1255_result.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb Cell 3 line <cell line: 8>()
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=24'>25</a> number_of_files_to_plot = len(list_of_files)
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=25'>26</a> #Corner plot of GW parameters
# ---> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=26'>27</a> fig = stacked_corner(list_of_files,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=27'>28</a>                 number_of_files_to_plot,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=28'>29</a>                 variables_to_plot,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=29'>30</a>                 labels,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=30'>31</a>                 injection_parameters,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=31'>32</a>                 ranges,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=32'>33</a>                 axes_scales,
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=33'>34</a>                 scalings = [1e9,1e12], #the scalings for omega and h
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=34'>35</a>                 savefig=f'example_corner_compare_{i}',
#      <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/A5.compare_psr_earth_posteriors.ipynb#W1sZmlsZQ%3D%3D?line=35'>36</a>                 smooth=True,smooth1d=True)
#
# File ~/github_repos/StateSpacePTA/notebooks/../py_src/plotting.py:267, in stacked_corner(list_of_files, number_of_files_to_plot, variables_to_plot, labels, injection_parameters, ranges, axes_scales, scalings, savefig, logscale, title, smooth, smooth1d, seed)
#     264 injection_parameters_idx = injection_parameters.copy()
#     265 ranges_idx = ranges.copy()
# --> 267 y_post,injection_parameters_idx,ranges_idx,return_code= _extract_posterior_results(f,variables_to_plot,injection_parameters_idx,ranges_idx,scalings=scalings)
#     269 if return_code == 1:
#     270     print("Breaking due to weird psi")
#
# File ~/github_repos/StateSpacePTA/notebooks/../py_src/plotting.py:109, in _extract_posterior_results(path, variables_to_plot, injection_parameters, ranges, scalings)
#     104 print("Extracting data from file: ", path)
#     106 if path.split('.')[-1] == 'json': #If it is a json files
#     107
#     108     # Opening JSON file
# --> 109     f = open(path)
#     111     # returns JSON object as
#     112     # a dictionary
#     113     data = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/clean/eg_canonical_earth_1e-12_1255_result.json'
