# %% [markdown]
# # Plots for paper

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %%
import matplotlib.pyplot as plt 
from priors import priors_dict
import numpy as np 
import json
import pandas as pd 
import corner
import scienceplots

def load_data(path,variables_to_plot):

    print("Loading data from file:", path)
    # Opening JSON file
    f = open(path)
    
    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    #Make it a dataframe. Nice for surfacing
    df = pd.DataFrame(data["samples"]["content"]) # posterior


    #Make it a dataframe. Nice for surfacing
    df_posterior = pd.DataFrame(data["posterior"]["content"]) # posterior
    df_samples = pd.DataFrame(data["samples"]["content"]) # posterior



    #Now make it a numpy array
    y_samp = df_samples.to_numpy() 


       
    y_post = df_posterior[variables_to_plot].to_numpy()


    print("The evidence is:", data["log_evidence"])
    print("Number of samples:",len(df_posterior))
    print("Truths/Medians/Variances")
    medians = df_posterior[variables_to_plot].median()
    variances = df_posterior[variables_to_plot].var()
    for i in range(len(medians)):
        print(variables_to_plot[i],medians[i],variances[i])
    

    print('---------------------------------------------------')
    return y_post 




def stacked_corner(list_of_files,variables_to_plot,ranges,injection_parameters,labels,axes_scales,savefig=None,logscale=False):


    y = []
    fig= None 
    for f in list_of_files:
        yi = load_data(f,variables_to_plot)
        y.extend([yi])

    plt.style.use('science')



    for i in range(len(y)):

        k = i 
        if k ==2:
            k = k+1 #convoluted way of skipping C2 color




        if logscale:
            yplot = np.log10(y[i])
            injection_parameters = np.log10(injection_parameters)
            #ranges = np.log10(ranges)
        else:
            yplot = y[i]
        
        print("ranges =", ranges)
        nsamples = len(y[i])
        fig = corner.corner(yplot, 
                            color=f'C{k}',
                            show_titles=True,
                            smooth=True,smooth1d=True,
                            truth_color='C2',
                            quantiles=[0.16, 0.84],
                            truths =injection_parameters ,
                            range=ranges,
                            labels = labels,
                            label_kwargs=dict(fontsize=16),
                            axes_scales = axes_scales,
                            weights = np.ones(nsamples)/nsamples,
                            fig=fig)






        i += 1


    
    if savefig != None:
        plt.savefig(f"../data/images/{savefig}.png", bbox_inches="tight",dpi=300)

# %%
import glob 
list_of_files = sorted(glob.glob("../data/nested_sampling/scp_dir_noise/*.json"))
short_list = [list_of_files[0],list_of_files[1],list_of_files[3],list_of_files[4],list_of_files[5]]

# %%
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
ranges=[(4e-7,6e-7),(-np.pi,np.pi),(0.0+1.0,np.pi+1.0),(0.0,np.pi/2.0),(-np.pi/2 + 0.8,np.pi/2 + 0.8),(0.0,np.pi),(0.5e-12,1.5e-12)]
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-12]
labels = [r'$\omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'h']
axes_scales = None

stacked_corner(short_list,variables_to_plot,ranges,injection_parameters,labels,axes_scales,savefig="stacked_GW_plot", logscale=False)
# Out:
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1245_result.json
# The evidence is: -542235.3962259282
# Number of samples: 8854
# Truths/Medians/Variances
# omega_gw 5.000030048361884e-07 2.0750539634786338e-23
# phi0_gw 0.1969840109148716 6.008554274430901e-07
# psi_gw 2.59643068790185 6.32532711726685e-07
# iota_gw 0.727250216498599 0.001696440412615186
# delta_gw 1.0026647892294398 4.79809851931503e-07
# alpha_gw 1.0411200561014704 2.602108401507158e-07
# h 1.0432236007359134e-12 7.6947465840962715e-28
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1246_result.json
# The evidence is: -538301.8875694362
# Number of samples: 9818
# Truths/Medians/Variances
# omega_gw 5.000272884520703e-07 2.2804946758951492e-23
# phi0_gw 0.20020649823067377 6.733905611972165e-07
# psi_gw 2.597053250057101 2.929535920100646e-07
# iota_gw 0.9189336969129986 0.007413420490062122
# delta_gw 1.000809959072269 2.8188424607520623e-07
# alpha_gw 1.0405580330439217 1.7162225464222117e-07
# h 1.1903910025038017e-12 5.246445458285294e-27
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1248_result.json
# The evidence is: -541937.162588719
# Number of samples: 9798
# Truths/Medians/Variances
# omega_gw 4.999971682022325e-07 2.2710413546444536e-23
# phi0_gw 0.19431316324130046 6.853661812801517e-07
# psi_gw 2.5960707349841403 3.3114528529465973e-07
# iota_gw 1.0190741135776187 0.0120358002419091
# delta_gw 1.0001397443664153 3.890780252067484e-07
# alpha_gw 1.0406596605572997 2.0891479715928274e-07
# h 1.2753627892287016e-12 9.066193758744168e-27
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1249_result.json
# The evidence is: -540232.3756413523
# Number of samples: 7584
# Truths/Medians/Variances
# omega_gw 5.000119030020045e-07 2.2652394442460855e-23
# phi0_gw 0.19690465986490013 6.694768811610086e-07
# psi_gw 2.5952533910739453 3.8810642296892193e-07
# iota_gw 1.0145538697321128 0.005236440532678233
# delta_gw 1.0011108017196841 2.387150174417802e-07
# alpha_gw 1.0387768518245482 1.925466242747964e-07
# h 1.2728156848352128e-12 3.952881331282575e-27
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1250_result.json
# The evidence is: -543095.9031836101
# Number of samples: 10454
# Truths/Medians/Variances
# omega_gw 4.999858762503582e-07 2.2022963396459733e-23
# phi0_gw 0.19169978162062457 6.558580384670517e-07
# psi_gw 2.594063008571128 4.6270427758346487e-07
# iota_gw 0.8887709185194712 0.007827313753446695
# delta_gw 1.0018565140533935 3.29556698231323e-07
# alpha_gw 1.037272376766104 2.097856297623626e-07
# h 1.163138533988981e-12 5.397045344005223e-27
# ---------------------------------------------------
# ranges = [(4e-07, 6e-07), (-3.141592653589793, 3.141592653589793), (1.0, 4.141592653589793), (0.0, 1.5707963267948966), (-0.7707963267948965, 2.3707963267948964), (0.0, 3.141592653589793), (5e-13, 1.5e-12)]
# ranges = [(4e-07, 6e-07), (-3.141592653589793, 3.141592653589793), (1.0, 4.141592653589793), (0.0, 1.5707963267948966), (-0.7707963267948965, 2.3707963267948964), (0.0, 3.141592653589793), (5e-13, 1.5e-12)]
# ranges = [(4e-07, 6e-07), (-3.141592653589793, 3.141592653589793), (1.0, 4.141592653589793), (0.0, 1.5707963267948966), (-0.7707963267948965, 2.3707963267948964), (0.0, 3.141592653589793), (5e-13, 1.5e-12)]
# ranges = [(4e-07, 6e-07), (-3.141592653589793, 3.141592653589793), (1.0, 4.141592653589793), (0.0, 1.5707963267948966), (-0.7707963267948965, 2.3707963267948964), (0.0, 3.141592653589793), (5e-13, 1.5e-12)]
# ranges = [(4e-07, 6e-07), (-3.141592653589793, 3.141592653589793), (1.0, 4.141592653589793), (0.0, 1.5707963267948966), (-0.7707963267948965, 2.3707963267948964), (0.0, 3.141592653589793), (5e-13, 1.5e-12)]

# %%
#Plot f0 
pulsars = pd.read_csv("../data/NANOGrav_pulsars.csv")
true_f = pulsars["F0"].to_numpy()


labels = [r'$f_0$',r'$f_1$',r'$f_2$',r'$f_3$', r'$f_4$']
idx = len(labels)
injection_parameters = true_f[0:idx]
variables_to_plot = ["f00", "f01", "f02", "f03", "f04"]



       # priors[key] = bilby.core.prior.Uniform(f-np.abs(f*tol),f+ np.abs(f*tol), key)

tol =0.1
#ranges = [(i*0.9,i*1.1) for i in injection_parameters]
ranges = [(i-np.abs(i*tol),i+np.abs(i*tol)) for i in injection_parameters]

axes_scales = None
stacked_corner(short_list,variables_to_plot,ranges,injection_parameters,labels,axes_scales,savefig="stacked_f_plot", logscale=False)
# Out:
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1245_result.json
# The evidence is: -542235.3962259282
# Number of samples: 8854
# Truths/Medians/Variances
# f00 330.0197265024523 0.20737294656852678
# f01 207.0009214765844 0.11142895982270253
# f02 303.3559722277465 1.7075471723546956
# f03 328.826447247567 0.1738481543088848
# f04 349.5849553874457 2.1833055559496817
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1246_result.json
# The evidence is: -538301.8875694362
# Number of samples: 9818
# Truths/Medians/Variances
# f00 330.63559421948025 0.08902444712171481
# f01 206.950065209012 0.11172950446554342
# f02 302.15961008314775 1.59067134470848
# f03 329.5239034761349 0.05349412274311007
# f04 347.9765243703281 1.8780820221749257
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1248_result.json
# The evidence is: -541937.162588719
# Number of samples: 9798
# Truths/Medians/Variances
# f00 330.55095753846115 0.10781216536705873
# f01 206.82412827932353 0.10987341615816851
# f02 303.7107805315721 1.5332590049332266
# f03 328.95443103155236 0.12737782557007818
# f04 347.7454215275241 2.5206668213714787
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1249_result.json
# The evidence is: -540232.3756413523
# Number of samples: 7584
# Truths/Medians/Variances
# f00 330.21184195377356 0.1528222082353886
# f01 205.7694545260075 0.20770317239956437
# f02 303.18454427690904 2.0299709707357736
# f03 329.5522734438099 0.054616659017881396
# f04 346.6820524349682 1.128945669608253
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1250_result.json
# The evidence is: -543095.9031836101
# Number of samples: 10454
# Truths/Medians/Variances
# f00 330.43555254215136 0.14283862561265087
# f01 207.16771330617877 0.07337005478447928
# f02 302.1869218230893 1.16330305798323
# f03 329.08215217454017 0.12938666502558466
# f04 348.18367938297587 2.0542686874046407
# ---------------------------------------------------
# ranges = [(295.06231850500666, 360.6317226172303), (184.977629190531, 226.083769010649), (272.7818814701878, 333.4000773524518), (293.9405057705439, 359.2606181639981), (313.7033085299912, 383.41515486998924)]
# ranges = [(295.06231850500666, 360.6317226172303), (184.977629190531, 226.083769010649), (272.7818814701878, 333.4000773524518), (293.9405057705439, 359.2606181639981), (313.7033085299912, 383.41515486998924)]
# ranges = [(295.06231850500666, 360.6317226172303), (184.977629190531, 226.083769010649), (272.7818814701878, 333.4000773524518), (293.9405057705439, 359.2606181639981), (313.7033085299912, 383.41515486998924)]
# ranges = [(295.06231850500666, 360.6317226172303), (184.977629190531, 226.083769010649), (272.7818814701878, 333.4000773524518), (293.9405057705439, 359.2606181639981), (313.7033085299912, 383.41515486998924)]
# ranges = [(295.06231850500666, 360.6317226172303), (184.977629190531, 226.083769010649), (272.7818814701878, 333.4000773524518), (293.9405057705439, 359.2606181639981), (313.7033085299912, 383.41515486998924)]

# %%
#Plot f1 
pulsars = pd.read_csv("../data/NANOGrav_pulsars.csv")
true_f = pulsars["F1"].to_numpy()


labels = [r'$\dot{f}_0$',r'$\dot{f}_1$',r'$\dot{f}_2$',r'$\dot{f}_3$', r'$\dot{f}_4$']
idx = len(labels)
injection_parameters = true_f[0:idx]
variables_to_plot = ["fdot0", "fdot1", "fdot2", "fdot3", "fdot4"]

tol = 0.1
ranges = [(i-np.abs(i*tol),i+np.abs(i*tol)) for i in injection_parameters]
axes_scales = None
stacked_corner(short_list,variables_to_plot,ranges,injection_parameters,labels,axes_scales,savefig="stacked_fdto_plot", logscale=False)
# Out:
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1245_result.json
# The evidence is: -542235.3962259282
# Number of samples: 8854
# Truths/Medians/Variances
# fdot0 -1.2298241922414264e-15 2.7040480300372246e-35
# fdot1 -4.2737853042671244e-16 1.7186136662875805e-36
# fdot2 -6.455001882924588e-16 7.463498384921037e-36
# fdot3 -1.028233992826649e-15 1.106550324740949e-35
# fdot4 -4.166205385037544e-16 1.3139582848800859e-36
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1246_result.json
# The evidence is: -538301.8875694362
# Number of samples: 9818
# Truths/Medians/Variances
# fdot0 -1.2292906286248653e-15 2.244714461322888e-35
# fdot1 -4.3073484789793853e-16 3.455110574274327e-36
# fdot2 -6.433528144262555e-16 2.5144543120072826e-36
# fdot3 -1.0211281619164603e-15 1.9173598954354039e-35
# fdot4 -4.1948867565222406e-16 2.6850946330807807e-36
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1248_result.json
# The evidence is: -541937.162588719
# Number of samples: 9798
# Truths/Medians/Variances
# fdot0 -1.2244043188768502e-15 2.5813987752545737e-35
# fdot1 -4.314264812175494e-16 2.5055308487881728e-36
# fdot2 -6.48217651076548e-16 6.940210492037436e-36
# fdot3 -1.0291486133941029e-15 7.52905715907225e-36
# fdot4 -4.1685108228250076e-16 1.729376371677469e-36
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1249_result.json
# The evidence is: -540232.3756413523
# Number of samples: 7584
# Truths/Medians/Variances
# fdot0 -1.2251272803633576e-15 2.711342172477343e-35
# fdot1 -4.3013652319259725e-16 3.7855948166070475e-36
# fdot2 -6.490077924636991e-16 7.721547686097873e-36
# fdot3 -1.027078478601208e-15 1.5396847892385486e-35
# fdot4 -4.1710168346155657e-16 2.225399547262486e-36
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1250_result.json
# The evidence is: -543095.9031836101
# Number of samples: 10454
# Truths/Medians/Variances
# fdot0 -1.2235607394723195e-15 2.052683025949245e-35
# fdot1 -4.310482176128756e-16 3.02991805835454e-36
# fdot2 -6.444803883513264e-16 4.5073907507082897e-36
# fdot3 -1.0221675965626027e-15 2.1729110992928148e-35
# fdot4 -4.202944007848168e-16 2.858566679393768e-36
# ---------------------------------------------------
# ranges = [(-1.3506174e-15, -1.1050506e-15), (-4.7267e-16, -3.8673e-16), (-7.12107e-16, -5.82633e-16), (-1.1252901e-15, -9.206918999999998e-16), (-4.60845e-16, -3.7705499999999997e-16)]
# ranges = [(-1.3506174e-15, -1.1050506e-15), (-4.7267e-16, -3.8673e-16), (-7.12107e-16, -5.82633e-16), (-1.1252901e-15, -9.206918999999998e-16), (-4.60845e-16, -3.7705499999999997e-16)]
# ranges = [(-1.3506174e-15, -1.1050506e-15), (-4.7267e-16, -3.8673e-16), (-7.12107e-16, -5.82633e-16), (-1.1252901e-15, -9.206918999999998e-16), (-4.60845e-16, -3.7705499999999997e-16)]
# ranges = [(-1.3506174e-15, -1.1050506e-15), (-4.7267e-16, -3.8673e-16), (-7.12107e-16, -5.82633e-16), (-1.1252901e-15, -9.206918999999998e-16), (-4.60845e-16, -3.7705499999999997e-16)]
# ranges = [(-1.3506174e-15, -1.1050506e-15), (-4.7267e-16, -3.8673e-16), (-7.12107e-16, -5.82633e-16), (-1.1252901e-15, -9.206918999999998e-16), (-4.60845e-16, -3.7705499999999997e-16)]

# %%
#Plot sigma p 





#Plot sigma_p, log scaled
generator = np.random.default_rng(1234)
σp = generator.uniform(low = 1e-21,high=1e-19,size=len(true_f))

    
labels = [r'$\sigma_p^0$',r'$\sigma_p^1$',r'$\sigma_p^2$',r'$\sigma_p^3$', r'$\sigma_p^4$']
idx = len(labels)
injection_parameters = σp[0:idx]
variables_to_plot    = ["sigma_p0", "sigma_p1", "sigma_p2", "sigma_p3", "sigma_p4"]




ranges = [(np.log10(1e-22),np.log10(1e-18)) for i in injection_parameters]


stacked_corner(short_list,variables_to_plot,ranges,injection_parameters,labels,axes_scales,savefig="stacked_sgima_p_plot",logscale=True)
# Out:
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1245_result.json
# The evidence is: -542235.3962259282
# Number of samples: 8854
# Truths/Medians/Variances
# sigma_p0 1.730898920713319e-20 4.293237284549641e-40
# sigma_p1 5.56549582423964e-21 1.6487950115124386e-40
# sigma_p2 1.9062529416885185e-20 4.997698077046997e-40
# sigma_p3 9.108545730288702e-21 2.3731116450799918e-40
# sigma_p4 2.7878982217110425e-21 7.397366816471684e-42
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1246_result.json
# The evidence is: -538301.8875694362
# Number of samples: 9818
# Truths/Medians/Variances
# sigma_p0 1.968534931153507e-20 5.287115421059771e-40
# sigma_p1 1.8173119737685806e-20 5.195067954741889e-40
# sigma_p2 2.9261879208161296e-21 2.5141294697554355e-41
# sigma_p3 2.4807684091853698e-20 5.320265902011268e-40
# sigma_p4 1.9989891828055048e-20 5.476921194903035e-40
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1248_result.json
# The evidence is: -541937.162588719
# Number of samples: 9798
# Truths/Medians/Variances
# sigma_p0 5.016098464766208e-21 4.945252746619349e-41
# sigma_p1 2.033149103094585e-20 5.180307110578463e-40
# sigma_p2 5.1267754959891185e-21 3.449286596104537e-41
# sigma_p3 2.255692266791496e-21 6.08166570573993e-42
# sigma_p4 3.6791360081243355e-20 6.020721892867908e-40
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1249_result.json
# The evidence is: -540232.3756413523
# Number of samples: 7584
# Truths/Medians/Variances
# sigma_p0 5.487205574884552e-21 1.329203340592729e-40
# sigma_p1 2.743519486062727e-21 1.3741565851898284e-41
# sigma_p2 1.482629592775528e-20 3.5912162115033054e-40
# sigma_p3 1.4622139860678166e-20 4.211904314496247e-40
# sigma_p4 1.3077459002832918e-20 4.578280665599526e-40
# ---------------------------------------------------
# Loading data from file: ../data/nested_sampling/scp_dir_noise/noise_batch_1250_result.json
# The evidence is: -543095.9031836101
# Number of samples: 10454
# Truths/Medians/Variances
# sigma_p0 2.7193022606847424e-21 1.6365283279885263e-41
# sigma_p1 3.008578333674011e-20 5.5349171275223406e-40
# sigma_p2 2.643830388967705e-21 1.0704183820024637e-41
# sigma_p3 5.602623364047625e-21 1.5361341272287596e-40
# sigma_p4 4.6537651033182166e-21 1.041517549863294e-40
# ---------------------------------------------------
# ranges = [(-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0)]
# /var/folders/bx/dsrq957n43bckqdm1vkk78yc0000gn/T/ipykernel_47763/3639424903.py:76: RuntimeWarning: invalid value encountered in log10
#   injection_parameters = np.log10(injection_parameters)
# ranges = [(-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0)]
# ranges = [(-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0)]
# ranges = [(-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0)]
# ranges = [(-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0), (-22.0, -18.0)]

# %% [markdown]
# ### Look over all noise iterations

# %%
def surface_numbers(path):
    # Opening JSON file
    f = open(path)

    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    #Make it a dataframe. Nice for surfacing
    df_posterior = pd.DataFrame(data["posterior"]["content"]) # posterior

    return df_posterior.median()

dfs = []
for f in list_of_files:
    print(f)
    df_i = surface_numbers(f)
    dfs.extend([df_i])


df = pd.concat(dfs)
# Out:
# ../data/nested_sampling/scp_dir_noise/noise_batch_1245_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1246_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1247_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1248_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1249_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1250_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1251_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1252_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1253_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1254_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1255_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1256_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1257_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1258_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1259_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1260_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1261_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1262_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1263_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1264_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1265_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1266_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1267_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1268_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1269_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1270_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1271_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1272_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1273_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1274_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1275_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1276_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1277_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1278_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1279_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1280_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1281_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1282_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1283_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1284_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1285_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1286_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1287_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1288_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1289_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1290_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1291_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1292_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1293_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1294_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1295_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1296_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1297_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1298_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1299_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1300_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1301_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1302_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1303_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1304_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1305_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1306_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1307_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1308_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1309_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1310_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1311_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1312_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1313_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1314_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1315_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1316_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1317_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1318_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1319_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1320_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1321_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1322_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1323_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1324_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1325_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1326_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1327_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1328_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1329_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1330_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1331_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1332_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1333_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1334_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1335_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1336_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1337_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1338_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1339_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1340_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1341_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1342_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1343_result.json
# ../data/nested_sampling/scp_dir_noise/noise_batch_1344_result.json

# %%
dfs_new = []


for df in dfs:
    df_i = df.to_frame().transpose()
    dfs_new.extend([df_i])


df = pd.concat(dfs_new)
df = df.reset_index()
df.to_pickle("../data/multiple_noise_realisations")
df = pd.read_pickle("../data/multiple_noise_realisations")

# %%
df
# Out:
#     index      omega_gw   phi0_gw    psi_gw   iota_gw  delta_gw  alpha_gw  \
# 0       0  5.000030e-07  0.196984  2.596431  0.727250  1.002665  1.041120
# 1       0  5.000273e-07  0.200206  2.597053  0.918934  1.000810  1.040558
# 2       0  4.999990e-07  0.188677  0.866019  0.950274  0.940751  2.529194
# 3       0  4.999972e-07  0.194313  2.596071  1.019074  1.000140  1.040660
# 4       0  5.000119e-07  0.196905  2.595253  1.014554  1.001111  1.038777
# ..    ...           ...       ...       ...       ...       ...       ...
# 95      0  4.999936e-07  0.188036  0.866489  0.483578  0.940288  2.532076
# 96      0  5.000127e-07  0.197971  2.600301  0.909062  1.004981  1.042118
# 97      0  5.000269e-07  0.200866  2.594569  1.175423  1.003185  1.039497
# 98      0  5.000379e-07  0.202983  2.596715  1.044418  1.002017  1.039869
# 99      0  5.000028e-07  0.194769  2.596136  0.922562  0.998607  1.038511
#
#                h         f00         f01  ...    distance40    distance41  \
# 0   1.043224e-12  330.019727  207.000921  ...  6.000000e+10  1.800000e+11
# 1   1.190391e-12  330.635594  206.950065  ...  6.000000e+10  1.800000e+11
# 2   1.246488e-12  330.467404  206.431243  ...  6.000000e+10  1.800000e+11
# 3   1.275363e-12  330.550958  206.824128  ...  6.000000e+10  1.800000e+11
# 4   1.272816e-12  330.211842  205.769455  ...  6.000000e+10  1.800000e+11
# ..           ...         ...         ...  ...           ...           ...
# 95  9.336775e-13  330.715359  206.246397  ...  6.000000e+10  1.800000e+11
# 96  1.181169e-12  330.125051  206.607541  ...  6.000000e+10  1.800000e+11
# 97  1.414339e-12  329.241177  207.203396  ...  6.000000e+10  1.800000e+11
# 98  1.299242e-12  330.635438  207.316547  ...  6.000000e+10  1.800000e+11
# 99  1.192947e-12  330.566790  207.108464  ...  6.000000e+10  1.800000e+11
#
#       distance42    distance43    distance44    distance45    distance46  \
# 0   9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 1   9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 2   9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 3   9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4   9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# ..           ...           ...           ...           ...           ...
# 95  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 96  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 97  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 98  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 99  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
#
#          sigma_m  log_likelihood    log_prior
# 0   1.000000e-11  -542061.630255  3877.692860
# 1   1.000000e-11  -538145.014889  3874.631149
# 2   1.000000e-11  -858092.273134  3890.766971
# 3   1.000000e-11  -541747.146908  3879.641092
# 4   1.000000e-11  -540072.831420  3878.734540
# ..           ...             ...          ...
# 95  1.000000e-11  -861540.792609  3877.920072
# 96  1.000000e-11  -540741.762114  3872.830661
# 97  1.000000e-11  -543181.811058  3873.864655
# 98  1.000000e-11  -540118.005663  3885.289006
# 99  1.000000e-11  -537127.976023  3873.076302
#
# [100 rows x 246 columns]

# %%
import numpy as np 
import scienceplots


def stacked_histogram(df,parameters,labels,injection_parameters,ranges,index_log_axes,x_upper_limit,savefig):



    plt.style.use('science')


    h,w = 8,20
    rows = len(parameters)
    cols = 1
    fig, axes_object = plt.subplots(nrows=rows, ncols=cols, figsize=(h,w),sharex=True)
        


    axes = fig.get_axes()


    fs=18

    for i in range(len(parameters)):
        p = parameters[i]
        ax = axes[i]
        
        df[p].hist(ax=ax,bins=20,orientation="horizontal",align="left")


        ax.set_ylabel(labels[i], fontsize=fs)
        ax.xaxis.set_tick_params(labelsize=fs-4)
        ax.yaxis.set_tick_params(labelsize=fs-4)
        ax.grid(False)
        ax.set_xlim(0,x_upper_limit)
        ax.set_ylim(ranges[i])

        ax.axhline(injection_parameters[i],c='C2', linestyle='--')



    for i in index_log_axes:
        axes[i].set_yscale('log') 
        axes[i].set_yscale('log') 
    


    axes[-1].set_xlabel('Counts', fontsize=fs)


    plt.subplots_adjust(hspace=0.0)



    if savefig != None:
        plt.savefig(f"../data/images/{savefig}.png", bbox_inches="tight",dpi=300)

# %%
parameters = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw","h",]
labels = [r'$\omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'h']
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,1e-12]
ranges=[(1e-9,1e-5),(0.0,0.50),(2.0,3.0),(0.5,1.5),(0.5,1.5),(0.5,1.5),(1e-13,1e-11)]
index_log_axes = [0,-1]

stacked_histogram(df,parameters,labels,injection_parameters,ranges,index_log_axes,x_upper_limit=100,savefig='parameter_medians')

# %%
#Plot f0 
pulsars = pd.read_csv("../data/NANOGrav_pulsars.csv")
true_f = pulsars["F0"].to_numpy()




parameters = ["f00", "f01", "f02", "f03", "f04"]
labels = [r'$f_0$',r'$f_1$',r'$f_2$',r'$f_3$', r'$f_4$']
idx = len(labels)
injection_parameters = true_f[0:idx]

tol =0.1
ranges = [(i-np.abs(i*tol),i+np.abs(i*tol)) for i in injection_parameters]
index_log_axes = []
stacked_histogram(df,parameters,labels,injection_parameters,ranges,index_log_axes,x_upper_limit=20,savefig='parameter_medians_f')

# %%
#Plot f0 
pulsars = pd.read_csv("../data/NANOGrav_pulsars.csv")
true_f = pulsars["F1"].to_numpy()





parameters = ["fdot0", "fdot1", "fdot2", "fdot3", "fdot4"]
labels = [r'$\dot{f}_0$',r'$\dot{f}_1$',r'$\dot{f}_2$',r'$\dot{f}_3$', r'$\dot{f}_4$']
idx = len(labels)
injection_parameters = true_f[0:idx]

tol =0.1
ranges = [(i-np.abs(i*tol),i+np.abs(i*tol)) for i in injection_parameters]
index_log_axes = []
stacked_histogram(df,parameters,labels,injection_parameters,ranges,index_log_axes,x_upper_limit=20,savefig='parameter_medians_fdot')

# %%
#Plot sigma_p, log scaled
generator = np.random.default_rng(1234)
σp = generator.uniform(low = 1e-21,high=1e-19,size=len(true_f))

    
labels = [r'$\sigma_p^0$',r'$\sigma_p^1$',r'$\sigma_p^2$',r'$\sigma_p^3$', r'$\sigma_p^4$']
idx = len(labels)
injection_parameters = σp[0:idx]
parameters    = ["sigma_p0", "sigma_p1", "sigma_p2", "sigma_p3", "sigma_p4"]




ranges = [(1e-23,1e-18) for i in injection_parameters]


index_log_axes = [0,1,2,3,4]

stacked_histogram(df,parameters,labels,injection_parameters,ranges,index_log_axes,x_upper_limit=20,savefig='parameter_medians_sigma_p')

# %%
σp
# Out:
# array([9.76932769e-20, 3.86393778e-20, 9.24013771e-20, 2.69075500e-20,
#        3.25906088e-20, 1.26910321e-20, 2.49348630e-20, 3.25348589e-20,
#        9.64438453e-20, 2.71013306e-20, 4.46596061e-20, 6.13772101e-20,
#        8.64985084e-20, 8.65120094e-20, 6.78132500e-20, 6.63275604e-20,
#        7.38400121e-20, 2.30526122e-20, 1.80345523e-20, 8.71710823e-20,
#        6.95372712e-21, 6.86852020e-20, 6.74525639e-20, 6.14907801e-20,
#        6.95359396e-21, 9.77991581e-20, 4.44562110e-20, 5.37269071e-20,
#        1.31009646e-21, 2.58754434e-20, 8.59905533e-20, 4.31045368e-20,
#        7.38460804e-20, 9.22822785e-20, 1.61939429e-20, 9.92336637e-20,
#        1.90508465e-20, 9.40711773e-20, 9.60142247e-21, 4.73528608e-20,
#        8.30699308e-20, 2.88241740e-20, 8.70400596e-20, 9.76652409e-20,
#        8.43296521e-20, 4.54384864e-20, 3.76803345e-20])
