# %% [markdown]
# # Review HD results
#
#
# This notebook compares the posteriors derived using the Earth terms and the pulsar terms
#
# ---

# %% [markdown]
# First load everything:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
import numpy as np 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %% [markdown]
# # 3 sources example

# %%
from plotting import plot_custom_corner



ranges = None 
labels = None
axes_scales = None







seed = 1237
num_gw_sources = 10
generator = np.random.default_rng(seed)
omegas = generator.uniform(low = 1e-7,high=9e-7,size=num_gw_sources)
phis = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)
psis = generator.uniform(low = 0.0,high=np.pi,size=num_gw_sources)
iotas = np.ones(num_gw_sources)
deltas = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)
alphas = generator.uniform(low = 0.0,high=np.pi,size=num_gw_sources)
hs = np.ones(num_gw_sources) * 1e-15
#injection_parameters = np.array([omegas,phis,psis,iotas,deltas,alphas,hs]).flatten()
injection_parameters = omegas
ranges = [(1e-7,9e-7) for i in range(len(omegas))]


num = num_gw_sources
omegas = [f"omega_gw_{i}" for i in range(num)]
variables_to_plot = omegas
labels = [rf"$\Omega_{i}$" for i in range(num)]



path = '../data/nested_sampling/floor_earth_10_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   np.array(variables_to_plot),
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   savefig=None,
                   smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/nested_sampling/floor_earth_10_result.json
# The evidence is: 586490.271048667
# The number of samples is: 13066
# Variable/Injection/Median
# omega_gw_0 5.003255272215568e-07 4.296554348347965e-07
# omega_gw_1 6.288834910712302e-07 1.4309848390691882e-07
# omega_gw_2 2.877256971002258e-07 2.482333661415729e-07
# omega_gw_3 1.3438428995297515e-07 8.676161497060703e-07
# omega_gw_4 4.1999098255152343e-07 5.770321488315753e-07
# omega_gw_5 5.423061344842906e-07 6.345643191685698e-07
# omega_gw_6 3.349671237983976e-07 4.511577969830615e-07
# omega_gw_7 5.092180221602693e-07 4.6515259437232635e-07
# omega_gw_8 7.375459647097501e-07 1.8653901738485742e-07
# omega_gw_9 1.4530398066811507e-07 5.692097762519094e-07
# -------------------------------

# %%
from plotting import plot_custom_corner



ranges = None 
labels = None
axes_scales = None







seed = 1237
num_gw_sources = 10
generator = np.random.default_rng(seed)
omegas = generator.uniform(low = 1e-7,high=9e-7,size=num_gw_sources)
phis = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)
psis = generator.uniform(low = 0.0,high=np.pi,size=num_gw_sources)
iotas = np.ones(num_gw_sources)
deltas = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)
alphas = generator.uniform(low = 0.0,high=np.pi,size=num_gw_sources)
hs = np.ones(num_gw_sources) * 1e-15
injection_parameters = np.array([omegas,phis,psis,iotas,deltas,alphas,hs]).flatten()



num = num_gw_sources


omegas = [f"omega_gw_{i}" for i in range(num)]
phis   = [f"phi0_gw_{i}" for i in range(num)]
psis   = [f"psi_gw_{i}" for i in range(num)]
iotas  = [f"iota_gw_{i}" for i in range(num)]
deltas = [f"delta_gw_{i}" for i in range(num)]
alphas = [f"alpha_gw_{i}" for i in range(num)]
hs     = [f"h_{i}" for i in range(num)]
variables_to_plot = np.array([omegas,phis,psis,iotas,deltas,alphas,hs]).flatten()


path = '../data/nested_sampling/floor_earth_10_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   np.array(variables_to_plot),
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   savefig=None,
                   smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/nested_sampling/floor_earth_10_result.json
# The evidence is: 586490.271048667
# The number of samples is: 13066
# Variable/Injection/Median
# omega_gw_0 5.003255272215568e-07 4.296554348347965e-07
# omega_gw_1 6.288834910712302e-07 1.4309848390691882e-07
# omega_gw_2 2.877256971002258e-07 2.482333661415729e-07
# omega_gw_3 1.3438428995297515e-07 8.676161497060703e-07
# omega_gw_4 4.1999098255152343e-07 5.770321488315753e-07
# omega_gw_5 5.423061344842906e-07 6.345643191685698e-07
# omega_gw_6 3.349671237983976e-07 4.511577969830615e-07
# omega_gw_7 5.092180221602693e-07 4.6515259437232635e-07
# omega_gw_8 7.375459647097501e-07 1.8653901738485742e-07
# omega_gw_9 1.4530398066811507e-07 5.692097762519094e-07
# phi0_gw_0 0.8247892577931843 1.1051165267127911
# phi0_gw_1 0.16229997501462393 1.522890710575195
# phi0_gw_2 0.12075498108616195 1.3929885755690354
# phi0_gw_3 0.23438899933450566 1.1651435806506512
# ...
