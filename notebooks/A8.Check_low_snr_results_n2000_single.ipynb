# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
import numpy as np 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %% [markdown]
# # Low SNR, pulsar terms

# %%
import glob 
from plotting import stacked_corner


#default values of GW parameters
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(1e-15,9e-15)]


#ranges = None
injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-15]
labels = [r'$10^9 \Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$10^{15} h_0$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None

list_of_files = sorted(glob.glob('/Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/*_pulsar_5e-15*')) #all the low snr pulsar results

#or select manually
#idx = 10
#list_of_files = list_of_files[idx:idx+10]
#list_of_files = ['/Users/t1/github_repos/StateSpacePTA/data/nested_sampling/compressed_files/bigrun_pulsar_5e-15_1300']

number_of_files_to_plot = len(list_of_files)
print("Plotting this many files:", number_of_files_to_plot)
#Corner plot of GW parameters
fig = stacked_corner(list_of_files,
                   number_of_files_to_plot,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e15], #the scalings for omega and h
                   savefig='corner_lowSNR',
                   smooth=True,smooth1d=True)
# Out:
# Plotting this many files: 10
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1245_result.json
# The evidence is: 585625.8048605279
# The number of samples is: 20127
# Variable/Injection/Median
# omega_gw 500.0 497.74801256935524
# phi0_gw 0.2 0.1838748385726302
# psi_gw 2.5 2.3703056368896975
# iota_gw 1.0 0.6005561860509693
# delta_gw 1.0 0.7670061238080221
# alpha_gw 1.0 0.8376947306490511
# h 5.0 3.0829581267513007
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $10^9 \Omega$ 0.004387067892419127 2.3486553019722596
# $\Phi_0$ 0.5440192467292747 0.13711058894934178
# $\psi$ 0.0565531138512726 0.1696600762302962
# $\iota$ 0.41498521405537264 0.4782891364412431
# $\delta$ 0.21273090946393974 0.2306492124337602
# $\alpha$ 0.18140022524361274 0.2295122961829398
# $10^{15} h_0$ 0.3639189647432797 1.9194228686996258
# *****************************
# debug: 0 0
# debug: 1 0
# debug: 2 0
# debug: 3 0
# debug: 4 0
# debug: 5 0
# debug: 6 0
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1246_result.json
# The evidence is: 585765.9959208963
# The number of samples is: 18928
# Variable/Injection/Median
# omega_gw 500.0 501.2981949342209
# phi0_gw 0.2 0.44046921022444707
# psi_gw 2.5 2.5135615391289834
# iota_gw 1.0 0.9024466998401557
# delta_gw 1.0 0.916946605249189
# alpha_gw 1.0 1.0214968963812758
# h 5.0 4.130935890305516
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $10^9 \Omega$ 0.002712732344702062 1.5646819124852036
# $\Phi_0$ 1.265988787074342 0.29586636351309875
# $\psi$ 0.0294273249178377 0.09706307409277985
# $\iota$ 0.28914473517704115 0.3489425633488858
# $\delta$ 0.09507704043830463 0.11669824527755736
# $\alpha$ 0.07552698705369544 0.10925185890918232
# $10^{15} h_0$ 0.2054057878334317 1.2115587827716565
# *****************************
# debug: 0 1
# debug: 1 1
# debug: 2 1
# debug: 3 1
# debug: 4 1
# debug: 5 1
# debug: 6 1
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1247_result.json
# The evidence is: 585861.9066464042
# The number of samples is: 22303
# Variable/Injection/Median
# omega_gw 500.0 501.32428025859076
# phi0_gw 0.2 0.36766779381544723
# psi_gw 2.5 2.4591730457958003
# iota_gw 1.0 0.7830688083561207
# delta_gw 1.0 0.9505874327899213
# alpha_gw 1.0 1.0167952186914389
# h 5.0 3.566045318958633
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $10^9 \Omega$ 0.0027680683038546223 1.6047201933643687
# $\Phi_0$ 1.0046533163237863 0.2482978135134236
# $\psi$ 0.03314888112693045 0.10478669950682361
# $\iota$ 0.32386051266909865 0.3847327903503479
# $\delta$ 0.0640544572633227 0.08354455903856546
# $\alpha$ 0.0748016349088752 0.10499153532679523
# $10^{15} h_0$ 0.2740778974261805 1.5316001833844874
# *****************************
# debug: 0 2
# debug: 1 2
# debug: 2 2
# debug: 3 2
# debug: 4 2
# debug: 5 2
# debug: 6 2
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1248_result.json
# The evidence is: 585883.0904464811
# The number of samples is: 20398
# Variable/Injection/Median
# omega_gw 500.0 500.58113135813477
# phi0_gw 0.2 0.3845245664964249
# psi_gw 2.5 0.8934468352579873
# iota_gw 1.0 0.737884964998972
# delta_gw 1.0 0.8815781403481915
# alpha_gw 1.0 2.4924130532475317
# h 5.0 3.4097118043926917
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# median psi is weird and won't match axis limits
# Breaking due to weird psi
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1249_result.json
# The evidence is: 585647.6576637047
# The number of samples is: 20212
# Variable/Injection/Median
# omega_gw 500.0 500.2606824417601
# phi0_gw 0.2 0.1728008453397551
# psi_gw 2.5 2.4086081641938075
# iota_gw 1.0 0.7766208813581483
# delta_gw 1.0 0.9133805232979473
# alpha_gw 1.0 0.9387117117723898
# h 5.0 4.053195668646966
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $10^9 \Omega$ 0.0012469318458769028 0.792140604557778
# $\Phi_0$ 0.5234912027648335 0.12819021556850163
# $\psi$ 0.04661570625167212 0.14682697324296384
# $\iota$ 0.3265208499383346 0.3928302693831189
# $\delta$ 0.09875822571136346 0.11955419915658282
# $\alpha$ 0.11000052953713592 0.15189064638149158
# $10^{15} h_0$ 0.2064860806911497 1.189279169398344
# *****************************
# debug: 0 4
# debug: 1 4
# debug: 2 4
# debug: 3 4
# debug: 4 4
# debug: 5 4
# debug: 6 4
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1250_result.json
# The evidence is: 585602.0873781973
# The number of samples is: 20897
# Variable/Injection/Median
# omega_gw 500.0 501.5728904995635
# phi0_gw 0.2 0.6639520293194114
# psi_gw 2.5 2.474500352614387
# iota_gw 1.0 0.5954649079522212
# delta_gw 1.0 1.0012306059356728
# alpha_gw 1.0 0.9205950942088289
# h 5.0 4.182754220703325
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $10^9 \Omega$ 0.0031595538751262127 1.7195938394377415
# $\Phi_0$ 2.303693442941264 0.4861760438973323
# $\psi$ 0.03556145263783236 0.11764466646333001
# $\iota$ 0.41387887019632896 0.467877808017439
# $\delta$ 0.04275851033428513 0.05510438139830251
# $\alpha$ 0.11329502853728338 0.14805078449061962
# $10^{15} h_0$ 0.17459779503739 1.003041327020731
# *****************************
# debug: 0 5
# debug: 1 5
# debug: 2 5
# debug: 3 5
# debug: 4 5
# debug: 5 5
# debug: 6 5
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1251_result.json
# The evidence is: 585755.6625344953
# The number of samples is: 23448
# Variable/Injection/Median
# omega_gw 500.0 501.25973899966596
# phi0_gw 0.2 0.3277299009619291
# psi_gw 2.5 2.4972929671678665
# iota_gw 1.0 0.6164237351086725
# delta_gw 1.0 0.9491707401595775
# alpha_gw 1.0 1.017447887689053
# h 5.0 3.4999279372867127
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $10^9 \Omega$ 0.002654199130903893 1.5436832083751293
# $\Phi_0$ 0.8457367639503807 0.2124129034708982
# $\psi$ 0.03082687683763515 0.10291112488088681
# $\iota$ 0.4003488695721768 0.45960849098664397
# $\delta$ 0.06572339280731931 0.08759317102337005
# $\alpha$ 0.07995944226025452 0.1116445575225254
# $10^{15} h_0$ 0.28575943593700043 1.5442956789893716
# *****************************
# debug: 0 6
# debug: 1 6
# debug: 2 6
# debug: 3 6
# debug: 4 6
# debug: 5 6
# debug: 6 6
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1252_result.json
# The evidence is: 585652.133109535
# The number of samples is: 21873
# Variable/Injection/Median
# omega_gw 500.0 501.186696471575
# phi0_gw 0.2 0.4544365029060474
# psi_gw 2.5 2.6463684859959047
# iota_gw 1.0 0.7240104217978156
# delta_gw 1.0 0.9648353542297038
# alpha_gw 1.0 1.0627068901098315
# h 5.0 4.5243298029173395
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $10^9 \Omega$ 0.002456867010886814 1.413509571555298
# $\Phi_0$ 1.320216089343337 0.3092610196229161
# $\psi$ 0.059445750266945846 0.1676268005249984
# $\iota$ 0.3426241624912056 0.40758669768931016
# $\delta$ 0.061186668591187265 0.08304327081446389
# $\alpha$ 0.11459067325252649 0.1421051255737289
# $10^{15} h_0$ 0.16645514683987053 0.9959224608893571
# *****************************
# debug: 0 7
# debug: 1 7
# debug: 2 7
# debug: 3 7
# debug: 4 7
# debug: 5 7
# debug: 6 7
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1253_result.json
# The evidence is: 585760.927503518
# The number of samples is: 21015
# Variable/Injection/Median
# omega_gw 500.0 501.18613728590736
# phi0_gw 0.2 0.18642514412110334
# psi_gw 2.5 2.474869987187933
# iota_gw 1.0 0.8003356397706388
# delta_gw 1.0 0.9919035462483866
# alpha_gw 1.0 0.9790587103178499
# h 5.0 3.789075179605147
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $10^9 \Omega$ 0.0024978819101854808 1.4554215574577296
# $\Phi_0$ 0.54992466963704 0.13563628783021092
# $\psi$ 0.04744449006238533 0.14904082022202958
# $\iota$ 0.3093826542618976 0.3685271164141978
# $\delta$ 0.04656813250065651 0.06206245087457723
# $\alpha$ 0.13064081280054668 0.16747525740178673
# $10^{15} h_0$ 0.24680520450363289 1.408265273751766
# *****************************
# debug: 0 8
# debug: 1 8
# debug: 2 8
# debug: 3 8
# debug: 4 8
# debug: 5 8
# debug: 6 8
# Extracting data from file:  /Users/t1/github_repos/StateSpacePTA/data/dir_eg_canonical_bias_exploration_single_bounding/eg_canonical_bias_exploration_single_bounding_pulsar_5e-15_1254_result.json
# The evidence is: 585648.21015766
# The number of samples is: 22536
# Variable/Injection/Median
# omega_gw 500.0 499.8531774888373
# phi0_gw 0.2 0.2721278874799209
# psi_gw 2.5 2.4276040219987074
# iota_gw 1.0 0.7019982707871162
# delta_gw 1.0 0.884738977818131
# alpha_gw 1.0 0.9033844179661442
# h 5.0 3.3792523477604695
# -------------------------------
# VARS TO PLOT ARE: ['omega_gw', 'phi0_gw', 'psi_gw', 'iota_gw', 'delta_gw', 'alpha_gw', 'h']
# The error in the 1D posteriors is as follows:
# $10^9 \Omega$ 0.001225405584919394 0.7681332156057094
# $\Phi_0$ 0.689635587037148 0.17543878787461306
# $\psi$ 0.04074394700342021 0.13030660530180743
# $\iota$ 0.3389959764382262 0.4006213460627967
# $\delta$ 0.12242300641179149 0.14121898765401247
# $\alpha$ 0.1362661972731641 0.17639275442287825
# $10^{15} h_0$ 0.3080344645640026 1.6632786638133292
# *****************************
# debug: 0 9
# debug: 1 9
# debug: 2 9
# debug: 3 9
# debug: 4 9
# debug: 5 9
# debug: 6 9
# Setting y major locator
# This is for axis: AxesSubplot(0.5875,0.325;0.125x0.125)
# Setting y major locator
# This is for axis: AxesSubplot(0.0625,0.19375;0.125x0.125)
# Setting y major locator
# This is for axis: AxesSubplot(0.19375,0.19375;0.125x0.125)
# Setting y major locator
# This is for axis: AxesSubplot(0.325,0.19375;0.125x0.125)
# Setting y major locator
# This is for axis: AxesSubplot(0.45625,0.19375;0.125x0.125)
# Setting y major locator
# This is for axis: AxesSubplot(0.5875,0.19375;0.125x0.125)
# Surfacing some numbers for comparing two posteriors
