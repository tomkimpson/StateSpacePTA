# %% [markdown]
# # Plots for paper

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %%
from plotting import plot_custom_corner

# %%
import numpy as np 

path = "../data/nested_sampling/data_for_manuscript/paper_canonical_example_earth_terms_1237_v2_result.json"

val = 1e-12

ranges=[(495,505),(0.05,0.50),(2.0,3.0),(0.0,np.pi/2.0),(0.5,1.1),(0.9,1.1),(0.5*val*1e12,1.5*val*1e12)]
injection_parameters = [5e-7*1e9,0.20,2.50,1.0,1.0,1.0,val*1e12]
labels = [r'$\Omega [\text{nHz}]$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10^{12}}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None

#Corner plot of GW parameters
plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=None)
# Out:
# json
# The evidence is: -538100.848569793
#         omega_gw   phi0_gw    psi_gw   iota_gw  delta_gw  alpha_gw         h  \
# 0     500.011586  0.196258  2.597662  0.738069  1.001450  1.041088  1.051818
# 1     500.009880  0.195615  2.599271  0.673460  1.001732  1.041584  1.011460
# 2     500.001193  0.193575  2.597799  0.791162  1.000761  1.041046  1.089261
# 3     500.007491  0.193849  2.598483  0.848028  1.001877  1.041711  1.132162
# 4     500.001372  0.195064  2.598857  0.587486  1.001873  1.041612  0.960797
# ...          ...       ...       ...       ...       ...       ...       ...
# 6657  500.000582  0.194116  2.598741  0.790842  1.001953  1.041444  1.090860
# 6658  499.998689  0.193743  2.597330  0.751355  1.001290  1.040488  1.061605
# 6659  499.994016  0.194176  2.600075  0.710999  1.002698  1.042420  1.034600
# 6660  500.001179  0.194334  2.600152  0.687094  1.002542  1.042278  1.020039
# 6661  499.997350  0.192869  2.598703  0.778236  1.001854  1.041508  1.080033
#
#              f00         f01         f02  ...    distance40    distance41  \
# 0     330.631382  207.386993  302.129437  ...  6.000000e+10  1.800000e+11
# 1     330.613692  207.168469  301.049199  ...  6.000000e+10  1.800000e+11
# 2     330.959752  207.022818  303.458181  ...  6.000000e+10  1.800000e+11
# 3     330.737797  207.172609  301.389457  ...  6.000000e+10  1.800000e+11
# 4     330.455501  207.196822  302.589219  ...  6.000000e+10  1.800000e+11
# ...          ...         ...         ...  ...           ...           ...
# 6657  330.299022  206.613664  302.535751  ...  6.000000e+10  1.800000e+11
# 6658  330.611385  207.239666  301.549602  ...  6.000000e+10  1.800000e+11
# 6659  330.505402  207.478963  301.790660  ...  6.000000e+10  1.800000e+11
# 6660  330.469088  207.423341  302.582766  ...  6.000000e+10  1.800000e+11
# 6661  330.875488  206.560205  301.581128  ...  6.000000e+10  1.800000e+11
#
#         distance42    distance43    distance44    distance45    distance46  \
# 0     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 1     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 2     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 3     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# ...            ...           ...           ...           ...           ...
# 6657  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 6658  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 6659  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 6660  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 6661  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
#
#            sigma_m  log_likelihood    log_prior
# 0     1.000000e-11  -537977.678045  3879.494701
# 1     1.000000e-11  -537977.488592  3884.746145
# 2     1.000000e-11  -537976.709689  3875.571889
# 3     1.000000e-11  -537976.124072  3875.984701
# 4     1.000000e-11  -537976.079017  3881.544249
# ...            ...             ...          ...
# 6657  1.000000e-11  -537897.569746  3876.373541
# 6658  1.000000e-11  -537895.921609  3884.769035
# 6659  1.000000e-11  -537892.855297  3878.190584
# 6660  1.000000e-11  -537890.597193  3875.415620
# 6661  1.000000e-11  -537889.362076  3878.614972
#
# [6662 rows x 245 columns]
# Number of samples:
# 6662
# Truths/Medians/Variances
# $\Omega [\text{nHz}]$ 500.0 500.00255852460043 2.021605805847573e-05
# $\Phi_0$ 0.2 0.19431272952866657 5.492024712492025e-07
# $\psi$ 2.5 2.5990842417723785 3.163586962623134e-07
# $\iota$ 1.0 0.7056147629276832 0.006118553964574223
# $\delta$ 1.0 1.0019729392831482 1.8170782112164935e-07
# $\alpha$ 1.0 1.0418855445212878 1.445432853268127e-07
# $h_{0, \times 10^{12}}$ 1.0 1.0316406149678632 0.0025106008831289176
# running with increased label size
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# **********************************************************************

# %%
import numpy as np 
path = "../data/nested_sampling/data_for_manuscript/paper_bayes_ratios_n2000_V3_h_8.511380382023759e-15_model_earth_seed_1245_result.json"




val = 8.511380382023759e-15

ranges=[(495,505),(0.05,0.50),(2.0,3.0),(0.0,np.pi/2.0),(0.5,1.1),(0.9,1.1),(0.5*val*1e12,1.5*val*1e12)]
injection_parameters = [5e-7*1e9,0.20,2.50,1.0,1.0,1.0,val*1e12]
labels = [r'$\Omega [\text{nHz}]$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10^{12}}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None

#Corner plot of GW parameters
plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=None)
# Out:
# json
# The evidence is: 585562.4823379245
#         omega_gw   phi0_gw    psi_gw   iota_gw  delta_gw  alpha_gw         h  \
# 0     498.362721  0.328191  2.478183  0.379855  0.879932  1.061324  0.006674
# 1     500.174768  0.311689  2.133946  0.583227  0.738834  0.451132  0.006088
# 2     500.897042  0.589582  2.546824  0.504998  0.861800  0.984277  0.006193
# 3     500.457836  0.340008  2.206925  1.112440  0.671524  0.470878  0.010265
# 4     500.733797  0.442676  2.476219  0.999923  0.738687  0.821889  0.008319
# ...          ...       ...       ...       ...       ...       ...       ...
# 9663  498.733963  0.119646  2.500889  0.514809  0.942297  1.008204  0.007719
# 9664  498.972713  0.180483  2.524564  0.848310  0.952035  1.030324  0.009494
# 9665  498.892532  0.168677  2.511246  0.557815  0.954745  1.018520  0.007796
# 9666  498.938416  0.154808  2.508631  0.836639  0.942374  1.011376  0.009150
# 9667  498.767328  0.132911  2.506882  0.761614  0.945371  1.014060  0.008760
#
#              f00         f01         f02  ...    distance40    distance41  \
# 0     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 1     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 2     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 3     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 4     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# ...          ...         ...         ...  ...           ...           ...
# 9663  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 9664  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 9665  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 9666  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 9667  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
#
#         distance42    distance43    distance44    distance45    distance46  \
# 0     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 1     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 2     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 3     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# ...            ...           ...           ...           ...           ...
# 9663  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 9664  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 9665  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 9666  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 9667  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
#
#            sigma_m  log_likelihood    log_prior
# 0     1.000000e-11   585572.438472  4753.442483
# 1     1.000000e-11   585576.355544  4745.834572
# 2     1.000000e-11   585576.527763  4751.115643
# 3     1.000000e-11   585576.883764  4757.992244
# 4     1.000000e-11   585577.065999  4754.161657
# ...            ...             ...          ...
# 9663  1.000000e-11   585590.711031  4739.226052
# 9664  1.000000e-11   585590.717448  4743.550553
# 9665  1.000000e-11   585590.743099  4758.170399
# 9666  1.000000e-11   585590.756623  4744.086775
# 9667  1.000000e-11   585590.769328  4743.770261
#
# [9668 rows x 245 columns]
# Number of samples:
# 9668
# Truths/Medians/Variances
# $\Omega [\text{nHz}]$ 500.0 499.198704166694 0.40524891933079066
# $\Phi_0$ 0.2 0.203230525743898 0.010247976570547115
# $\psi$ 2.5 2.5009234608881554 0.0030745260218675323
# $\iota$ 1.0 0.638924231184075 0.11471113568048792
# $\delta$ 1.0 0.9360517175920366 0.0034884201695216514
# $\alpha$ 1.0 1.006618503731211 0.005190749776970032
# $h_{0, \times 10^{12}}$ 0.008511380382023759 0.00779391536559511 3.2428435941608906e-06
# running with increased label size
# **********************************************************************

# %%
import numpy as np 
path = "../data/nested_sampling/data_for_manuscript/paper_bayes_ratios_n2000_V3_h_6.4565422903465625e-15_model_earth_seed_1245_result.json"



ranges=[(495,505),(0.05,0.50),(2.0,3.0),(0.0,np.pi/2.0),(0.5,1.1),(0.9,1.1),(0.5*6.4565422903465625e-15*1e12,1.5*6.4565422903465625e-15*1e12)]
injection_parameters = [5e-7*1e9,0.20,2.50,1.0,1.0,1.0,6.4565422903465625e-15*1e12]
labels = [r'$\Omega [\text{nHz}]$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10^{12}}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None

#Corner plot of GW parameters
plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=None)
# Out:
# json
# The evidence is: 585599.8771072715
#         omega_gw   phi0_gw    psi_gw   iota_gw  delta_gw  alpha_gw         h  \
# 0     500.444036  0.403072  2.139014  0.893971  0.496763  0.501410  0.004791
# 1     502.177954  0.664008  2.079865  1.235892  0.604433  0.341423  0.006384
# 2     501.506679  0.717698  2.268542  0.675436  0.604708  0.608858  0.005652
# 3     499.614664  0.273849  2.244924  0.591170  0.715572  0.359737  0.004214
# 4     499.376398  0.057369  2.409632  0.948108  0.504982  0.800031  0.006966
# ...          ...       ...       ...       ...       ...       ...       ...
# 9572  498.482283  0.107374  2.506751  0.676765  0.938245  1.022389  0.006565
# 9573  498.270645  0.106089  2.515987  1.175213  0.936683  1.024857  0.008933
# 9574  498.859958  0.188536  2.486511  0.997019  0.932414  1.013638  0.007902
# 9575  498.467187  0.140185  2.511838  0.949860  0.934207  1.024876  0.007573
# 9576  498.577063  0.112832  2.496322  0.517885  0.924794  1.017013  0.005868
#
#              f00         f01         f02  ...    distance40    distance41  \
# 0     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 1     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 2     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 3     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 4     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# ...          ...         ...         ...  ...           ...           ...
# 9572  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 9573  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 9574  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 9575  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 9576  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
#
#         distance42    distance43    distance44    distance45    distance46  \
# 0     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 1     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 2     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 3     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# ...            ...           ...           ...           ...           ...
# 9572  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 9573  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 9574  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 9575  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 9576  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
#
#            sigma_m  log_likelihood    log_prior
# 0     1.000000e-11   585603.512593  4752.755463
# 1     1.000000e-11   585606.955050  4750.679218
# 2     1.000000e-11   585607.748460  4758.773496
# 3     1.000000e-11   585609.423411  4745.143087
# 4     1.000000e-11   585609.648093  4750.966032
# ...            ...             ...          ...
# 9572  1.000000e-11   585623.295100  4760.020527
# 9573  1.000000e-11   585623.295248  4764.053433
# 9574  1.000000e-11   585623.299045  4734.081986
# 9575  1.000000e-11   585623.303290  4753.936225
# 9576  1.000000e-11   585623.326595  4744.071184
#
# [9577 rows x 245 columns]
# Number of samples:
# 9577
# Truths/Medians/Variances
# $\Omega [\text{nHz}]$ 500.0 498.8523331922877 0.6175831568499784
# $\Phi_0$ 0.2 0.19704492886635336 0.014193896428317952
# $\psi$ 2.5 2.4493781672505004 0.010068958960674921
# $\iota$ 1.0 0.8035260048900438 0.1342233316279845
# $\delta$ 1.0 0.883338657506636 0.01104074125799925
# $\alpha$ 1.0 0.9799369927535543 0.02553159449577114
# $h_{0, \times 10^{12}}$ 0.006456542290346563 0.006449051811846719 2.4605266129351222e-06
# running with increased label size
# **********************************************************************

# %%
import numpy as np 
path = "../data/nested_sampling/data_for_manuscript/paper_bayes_ratios_n2000_V3_h_5.248074602497734e-15_model_earth_seed_1245_result.json"



ranges=[(495,505),(0.05,0.50),(2.0,3.0),(0.0,np.pi/2.0),(0.5,1.1),(0.9,1.1),(0.5*5.248074602497734e-15*1e12,1.5*5.248074602497734e-15*1e12)]
injection_parameters = [5e-7*1e9,0.20,2.50,1.0,1.0,1.0,5.248074602497734e-15*1e12]
labels = [r'$\Omega [\text{nHz}]$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10^{12}}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None

#Corner plot of GW parameters
plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=None)
# Out:
# json
# The evidence is: 585616.1350038428
#          omega_gw   phi0_gw    psi_gw   iota_gw  delta_gw  alpha_gw         h  \
# 0      501.318745  0.631112  2.184660  0.109265  0.885374  0.442403  0.002226
# 1      499.353847  0.271297  2.464977  0.813079  0.580328  0.971284  0.003126
# 2      502.105468  0.507811  2.374735  1.251868  0.784657  1.208149  0.006386
# 3      501.710983  0.658508  2.283188  1.028356  0.520870  0.874271  0.005378
# 4      501.599475  0.604532  2.445794  0.556322  0.738220  0.695567  0.002836
# ...           ...       ...       ...       ...       ...       ...       ...
# 10082  498.002692  0.075042  2.465000  1.456021  0.900369  1.006409  0.007844
# 10083  497.855724  0.108380  2.481293  1.122545  0.928278  1.003464  0.007005
# 10084  498.169280  0.090425  2.479905  0.813961  0.898931  1.009813  0.005521
# 10085  498.332700  0.112112  2.462944  0.883413  0.913589  0.999033  0.005822
# 10086  498.147089  0.116622  2.470456  0.822712  0.922108  1.009037  0.005624
#
#               f00         f01         f02  ...    distance40    distance41  \
# 0      327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 1      327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 2      327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 3      327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 4      327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# ...           ...         ...         ...  ...           ...           ...
# 10082  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 10083  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 10084  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 10085  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 10086  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
#
#          distance42    distance43    distance44    distance45    distance46  \
# 0      9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 1      9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 2      9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 3      9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4      9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# ...             ...           ...           ...           ...           ...
# 10082  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 10083  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 10084  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 10085  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 10086  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
#
#             sigma_m  log_likelihood    log_prior
# 0      1.000000e-11   585621.219486  4743.898880
# 1      1.000000e-11   585621.883041  4747.471558
# 2      1.000000e-11   585623.170088  4757.539140
# 3      1.000000e-11   585623.648879  4729.984372
# 4      1.000000e-11   585623.746156  4743.884684
# ...             ...             ...          ...
# 10082  1.000000e-11   585637.886838  4749.964352
# 10083  1.000000e-11   585637.919654  4759.945224
# 10084  1.000000e-11   585637.923876  4771.674880
# 10085  1.000000e-11   585637.934019  4749.616671
# 10086  1.000000e-11   585638.034126  4747.252642
#
# [10087 rows x 245 columns]
# Number of samples:
# 10087
# Truths/Medians/Variances
# $\Omega [\text{nHz}]$ 500.0 498.88161677570423 1.008833490234618
# $\Phi_0$ 0.2 0.22573950755878808 0.02051996956076526
# $\psi$ 2.5 2.403592594966086 0.014978920776873255
# $\iota$ 1.0 0.9448872980444002 0.1280947663773421
# $\delta$ 1.0 0.7592156234489206 0.015094293705402254
# $\alpha$ 1.0 0.9129679388043577 0.03956269697253466
# $h_{0, \times 10^{12}}$ 0.005248074602497734 0.005555785164947876 1.7144883739589698e-06
# running with increased label size
# **********************************************************************

# %%
import glob
list_of_files = sorted(glob.glob("../data/nested_sampling/data_for_manuscript/small_h_batch/*"))


#2 is good
path = list_of_files[9]
print(path)
val = 5e-15

ranges=[(495,505),(0.05,0.50),(2.0,3.0),(0.0,np.pi/2.0),(0.5,1.1),(0.9,1.1),(0.5*val*1e12,1.5*val*1e12)]
injection_parameters = [5e-7*1e9,0.20,2.50,1.0,1.0,1.0,val*1e12]
labels = [r'$\Omega [\text{nHz}]$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10^{12}}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None

#Corner plot of GW parameters
plot_custom_corner(path,variables_to_plot,labels,injection_parameters,ranges,axes_scales,savefig=None)
# Out:
# ../data/nested_sampling/data_for_manuscript/small_h_batch/small_h_model_earth_batch_1254_result.json
# json
# The evidence is: 585639.1427150589
#         omega_gw   phi0_gw    psi_gw   iota_gw  delta_gw  alpha_gw         h  \
# 0     498.387461  0.220356  2.394796  0.589517  1.074859  0.783759  0.002311
# 1     500.329897  0.589007  2.512257  0.445483  0.922013  0.745689  0.003265
# 2     501.444015  0.524420  2.261783  0.347987  0.883708  0.646764  0.001882
# 3     500.689440  0.397962  2.359426  0.243071  0.802204  0.958092  0.002452
# 4     503.446742  0.604847  2.102518  0.671809  0.925528  0.563227  0.003216
# ...          ...       ...       ...       ...       ...       ...       ...
# 4635  499.228265  0.017836  2.516151  0.826773  0.985549  0.905609  0.005166
# 4636  499.554390  0.026346  2.511913  0.770968  0.940875  0.899289  0.005123
# 4637  499.639297  0.047641  2.487749  0.484437  0.929363  0.903847  0.004258
# 4638  499.643463  0.067424  2.511614  1.122467  0.975166  0.916689  0.006244
# 4639  499.486036  0.015555  2.511179  1.406624  0.935426  0.919273  0.007104
#
#              f00         f01         f02  ...    distance40    distance41  \
# 0     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 1     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 2     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 3     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 4     327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# ...          ...         ...         ...  ...           ...           ...
# 4635  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 4636  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 4637  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 4638  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
# 4639  327.847021  205.530699  303.090979  ...  6.000000e+10  1.800000e+11
#
#         distance42    distance43    distance44    distance45    distance46  \
# 0     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 1     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 2     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 3     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4     9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# ...            ...           ...           ...           ...           ...
# 4635  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4636  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4637  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4638  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
# 4639  9.708667e+10  1.587000e+11  8.630000e+10  1.666655e+11  1.011000e+11
#
#            sigma_m  log_likelihood    log_prior
# 0     1.000000e-11   585649.871238  4755.476556
# 1     1.000000e-11   585649.932631  4746.560391
# 2     1.000000e-11   585650.222809  4753.074348
# 3     1.000000e-11   585650.841511  4757.491502
# 4     1.000000e-11   585651.211400  4759.068536
# ...            ...             ...          ...
# 4635  1.000000e-11   585663.440222  4748.012767
# 4636  1.000000e-11   585663.447243  4755.979694
# 4637  1.000000e-11   585663.458539  4740.512000
# 4638  1.000000e-11   585663.465596  4746.154791
# 4639  1.000000e-11   585663.532475  4761.657296
#
# [4640 rows x 245 columns]
# Number of samples:
# 4640
# Truths/Medians/Variances
# $\Omega [\text{nHz}]$ 500.0 500.23988161558384 0.6832271834919309
# $\Phi_0$ 0.2 0.15971019281609966 0.01545431618571453
# $\psi$ 2.5 2.4635699019188375 0.011759899983510604
# $\iota$ 1.0 0.6538255792977228 0.10997856748385622
# $\delta$ 1.0 0.9322826420619005 0.0076954171578709945
# $\alpha$ 1.0 0.8583162213477316 0.014425873407890767
# $h_{0, \times 10^{12}}$ 0.005 0.004225961839989382 1.1060019643523335e-06
# running with increased label size
# **********************************************************************
