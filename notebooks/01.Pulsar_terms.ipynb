# %% [markdown]
# # First attempt at pulsar terms
#
#
# This notebook is our first attempt at generating posteriors including the pulsar terms.
#
# It is based on a run with 2500 live points, h= $5 \times 10^{-15}$ and $\Omega = 5 \times 10^{-7}$ Hz.
#
#
# ---

# %% [markdown]
# First load everything:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
import numpy as np 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %% [markdown]
# Now plot the result from a single run:

# %%
from plotting import plot_custom_corner


#default values of GW parameters
ranges=[(4e-7,6e-7),(0.5,1.5),(1.2,2.6),(0.4,1.6),(0.8,1.2),(0.2,1.5),(3e-15,7e-15)]

injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-15]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
ranges = None
path = '../data/nested_sampling/pulsar_terms_test_h5e15_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e15], #the scalings for omega and h
                   savefig=None,
                   smooth=False,smooth1d=False)
# Out:
# The evidence is: 585693.964244452
# The number of samples is: 12411
# Variable/Injection/Median
# omega_gw 500.0 504.95904589474634
# phi0_gw 0.2 1.10622875454441
# psi_gw 2.5 1.960905189893369
# iota_gw 1.0 1.3547341321466422
# delta_gw 1.0 1.008272725260226
# alpha_gw 1.0 0.28672608323388843
# h 5.0 4.671712646019925
# -------------------------------
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# # Try again! Now $h=10^{-12}$

# %%
from plotting import plot_custom_corner

#default values of GW parameters
ranges=[(4e-7,6e-7),(0.5,1.5),(1.2,2.6),(0.4,1.6),(0.8,1.2),(0.2,1.5),(5e-13,5e-12)]

injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-12]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
ranges = None
path = '../data/nested_sampling/pulsar_terms_test_h1e12_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e12], #the scalings for omega and h
                   savefig=None,
                   smooth=False,smooth1d=False)
# Out:
# The evidence is: -18894.668633730667
# The number of samples is: 11589
# Variable/Injection/Median
# omega_gw 500.0 500.6673281111228
# phi0_gw 0.2 0.17495628325682464
# psi_gw 2.5 2.571223859362265
# iota_gw 1.0 1.4390705182841081
# delta_gw 1.0 1.0072107511846151
# alpha_gw 1.0 1.0819289829200516
# h 5.0 1.1362384081942432
# -------------------------------

# %% [markdown]
# # This is $h = 10^{-12}$, with 4000 live points

# %%
from plotting import plot_custom_corner

#default values of GW parameters
ranges=[(4e-7,6e-7),(0.5,1.5),(1.2,2.6),(0.4,1.6),(0.8,1.2),(0.2,1.5),(5e-13,5e-12)]

injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-12]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
ranges = None
path = '../data/nested_sampling/psr_testing_h1e12_n4000_dlog01_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e12], #the scalings for omega and h
                   savefig=None,
                   smooth=False,smooth1d=False)
# Out:
# The evidence is: -200152.56974123226
# The number of samples is: 18689
# Variable/Injection/Median
# omega_gw 500.0 499.43324450348024
# phi0_gw 0.2 0.17574802965515887
# psi_gw 2.5 2.2309933627276712
# iota_gw 1.0 0.611280990635262
# delta_gw 1.0 0.9076762587763578
# alpha_gw 1.0 0.6417309194596684
# h 5.0 0.6068029932237292
# -------------------------------

# %% [markdown]
# # This is $h=10^{-12}$, with 1000 live points and a single ellipsoid decomposition

# %%
from plotting import plot_custom_corner

#default values of GW parameters
ranges=[(4e-7,6e-7),(0.5,1.5),(1.2,2.6),(0.4,1.6),(0.8,1.2),(0.2,1.5),(5e-13,5e-12)]

injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-12]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
ranges = None
path = '../data/nested_sampling/psr_testing_single_bound_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e12], #the scalings for omega and h
                   savefig=None,
                   smooth=False,smooth1d=False)
# Out:
# The evidence is: -439856.09967230266
# The number of samples is: 5099
# Variable/Injection/Median
# omega_gw 500.0 503.0268649400331
# phi0_gw 0.2 0.7011602862930345
# psi_gw 2.5 2.181779091006025
# iota_gw 1.0 0.45277300339677934
# delta_gw 1.0 0.7554409519869641
# alpha_gw 1.0 0.4722142601133173
# h 5.0 0.531985953801756
# -------------------------------
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# # This is the Eric/Tong/Jackie method

# %%
from plotting import plot_custom_corner


#default values of GW parameters
ranges=[(4e-7,6e-7),(0.5,1.5),(1.2,2.6),(0.4,1.6),(0.8,1.2),(0.2,1.5),(3e-15,7e-15)]

injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-15]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
ranges = None
path = '../data/nested_sampling/ETJ_5e15_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e15], #the scalings for omega and h
                   savefig='example_psr_terms',
                   smooth=True,smooth1d=True)
# Out:
# The evidence is: 585703.3301431705
# The number of samples is: 10574
# Variable/Injection/Median
# omega_gw 500.0 500.4573211749123
# phi0_gw 0.2 0.20003951912570755
# psi_gw 2.5 2.460247950595992
# iota_gw 1.0 0.6949203316193573
# delta_gw 1.0 0.9506490529642893
# alpha_gw 1.0 0.926582386307305
# h 5.0 3.460213092137367
# -------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/tomkimpson/github_repos/ssnew/StateSpacePTA/notebooks/01.Pulsar_terms.ipynb Cell 14 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/Users/tomkimpson/github_repos/ssnew/StateSpacePTA/notebooks/01.Pulsar_terms.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> path = '../data/nested_sampling/ETJ_5e15_result.json'
# ...
