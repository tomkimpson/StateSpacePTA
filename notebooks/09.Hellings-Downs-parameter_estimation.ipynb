# %% [markdown]
# # Hellings-Downs curve
#
#
#
#
# ---

# %% [markdown]
# ### Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %% [markdown]
# ### Define some useful functions

# %%
from plotting import plot_custom_corner
import numpy as np 

#default values of GW parameters
ranges = None



seed = 1237
num_gw_sources = 2
generator = np.random.default_rng(seed)
injection_parameters_1 = generator.uniform(low = 1e-7,high=1e-6,size=num_gw_sources)
injection_parameters_2 = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)
injection_parameters_3 = generator.uniform(low = 0.0,high=np.pi,size=num_gw_sources)

injection_parameters = np.concatenate([injection_parameters_1,injection_parameters_2,injection_parameters_3])
#injection_parameters = None 

labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
labels = None 

variables_to_plot = ["omega_gw_0","omega_gw_1","phi0_gw_0", "phi0_gw_1","psi_gw_0", "psi_gw_1"]


axes_scales = None
ranges = None
path = '../data/nested_sampling/HD_K2_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   savefig=None,
                   smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/nested_sampling/HD_K2_result.json
# The evidence is: 585699.0009913908
# Turned off scaling
# The number of samples is: 10600
# Variable/Injection/Median
# omega_gw_0 5.503662181242514e-07 1.619744459278467e-07
# omega_gw_1 6.94993927455134e-07 6.966071643436744e-07
# phi0_gw_0 0.3685985443125576 0.567057274503306
# phi0_gw_1 0.06751339544698005 0.7219890086743475
# psi_gw_0 1.2566016499985573 2.1726383831295797
# psi_gw_1 1.7369321284169326 1.5276356671789935
# -------------------------------

# %%
from plotting import plot_custom_corner
import numpy as np 

#default values of GW parameters
ranges = None



seed = 1237
num_gw_sources = 1
generator = np.random.default_rng(seed)
injection_parameters_1 = generator.uniform(low = 1e-7,high=1e-6,size=num_gw_sources)
injection_parameters_2 = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)

injection_parameters = np.concatenate([injection_parameters_1,injection_parameters_2])
#injection_parameters = None 

labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
labels = None 

variables_to_plot = ["omega_gw_0","phi0_gw_0"]


axes_scales = None
ranges = None
path = '../data/nested_sampling/HD_K1_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   savefig=None,
                   smooth=True,smooth1d=True)
# Out:
# Extracting data from file:  ../data/nested_sampling/HD_K1_result.json
# The evidence is: 585712.3346423662
# Turned off scaling
# The number of samples is: 10854
# Variable/Injection/Median
# omega_gw_0 5.503662181242514e-07 5.508492417552333e-07
# phi0_gw_0 1.0384603063464375 1.1686647245083135
# -------------------------------

# %%
#default values of GW parameters
ranges=[(4e-7,6e-7),(0.5,1.5),(1.2,2.6),(0.4,1.6),(0.8,1.2),(0.2,1.5),(5e-13,5e-12)]

injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-12]
labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
variables_to_plot = ["omega_gw","phi0_gw","psi_gw","iota_gw","delta_gw","alpha_gw", "h"]
axes_scales = None
ranges = None
path = '../data/nested_sampling/pulsar_terms_test_h1e12_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   scalings = [1e9,1e12], #the scalings for omega and h
                   savefig=None,
                   smooth=False,smooth1d=False)

# %%
from plotting import plot_custom_corner
import numpy as np 

#default values of GW parameters
#ranges=[(4e-7,6e-7),(0.5,1.5),(1.2,2.6),(0.4,1.6),(0.8,1.2),(0.2,1.5),(3e-15,7e-15)]
ranges = None



seed = 1237
num_gw_sources = 1
generator = np.random.default_rng(seed)
Ω = generator.uniform(low = 1e-7,high=1e-6,size=num_gw_sources)
Φ0 = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)
ψ = generator.uniform(low = 0.0,high=np.pi,size=num_gw_sources)
ι = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)
δ = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)
α = generator.uniform(low = 0.0,high=np.pi,size=num_gw_sources)
h = generator.uniform(low = 1e-15,high=1e-14,size=num_gw_sources)


injection_parameters = np.concatenate([Ω,Φ0,ψ,ι,δ,α,h])
 

labels = [r'$\Omega$',r'$\Phi_0$',r'$\psi$',r'$\iota$', r'$\delta$',r'$\alpha$',r'$h_{0, \times 10}$']
labels = None 

variables_to_plot = ["omega_gw_0","phi0_gw_0","psi_gw_0","iota_gw_0","delta_gw_0","alpha_gw_0", "h_0"]


axes_scales = None
ranges = None
path = '../data/nested_sampling/HD_K1_result.json'

#Corner plot of GW parameters
plot_custom_corner(path,
                   variables_to_plot,
                   labels,
                   injection_parameters,
                   ranges,
                   axes_scales,
                   savefig=None,
                   smooth=False,smooth1d=False)
# Out:
# Extracting data from file:  ../data/nested_sampling/HD_K1_result.json
# The evidence is: 585712.3346423662
# Turned off scaling
# The number of samples is: 10854
# Variable/Injection/Median
# omega_gw_0 5.503662181242514e-07 5.508492417552333e-07
# phi0_gw_0 1.0384603063464375 1.1686647245083135
# psi_gw_0 0.7371970886251152 0.28946150112288715
# iota_gw_0 0.06751339544698005 0.8085814532497952
# delta_gw_0 0.6283008249992786 0.43016037694704456
# alpha_gw_0 1.7369321284169326 0.9670207356744338
# h_0 3.643380142731973e-15 1.785727334178578e-15
# -------------------------------
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
seed = 1237
num_gw_sources = 2
generator = np.random.default_rng(seed)
injection_parameters_1 = generator.uniform(low = 1e-7,high=1e-6,size=num_gw_sources)
injection_parameters_2 = generator.uniform(low = 0.0,high=np.pi/2,size=num_gw_sources)

# %%
np.concatenate([injection_parameters_1,injection_parameters_2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/t1/github_repos/StateSpacePTA/notebooks/09.Hellings-Downs-parameter_estimation.ipynb Cell 10 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/t1/github_repos/StateSpacePTA/notebooks/09.Hellings-Downs-parameter_estimation.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> np.concatenate(injection_parameters_1,injection_parameters_2)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
from numba import njit

# @njit(fastmath=True)
def example_function(m,n):
    out = m[:, None] * m[None, :] - n[:, None] * n[None, :]
    return out

# %%
K = 4
m = np.random.rand(K, 3)
n = np.random.rand(K, 3)

example_function(m,n)
# Out:
# array([[[ 0.3875865 , -0.56217015, -0.05645147],
#         [ 0.36925799, -0.46793625, -0.55727046],
#         [ 0.50412234, -0.17441273,  0.2746122 ],
#         [-0.02119831, -0.25186697,  0.27774267]],
#
#        [[ 0.36925799, -0.46793625, -0.55727046],
#         [ 0.31225189, -0.28308981, -0.65941533],
#         [ 0.43575107, -0.13601826, -0.15633845],
#         [-0.09346884, -0.23189415, -0.07185092]],
#
#        [[ 0.50412234, -0.17441273,  0.2746122 ],
#         [ 0.43575107, -0.13601826, -0.15633845],
#         [ 0.60554849, -0.05332311,  0.36205004],
#         [-0.11008668, -0.08005621,  0.31508976]],
#
#        [[-0.02119831, -0.25186697,  0.27774267],
#         [-0.09346884, -0.23189415, -0.07185092],
#         [-0.11008668, -0.08005621,  0.31508976],
#         [-0.1346105 , -0.10819202,  0.2685489 ]]])
